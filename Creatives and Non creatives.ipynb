# %% [markdown]
# # Total number of people with disturbs

# %%
SELECT  (COUNT (DISTINCT ?person) as ?peopleCount) 
WHERE { 
  # ?person wdt:P31 wd:Q5. 
  # ?person wdt:P1050 ?disorder.
  # ?disorder wdt:P279+ wd:Q12135.
}

# %% [markdown]
# Result is 2,387

# %% [markdown]
# # Total number of people with disturbs for which an occupation is specified

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT  (COUNT (DISTINCT ?person) as ?peopleCount) 
WHERE { 
  # ?person wdt:P31 wd:Q5. 
  # ?person wdt:P106 ?occupation.
  # ?person wdt:P1050 ?disorder.
  # ?disorder wdt:P279+ wd:Q12135.
}

# %% [markdown]
# Result is 2,268

# %% [markdown]
# # Creatives

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?creativePerson ?occupationLabel ?disorderLabel 
WHERE {
  # ?creativePerson wdt:P31 wd:Q5.
  # ?creativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.
  {VALUES ?occupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501  }} 
  UNION {?occupation wdt:P279+ wd:Q205375}  
  UNION {?occupation wdt:P279+ wd:Q3492227} 
  UNION {?occupation wdt:P279+ wd:Q482980} 
  UNION {?occupation wdt:P279+ wd:Q483501}
  
  MINUS {?occupation wdt:P279+ wd:Q15980158} # non-fiction writer
  MINUS {?occupation wdt:P279+ wd:Q108289407} # authors, journalists, linguists
  MINUS {?occupation wdt:P279+ wd:Q1607826} # editor
  MINUS {?occupation wdt:P279+ wd:Q2675537} # music teacher
  MINUS {?occupation wdt:P279+ wd:Q4610556} # model
  MINUS {?occupation wdt:P279+ wd:Q109459317} # content creator
  MINUS {?occupation wdt:P279+ wd:Q138858} # entertainer
  MINUS {?occupation wdt:P279+ wd:Q13474373} # professional wrestler
  MINUS {?occupation wdt:P279+ wd:Q2066131} # athlete
  MINUS {?occupation wdt:P279+ wd:Q947873} # television presenter
  MINUS {?occupation wdt:P279+ wd:Q2405480} # voice actor
  MINUS {?occupation wdt:P279+ wd:Q852857} # sex worker
  MINUS {?occupation wdt:P279+ wd:Q55187} # hairdresser
  MINUS {?occupation wdt:P279+ wd:Q1294787} # artisan
  MINUS {?occupation wdt:P279+ wd:Q13235160} # manufacturer
  MINUS {?occupation wdt:P279+ wd:Q755070} # narrator
  MINUS {?occupation wdt:P279+ wd:Q115460164} # internet user
  MINUS {?occupation wdt:P279+ wd:Q1907198} # taxonomist
  MINUS {?occupation wdt:P279+ wd:Q1734662} # cartographer
  MINUS {?occupation wdt:P279+ wd:Q183888} # software developer
  MINUS {?occupation wdt:P279+ wd:Q111263847} # digital creator
  MINUS {?occupation wdt:P279+ wd:Q1790480} # translator-interpreter
  MINUS {?occupation wdt:P279+ wd:Q47541952} # producer
  # ?creativePerson wdt:P1050 ?disorder.
   # ?disorder wdt:P279+ wd:Q12135.
   # ?disorder rdfs:label ?disorderLabel.
   FILTER (lang(?disorderLabel) = "en")
   FILTER (LANG(?occupationLabel) = "en") .
}

# %% [markdown]
# Results in 'creativiID.tsv'

# %%
from collections import Counter
import csv

def analyze_creative_persons(tsv_file_path):
    # Initialize Counter
    creative_person_counts = Counter()
    total_rows = 0
    
    # Read TSV file
    with open(tsv_file_path, 'r', encoding='utf-8') as file:
        # Create TSV reader
        tsv_reader = csv.DictReader(file, delimiter='\t')
        
        # Count each creative person occurrence and total rows
        for row in tsv_reader:
            creative_person = row['?creativePerson']
            creative_person_counts[creative_person] += 1
            total_rows += 1
    
    # Get total unique IDs
    total_unique = len(creative_person_counts)
    
    # Count how many IDs appear multiple times
    repeated_ids = sum(1 for count in creative_person_counts.values() if count > 1)
    
    return total_rows, total_unique, repeated_ids

# Example usage
if __name__ == "__main__":
    file_path = "creativiID.tsv"  
    total_rows, total_unique, repeated = analyze_creative_persons(file_path)
    
    print(f"Total number of rows: {total_rows}")
    print(f"Total number of unique creative persons: {total_unique}")
    print(f"Number of creative persons that appear multiple times: {repeated}")
# Out:
# Total number of rows: 4873
# Total number of unique creative persons: 1443
# Number of creative persons that appear multiple times: 1003

# %% [markdown]
# # Non creativi

# %% [markdown]
# Prima query: esclude le classi e sottoclassi di creativi

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?occupationLabel ?disorderLabel ?provenance ?gender ?yearOfBirth
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.
  # Exclude creative professions and their subclasses
  MINUS {
    VALUES ?occupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
  
  MINUS {
    # ?occupation wdt:P279+ ?excludedOccupation .
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
   # ?nonCreativePerson wdt:P1050 ?disorder.
   # ?disorder wdt:P279+ wd:Q12135.
   # ?disorder rdfs:label ?disorderLabel.
   FILTER (lang(?disorderLabel) = "en")
   FILTER (LANG(?occupationLabel) = "en") .
}

# %% [markdown]
# Risultato: nonCreativiID.tsv

# %% [markdown]
# ## Seconda query: include le sottoclassi di mestieri creativi escluse nelle ricerche sui creativi

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?occupationLabel ?disorderLabel ?provenance ?gender ?yearOfBirth
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.

  {
    VALUES ?occupation {
      wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
      wd:Q4610556 wd:Q109459317 wd:Q138858 wd:Q13474373
      wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
      wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
      wd:Q115460164 wd:Q1907198 wd:Q1734662 wd:Q183888
      wd:Q111263847 wd:Q1790480 wd:Q47541952
    }
  } UNION {
    # ?occupation wdt:P279+ ?includedOccupation .
    VALUES ?includedOccupation {
      wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
      wd:Q4610556 wd:Q109459317 wd:Q138858 wd:Q13474373
      wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
      wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
      wd:Q115460164 wd:Q1907198 wd:Q1734662 wd:Q183888
      wd:Q111263847 wd:Q1790480 wd:Q47541952
    }
  }
  # ?nonCreativePerson wdt:P1050 ?disorder.
   # ?disorder wdt:P279+ wd:Q12135.
   # ?disorder rdfs:label ?disorderLabel.
   FILTER (lang(?disorderLabel) = "en")
   FILTER (LANG(?occupationLabel) = "en") .
}

# %%
Risultato: nonCreativiID2.tsv

# %% [markdown]
# ## A code to merge the two non-creatives files and delete people identified as creative

# %% [markdown]
# The code:
# - First merges both non-creative files into one
# - Then checks for any IDs that appear in both:
#         - the merged non-creative file
#         - the creative file
# - Removes any rows from the merged non-creative file where the ID appears in the creative file
# - Save the result to a new file

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'merged_cleaned_noncreative.tsv') -> None:
    """
    Merge non-creative files and remove duplicates that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')
        
        # Step 1: Merge non-creative files
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        print(f"\nInitial merge:")
        print(f"- Rows from first non-creative file: {len(noncreative_df1)}")
        print(f"- Rows from second non-creative file: {len(noncreative_df2)}")
        print(f"- Total rows after merge: {len(merged_df)}")
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Find duplicate IDs
        duplicate_ids = set(merged_df['?nonCreativePerson']).intersection(creative_ids)
        
        # Remove rows with duplicate IDs from merged file
        cleaned_df = merged_df[~merged_df['?nonCreativePerson'].isin(duplicate_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print summary
        print(f"\nDuplicate removal:")
        print(f"- Found {len(duplicate_ids)} IDs that appear in both creative and non-creative files")
        if duplicate_ids:
            print("\nDuplicate IDs removed:")
            for id in sorted(duplicate_ids):
                print(f"- {id}")
        
        print(f"\nFinal results:")
        print(f"- Original total rows: {len(merged_df)}")
        print(f"- Rows after removing duplicates: {len(cleaned_df)}")
        print(f"- Rows removed: {len(merged_df) - len(cleaned_df)}")
        print(f"- Output saved to: {output_file}")
        
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativiID.tsv'
        noncreative_file1 = 'nonCreativiID.tsv'
        noncreative_file2 = 'nonCreativiID2.tsv'
        output_file = 'merged_cleaned_noncreative.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Initial merge:
# - Rows from first non-creative file: 2169
# - Rows from second non-creative file: 2388
# - Total rows after merge: 4557
#
# Duplicate removal:
# - Found 758 IDs that appear in both creative and non-creative files
#
# Duplicate IDs removed:
# - <http://www.wikidata.org/entity/Q100292045>
# - <http://www.wikidata.org/entity/Q100583464>
# - <http://www.wikidata.org/entity/Q100595699>
# - <http://www.wikidata.org/entity/Q1006152>
# - <http://www.wikidata.org/entity/Q101424804>
# - <http://www.wikidata.org/entity/Q102046737>
# - <http://www.wikidata.org/entity/Q102374>
# - <http://www.wikidata.org/entity/Q102423299>
# - <http://www.wikidata.org/entity/Q102870>
# - <http://www.wikidata.org/entity/Q10314466>
# - <http://www.wikidata.org/entity/Q10321758>
# - <http://www.wikidata.org/entity/Q1035>
# - <http://www.wikidata.org/entity/Q104358>
# - <http://www.wikidata.org/entity/Q104524450>
# - <http://www.wikidata.org/entity/Q104604510>
# - <http://www.wikidata.org/entity/Q104678350>
# - <http://www.wikidata.org/entity/Q1047230>
# - <http://www.wikidata.org/entity/Q104833817>
# - <http://www.wikidata.org/entity/Q105062256>
# - <http://www.wikidata.org/entity/Q105118>
# - <http://www.wikidata.org/entity/Q1051540>
# - <http://www.wikidata.org/entity/Q105221>
# - <http://www.wikidata.org/entity/Q105586692>
# - <http://www.wikidata.org/entity/Q105670357>
# - <http://www.wikidata.org/entity/Q105756>
# - <http://www.wikidata.org/entity/Q106059562>
# - <http://www.wikidata.org/entity/Q106144371>
# - <http://www.wikidata.org/entity/Q106144873>
# - <http://www.wikidata.org/entity/Q1064725>
# - <http://www.wikidata.org/entity/Q1064>
# - <http://www.wikidata.org/entity/Q106555026>
# - <http://www.wikidata.org/entity/Q106655>
# - <http://www.wikidata.org/entity/Q1066772>
# - <http://www.wikidata.org/entity/Q106764172>
# - <http://www.wikidata.org/entity/Q106919>
# - <http://www.wikidata.org/entity/Q107178342>
# - <http://www.wikidata.org/entity/Q107578176>
# - <http://www.wikidata.org/entity/Q1082262>
# - <http://www.wikidata.org/entity/Q108381040>
# - <http://www.wikidata.org/entity/Q10852064>
# - <http://www.wikidata.org/entity/Q108730747>
# - <http://www.wikidata.org/entity/Q108866571>
# - <http://www.wikidata.org/entity/Q108869462>
# - <http://www.wikidata.org/entity/Q108941>
# - <http://www.wikidata.org/entity/Q109723134>
# - <http://www.wikidata.org/entity/Q1097700>
# - <http://www.wikidata.org/entity/Q10993>
# - <http://www.wikidata.org/entity/Q110124197>
# - <http://www.wikidata.org/entity/Q110426251>
# - <http://www.wikidata.org/entity/Q110606167>
# - <http://www.wikidata.org/entity/Q110715063>
# - <http://www.wikidata.org/entity/Q110761439>
# - <http://www.wikidata.org/entity/Q110887457>
# - <http://www.wikidata.org/entity/Q11093>
# - <http://www.wikidata.org/entity/Q110981566>
# - <http://www.wikidata.org/entity/Q111077228>
# - <http://www.wikidata.org/entity/Q111145154>
# - <http://www.wikidata.org/entity/Q111964983>
# - <http://www.wikidata.org/entity/Q11239>
# - <http://www.wikidata.org/entity/Q83338>
# - <http://www.wikidata.org/entity/Q834338>
# - <http://www.wikidata.org/entity/Q83484>
# - <http://www.wikidata.org/entity/Q84232>
# - <http://www.wikidata.org/entity/Q8442>
# - <http://www.wikidata.org/entity/Q86016909>
# - <http://www.wikidata.org/entity/Q862389>
# - <http://www.wikidata.org/entity/Q8704>
# - <http://www.wikidata.org/entity/Q87370196>
# - <http://www.wikidata.org/entity/Q887401>
# - <http://www.wikidata.org/entity/Q894993>
# - <http://www.wikidata.org/entity/Q89624>
# - <http://www.wikidata.org/entity/Q90031>
# - <http://www.wikidata.org/entity/Q9012879>
# - <http://www.wikidata.org/entity/Q9039389>
# - <http://www.wikidata.org/entity/Q906529>
# - <http://www.wikidata.org/entity/Q91059>
# - <http://www.wikidata.org/entity/Q92601>
# - <http://www.wikidata.org/entity/Q926682>
# - <http://www.wikidata.org/entity/Q9286833>
# - <http://www.wikidata.org/entity/Q939050>
# - <http://www.wikidata.org/entity/Q944894>
# - <http://www.wikidata.org/entity/Q948093>
# - <http://www.wikidata.org/entity/Q95459>
# - <http://www.wikidata.org/entity/Q95573131>
# - <http://www.wikidata.org/entity/Q95880846>
# - <http://www.wikidata.org/entity/Q95883175>
# - <http://www.wikidata.org/entity/Q95883837>
# - <http://www.wikidata.org/entity/Q96675594>
# - <http://www.wikidata.org/entity/Q971585>
# - <http://www.wikidata.org/entity/Q977651>
# - <http://www.wikidata.org/entity/Q97924877>
# - <http://www.wikidata.org/entity/Q979387>
# - <http://www.wikidata.org/entity/Q98104741>
# - <http://www.wikidata.org/entity/Q98406706>
# - <http://www.wikidata.org/entity/Q98445880>
# - <http://www.wikidata.org/entity/Q98465764>
# - <http://www.wikidata.org/entity/Q98819388>
# - <http://www.wikidata.org/entity/Q99251772>
# - <http://www.wikidata.org/entity/Q99772980>
#
# Final results:
# - Original total rows: 4557
# - Rows after removing duplicates: 2088
# - Rows removed: 2469
# - Output saved to: merged_cleaned_noncreative.tsv

# %%
from collections import Counter
import csv

def analyze_creative_persons(tsv_file_path):
    # Initialize Counter
    creative_person_counts = Counter()
    total_rows = 0
    
    # Read TSV file
    with open(tsv_file_path, 'r', encoding='utf-8') as file:
        # Create TSV reader
        tsv_reader = csv.DictReader(file, delimiter='\t')
        
        # Count each creative person occurrence and total rows
        for row in tsv_reader:
            creative_person = row['?nonCreativePerson']
            creative_person_counts[creative_person] += 1
            total_rows += 1
    
    # Get total unique IDs
    total_unique = len(creative_person_counts)
    
    # Count how many IDs appear multiple times
    repeated_ids = sum(1 for count in creative_person_counts.values() if count > 1)
    
    return total_rows, total_unique, repeated_ids

# Example usage
if __name__ == "__main__":
    file_path = "merged_cleaned_noncreative.tsv" 
    total_rows, total_unique, repeated = analyze_creative_persons(file_path)
    
    print(f"Total number of rows: {total_rows}")
    print(f"Total number of unique non-creative persons: {total_unique}")
    print(f"Number of non-creative persons that appear multiple times: {repeated}")
# Out:
# Total number of rows: 2088
# Total number of unique non-creative persons: 823
# Number of non-creative persons that appear multiple times: 566

# %% [markdown]
# Total of creatives with disturbs (1443) and non-creatives with disturbs (823) sums up to 2266.The missing people do not have an occupation specified.

# %% [markdown]
# # Ask for creatives' gender, provenance, year of birth via a remote query

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from tqdm import tqdm
import time
import re

def extract_wikidata_id(uri):
    """Extract Q-identifier from full Wikidata URI"""
    match = re.search(r'Q\d+', uri)
    return match.group(0) if match else None

def chunk_list(lst, chunk_size):
    """Split list into chunks of specified size"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def create_query(wikidata_ids):
    """Create SPARQL query for multiple entities with optional properties"""
    # Create VALUES clause with wd: prefix for each Q-ID
    entities = ' '.join(f'(wd:{id_})' for id_ in wikidata_ids)
    
    query = f"""
    SELECT DISTINCT ?entity ?genderLabel ?provenanceLabel ?yearOfBirth
    WHERE {{
        VALUES (?entity) {{ {entities} }}
        
        OPTIONAL {{
            # ?entity wdt:P21 ?gender.
            # ?gender rdfs:label ?genderLabel.
            FILTER(LANG(?genderLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P27 ?provenance.
            # ?provenance rdfs:label ?provenanceLabel.
            FILTER(LANG(?provenanceLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P569 ?dateOfBirth.
            BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
        }}
    }}
    """
    return query

def query_wikidata(sparql, ids):
    """Query Wikidata and return results"""
    query = create_query(ids)
    sparql.setQuery(query)
    
    try:
        results = sparql.query().convert()
        return results['results']['bindings']
    except Exception as e:
        print(f"Error querying Wikidata: {e}")
        return []

def process_results(results):
    """Process SPARQL results into a list of dictionaries"""
    processed = []
    for result in results:
        processed.append({
            'entity': result['entity']['value'],
            'gender': result.get('genderLabel', {}).get('value', None),
            'provenance': result.get('provenanceLabel', {}).get('value', None),
            'year_of_birth': result.get('yearOfBirth', {}).get('value', None)
        })
    return processed

def main():
    # Initialize SPARQL endpoint
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader('User-Agent', 'MyWikidataBot/1.0')
    
    # Read TSV file - replace 'your_file.tsv' with actual filename
    # and 'wikidata_column' with the actual column name containing Wikidata IDs
    df = pd.read_csv('creativiID.tsv', sep='\t')
    
    # Extract unique Wikidata IDs and clean them
    wikidata_uris = df['?creativePerson'].unique()
    wikidata_ids = [extract_wikidata_id(uri) for uri in wikidata_uris if pd.notna(uri)]
    wikidata_ids = [id_ for id_ in wikidata_ids if id_ is not None]
    
    print(f"Found {len(wikidata_ids)} unique Wikidata IDs")
    
    # Process in chunks of 50 entities
    CHUNK_SIZE = 50
    chunks = chunk_list(wikidata_ids, CHUNK_SIZE)
    
    all_results = []
    
    # Process each chunk with progress bar
    for chunk in tqdm(chunks, desc="Processing Wikidata entities"):
        results = query_wikidata(sparql, chunk)
        processed_results = process_results(results)
        all_results.extend(processed_results)
        
        # Add delay to avoid hitting rate limits
        time.sleep(1)
    
    # Convert results to DataFrame and save
    results_df = pd.DataFrame(all_results)
    results_df.to_csv('wikidata_results.csv', index=False)
    print(f"Processed {len(all_results)} entities. Results saved to wikidata_results.csv")

if __name__ == "__main__":
    main()
# Out:
# Found 1443 unique Wikidata IDs
# Processing Wikidata entities: 100%|████████████████████████████████████████████████████| 29/29 [01:02<00:00,  2.16s/it]
# Processed 1634 entities. Results saved to wikidata_results.csv

# %% [markdown]
# # Ask for non-creatives' gender, provenance, year of birth via a remote query

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from tqdm import tqdm
import time
import re

def extract_wikidata_id(uri):
    """Extract Q-identifier from full Wikidata URI"""
    match = re.search(r'Q\d+', uri)
    return match.group(0) if match else None

def chunk_list(lst, chunk_size):
    """Split list into chunks of specified size"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def create_query(wikidata_ids):
    """Create SPARQL query for multiple entities with optional properties"""
    # Create VALUES clause with wd: prefix for each Q-ID
    entities = ' '.join(f'(wd:{id_})' for id_ in wikidata_ids)
    
    query = f"""
    SELECT DISTINCT ?entity ?genderLabel ?provenanceLabel ?yearOfBirth
    WHERE {{
        VALUES (?entity) {{ {entities} }}
        
        OPTIONAL {{
            # ?entity wdt:P21 ?gender.
            # ?gender rdfs:label ?genderLabel.
            FILTER(LANG(?genderLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P27 ?provenance.
            # ?provenance rdfs:label ?provenanceLabel.
            FILTER(LANG(?provenanceLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P569 ?dateOfBirth.
            BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
        }}
    }}
    """
    return query

def query_wikidata(sparql, ids):
    """Query Wikidata and return results"""
    query = create_query(ids)
    sparql.setQuery(query)
    
    try:
        results = sparql.query().convert()
        return results['results']['bindings']
    except Exception as e:
        print(f"Error querying Wikidata: {e}")
        return []

def process_results(results):
    """Process SPARQL results into a list of dictionaries"""
    processed = []
    for result in results:
        processed.append({
            'entity': result['entity']['value'],
            'gender': result.get('genderLabel', {}).get('value', None),
            'provenance': result.get('provenanceLabel', {}).get('value', None),
            'year_of_birth': result.get('yearOfBirth', {}).get('value', None)
        })
    return processed

def main():
    # Initialize SPARQL endpoint
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader('User-Agent', 'MyWikidataBot/1.0')
    
    # Read TSV file - replace 'your_file.tsv' with actual filename
    # and 'wikidata_column' with the actual column name containing Wikidata IDs
    df = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
    
    # Extract unique Wikidata IDs and clean them
    wikidata_uris = df['?nonCreativePerson'].unique()
    wikidata_ids = [extract_wikidata_id(uri) for uri in wikidata_uris if pd.notna(uri)]
    wikidata_ids = [id_ for id_ in wikidata_ids if id_ is not None]
    
    print(f"Found {len(wikidata_ids)} unique Wikidata IDs")
    
    # Process in chunks of 50 entities
    CHUNK_SIZE = 50
    chunks = chunk_list(wikidata_ids, CHUNK_SIZE)
    
    all_results = []
    
    # Process each chunk with progress bar
    for chunk in tqdm(chunks, desc="Processing Wikidata entities"):
        results = query_wikidata(sparql, chunk)
        processed_results = process_results(results)
        all_results.extend(processed_results)
        
        # Add delay to avoid hitting rate limits
        time.sleep(1)
    
    # Convert results to DataFrame and save
    results_df = pd.DataFrame(all_results)
    results_df.to_csv('wikidata_results_non_creatives.csv', index=False)
    print(f"Processed {len(all_results)} entities. Results saved to wikidata_results.csv")

if __name__ == "__main__":
    main()
# Out:
# Found 823 unique Wikidata IDs
# Processing Wikidata entities: 100%|████████████████████████████████████████████████████| 17/17 [00:33<00:00,  1.99s/it]
# Processed 917 entities. Results saved to wikidata_results.csv

# %% [markdown]
# # Merge new info in creatives' dataset

# %% [markdown]
# First note: in the csv, we have duplicates for people with multiple nationality or gender info. We keep it for now.

# %%
import pandas as pd

def analyze_duplicates():
    # Read the CSV file
    df = pd.read_csv('wikidata_results.csv')
    
    # Find duplicated entities
    duplicated_entities = df[df.duplicated(subset=['entity'], keep=False)].sort_values('entity')
    
    print(f"Total number of rows with duplicates: {len(duplicated_entities)}")
    print(f"Number of unique entities with duplicates: {len(duplicated_entities['entity'].unique())}")
    print("\nDetailed view of duplicates:")
    print("=" * 80)
    
    # Group by entity and show differences
    for entity in duplicated_entities['entity'].unique():
        entity_rows = duplicated_entities[duplicated_entities['entity'] == entity]
        print(f"\nEntity: {entity}")
        print(f"Number of occurrences: {len(entity_rows)}")
        print("\nFull data:")
        print(entity_rows.to_string(index=False))
        print("-" * 80)

if __name__ == "__main__":
    analyze_duplicates()
# Out:
# Total number of rows with duplicates: 356
# Number of unique entities with duplicates: 165
#
# Detailed view of duplicates:
# ================================================================================
#
# Entity: http://www.wikidata.org/entity/Q1040834
# Number of occurrences: 2
#
# Full data:
#                                  entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q1040834   male   German Empire         1831.0
# http://www.wikidata.org/entity/Q1040834   male Austria-Hungary         1831.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1064
# Number of occurrences: 3
#
# Full data:
#                               entity gender          provenance  year_of_birth
# http://www.wikidata.org/entity/Q1064   male Kingdom of Sardinia         1785.0
# http://www.wikidata.org/entity/Q1064   male      Duchy of Milan         1785.0
# http://www.wikidata.org/entity/Q1064   male    Kingdom of Italy         1785.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q106881
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q106881 female            Italy         1931.0
# http://www.wikidata.org/entity/Q106881 female Kingdom of Italy         1931.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q106919
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q106919 female Kingdom of Italy         1930.0
# http://www.wikidata.org/entity/Q106919 female            Italy         1930.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q108036804
# Number of occurrences: 2
#
# Full data:
#                                    entity         gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q108036804     non-binary United States         1984.0
# http://www.wikidata.org/entity/Q108036804 transmasculine United States         1984.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q108381040
# Number of occurrences: 2
#
# Full data:
#                                    entity     gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q108381040 non-binary United States            NaN
# http://www.wikidata.org/entity/Q108381040  trans man United States            NaN
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q108600209
# Number of occurrences: 2
#
# Full data:
#                                    entity         gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q108600209 transmasculine United States            NaN
# http://www.wikidata.org/entity/Q108600209     non-binary United States            NaN
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q108866571
# Number of occurrences: 2
#
# Full data:
#                                    entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q108866571 female United States         1990.0
# http://www.wikidata.org/entity/Q108866571 female   South Korea         1990.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q110981566
# Number of occurrences: 2
#
# Full data:
#                                    entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q110981566 female United Kingdom         1996.0
# http://www.wikidata.org/entity/Q110981566 female  United States         1996.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q113695003
# Number of occurrences: 2
#
# Full data:
#                                    entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q113695003   male  Australia         1993.0
# http://www.wikidata.org/entity/Q113695003   male   Malaysia         1993.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q115948996
# Number of occurrences: 2
#
# Full data:
#                                    entity     gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q115948996 non-binary United States         2001.0
# http://www.wikidata.org/entity/Q115948996  trans man United States         2001.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q116782744
# Number of occurrences: 2
#
# Full data:
#                                    entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q116782744 female United Kingdom         1969.0
# http://www.wikidata.org/entity/Q116782744 female          Sudan         1969.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q117289325
# Number of occurrences: 2
#
# Full data:
#                                    entity        gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q117289325    non-binary United States         1998.0
# http://www.wikidata.org/entity/Q117289325 transfeminine United States         1998.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q117825637
# Number of occurrences: 2
#
# Full data:
#                                    entity      gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q117825637 trans woman United States         1985.0
# http://www.wikidata.org/entity/Q117825637 trans woman United States         1986.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q11998
# Number of occurrences: 2
#
# Full data:
#                                entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q11998 female      Australia         1968.0
# http://www.wikidata.org/entity/Q11998 female United Kingdom         1968.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q12213386
# Number of occurrences: 3
#
# Full data:
#                                   entity gender             provenance  year_of_birth
# http://www.wikidata.org/entity/Q12213386   male         Ba'athist Iraq         1934.0
# http://www.wikidata.org/entity/Q12213386   male First Republic of Iraq         1934.0
# http://www.wikidata.org/entity/Q12213386   male        Kingdom of Iraq         1934.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q12213432
# Number of occurrences: 3
#
# Full data:
#                                   entity gender             provenance  year_of_birth
# http://www.wikidata.org/entity/Q12213432   male First Republic of Iraq         1931.0
# http://www.wikidata.org/entity/Q12213432   male        Kingdom of Iraq         1931.0
# http://www.wikidata.org/entity/Q12213432   male         Ba'athist Iraq         1931.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q12297196
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q12297196 female     Venezuela         1996.0
# http://www.wikidata.org/entity/Q12297196 female United States         1996.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q123608843
# Number of occurrences: 2
#
# Full data:
#                                    entity    gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q123608843 trans man     Canada         1998.0
# http://www.wikidata.org/entity/Q123608843 trans man     Canada         1999.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q124606307
# Number of occurrences: 2
#
# Full data:
#                                    entity gender         provenance  year_of_birth
# http://www.wikidata.org/entity/Q124606307 female           Ethiopia         1997.0
# http://www.wikidata.org/entity/Q124606307 female Kingdom of Denmark         1997.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q125106
# Number of occurrences: 3
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q125106 female        Mexico         1966.0
# http://www.wikidata.org/entity/Q125106 female        France         1966.0
# http://www.wikidata.org/entity/Q125106 female United States         1966.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q12644829
# Number of occurrences: 2
#
# Full data:
#                                   entity gender                               provenance  year_of_birth
# http://www.wikidata.org/entity/Q12644829   male                                  Croatia         1947.0
# http://www.wikidata.org/entity/Q12644829   male Socialist Federal Republic of Yugoslavia         1947.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1300641
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q1300641   male Kingdom of Italy         1885.0
# http://www.wikidata.org/entity/Q1300641   male Kingdom of Italy         1884.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q131814
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q131814 female   Switzerland         1939.0
# http://www.wikidata.org/entity/Q131814 female United States         1939.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q134942
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q134942   male                              United Kingdom         1874.0
# http://www.wikidata.org/entity/Q134942   male United Kingdom of Great Britain and Ireland         1874.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1358541
# Number of occurrences: 2
#
# Full data:
#                                  entity gender  provenance  year_of_birth
# http://www.wikidata.org/entity/Q1358541   male Switzerland         1920.0
# http://www.wikidata.org/entity/Q1358541   male      France         1920.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1496427
# Number of occurrences: 2
#
# Full data:
#                                  entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q1496427   male United Kingdom of Great Britain and Ireland         1914.0
# http://www.wikidata.org/entity/Q1496427   male                              United Kingdom         1914.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q152292
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q152292 female          Italy         1969.0
# http://www.wikidata.org/entity/Q152292 female United Kingdom         1969.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q15429155
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q15429155   male      Australia         1948.0
# http://www.wikidata.org/entity/Q15429155   male United Kingdom         1948.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q155136
# Number of occurrences: 2
#
# Full data:
#                                 entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q155136   male    Germany         1885.0
# http://www.wikidata.org/entity/Q155136   male     Israel         1885.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1587727
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q1587727 female            Italy         1924.0
# http://www.wikidata.org/entity/Q1587727 female Kingdom of Italy         1924.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q159648
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q159648   male            Italy         1936.0
# http://www.wikidata.org/entity/Q159648   male Kingdom of Italy         1936.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q161363
# Number of occurrences: 3
#
# Full data:
#                                 entity gender               provenance  year_of_birth
# http://www.wikidata.org/entity/Q161363   male Polish People's Republic         1924.0
# http://www.wikidata.org/entity/Q161363   male                   Poland         1924.0
# http://www.wikidata.org/entity/Q161363   male   Second Polish Republic         1924.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q164358
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q164358   male United States         1925.0
# http://www.wikidata.org/entity/Q164358   male       Germany         1925.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q164750
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q164750   male United Kingdom         1967.0
# http://www.wikidata.org/entity/Q164750   male  United States         1967.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q16509396
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q16509396   male United Kingdom         1938.0
# http://www.wikidata.org/entity/Q16509396   male        England         1938.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q16734476
# Number of occurrences: 2
#
# Full data:
#                                   entity     gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q16734476 non-binary United States         2004.0
# http://www.wikidata.org/entity/Q16734476 non-binary United States         2005.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q170509
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q170509   male                               United States         1843.0
# http://www.wikidata.org/entity/Q170509   male United Kingdom of Great Britain and Ireland         1843.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q172678
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q172678   male United States         1948.0
# http://www.wikidata.org/entity/Q172678   male         Gabon         1948.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q173481
# Number of occurrences: 2
#
# Full data:
#                                 entity gender          provenance  year_of_birth
# http://www.wikidata.org/entity/Q173481   male Kingdom of Portugal         1888.0
# http://www.wikidata.org/entity/Q173481   male            Portugal         1888.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q18107406
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q18107406 female     Australia         1950.0
# http://www.wikidata.org/entity/Q18107406 female United States         1950.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1857695
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q1857695   male       Russia         1924.0
# http://www.wikidata.org/entity/Q1857695   male Soviet Union         1924.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q186329
# Number of occurrences: 3
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q186329   male  United States         1983.0
# http://www.wikidata.org/entity/Q186329   male        Lebanon         1983.0
# http://www.wikidata.org/entity/Q186329   male United Kingdom         1983.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q191132
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q191132   male       Romania         1939.0
# http://www.wikidata.org/entity/Q191132   male United States         1939.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q192912
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q192912   male        Austria         1957.0
# http://www.wikidata.org/entity/Q192912   male United Kingdom         1957.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q193405
# Number of occurrences: 4
#
# Full data:
#                                 entity gender         provenance  year_of_birth
# http://www.wikidata.org/entity/Q193405   male            Romania         1911.0
# http://www.wikidata.org/entity/Q193405   male             France         1911.0
# http://www.wikidata.org/entity/Q193405   male    Austria-Hungary         1911.0
# http://www.wikidata.org/entity/Q193405   male Kingdom of Romania         1911.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q193517
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q193517 female  United States         1983.0
# http://www.wikidata.org/entity/Q193517 female United Kingdom         1983.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q194363
# Number of occurrences: 6
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q194363   male   Soviet Union         1889.0
# http://www.wikidata.org/entity/Q194363   male         Poland         1889.0
# http://www.wikidata.org/entity/Q194363   male         Poland         1890.0
# http://www.wikidata.org/entity/Q194363   male Russian Empire         1889.0
# http://www.wikidata.org/entity/Q194363   male Russian Empire         1890.0
# http://www.wikidata.org/entity/Q194363   male   Soviet Union         1890.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2022
# Number of occurrences: 2
#
# Full data:
#                               entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q2022   male Kingdom of Italy         1908.0
# http://www.wikidata.org/entity/Q2022   male            Italy         1908.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2023710
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q2023710   male        England         1996.0
# http://www.wikidata.org/entity/Q2023710   male United Kingdom         1996.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2027983
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q2027983   male     Sweden         1932.0
# http://www.wikidata.org/entity/Q2027983   male     Norway         1932.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q204019
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q204019 female United Kingdom         1975.0
# http://www.wikidata.org/entity/Q204019 female      Sri Lanka         1975.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q20721
# Number of occurrences: 3
#
# Full data:
#                                entity gender             provenance  year_of_birth
# http://www.wikidata.org/entity/Q20721   male         United Kingdom         1760.0
# http://www.wikidata.org/entity/Q20721   male                 France         1760.0
# http://www.wikidata.org/entity/Q20721   male Grand Duchy of Tuscany         1760.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q21062531
# Number of occurrences: 3
#
# Full data:
#                                   entity         gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q21062531 transmasculine United States         1991.0
# http://www.wikidata.org/entity/Q21062531     non-binary United States         1991.0
# http://www.wikidata.org/entity/Q21062531       bigender United States         1991.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q214309
# Number of occurrences: 3
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q214309   male United Kingdom         1947.0
# http://www.wikidata.org/entity/Q214309   male    New Zealand         1947.0
# http://www.wikidata.org/entity/Q214309   male        Ireland         1947.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q233295
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q233295 female United States         1981.0
# http://www.wikidata.org/entity/Q233295 female     Singapore         1981.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q234471
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q234471 female United States         1948.0
# http://www.wikidata.org/entity/Q234471 female        Canada         1948.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q237268
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q237268   male Kingdom of the Netherlands         1940.0
# http://www.wikidata.org/entity/Q237268   male                  Australia         1940.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q237820
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q237820 female         France         1961.0
# http://www.wikidata.org/entity/Q237820 female United Kingdom         1961.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q241087
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q241087 female            Italy         1931.0
# http://www.wikidata.org/entity/Q241087 female Kingdom of Italy         1931.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q243419
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q243419   male United Kingdom of Great Britain and Ireland         1887.0
# http://www.wikidata.org/entity/Q243419   male                              United Kingdom         1887.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2450102
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q2450102   male United Kingdom         1949.0
# http://www.wikidata.org/entity/Q2450102   male         Canada         1949.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q24572584
# Number of occurrences: 3
#
# Full data:
#                                   entity      gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q24572584  non-binary     Canada         1988.0
# http://www.wikidata.org/entity/Q24572584      female     Canada         1988.0
# http://www.wikidata.org/entity/Q24572584 trans woman     Canada         1988.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2510829
# Number of occurrences: 2
#
# Full data:
#                                  entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q2510829   male United Kingdom of Great Britain and Ireland         1922.0
# http://www.wikidata.org/entity/Q2510829   male                              United Kingdom         1922.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q25161
# Number of occurrences: 2
#
# Full data:
#                                entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q25161   male United Kingdom         1916.0
# http://www.wikidata.org/entity/Q25161   male         Norway         1916.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q25396976
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q25396976 female United Kingdom         1990.0
# http://www.wikidata.org/entity/Q25396976 female United Kingdom         1991.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q254383
# Number of occurrences: 2
#
# Full data:
#                                 entity gender            provenance  year_of_birth
# http://www.wikidata.org/entity/Q254383 female Kingdom of Yugoslavia         1874.0
# http://www.wikidata.org/entity/Q254383 female    Kingdom of Hungary         1874.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q255
# Number of occurrences: 2
#
# Full data:
#                              entity gender            provenance  year_of_birth
# http://www.wikidata.org/entity/Q255   male       Austrian Empire         1770.0
# http://www.wikidata.org/entity/Q255   male Electorate of Cologne         1770.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q275610
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q275610 female        Canada         1912.0
# http://www.wikidata.org/entity/Q275610 female United States         1912.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q275979
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q275979 female            Italy         1912.0
# http://www.wikidata.org/entity/Q275979 female Kingdom of Italy         1912.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q27917788
# Number of occurrences: 2
#
# Full data:
#                                   entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q27917788   male Empire of Japan         1927.0
# http://www.wikidata.org/entity/Q27917788   male           Japan         1927.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q28036796
# Number of occurrences: 2
#
# Full data:
#                                   entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q28036796 female                              United Kingdom         1926.0
# http://www.wikidata.org/entity/Q28036796 female United Kingdom of Great Britain and Ireland         1926.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2830336
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q2830336   male South Africa         1988.0
# http://www.wikidata.org/entity/Q2830336   male    Australia         1988.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q29033239
# Number of occurrences: 2
#
# Full data:
#                                   entity          gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q29033239 cisgender woman United Kingdom         1970.0
# http://www.wikidata.org/entity/Q29033239          female United Kingdom         1970.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q294773
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q294773   male United Kingdom         1937.0
# http://www.wikidata.org/entity/Q294773   male Czechoslovakia         1937.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2975269
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q2975269 female United Kingdom         1950.0
# http://www.wikidata.org/entity/Q2975269 female        Iceland         1950.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q297865
# Number of occurrences: 2
#
# Full data:
#                                 entity      gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q297865 trans woman United Kingdom         1954.0
# http://www.wikidata.org/entity/Q297865    intersex United Kingdom         1954.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q302573
# Number of occurrences: 3
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q302573   male United Kingdom         1949.0
# http://www.wikidata.org/entity/Q302573   male    New Zealand         1949.0
# http://www.wikidata.org/entity/Q302573   male         Canada         1949.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3072632
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q3072632 female     Brazil         1960.0
# http://www.wikidata.org/entity/Q3072632 female     Brazil         1959.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3080044
# Number of occurrences: 4
#
# Full data:
#                                  entity gender                              provenance  year_of_birth
# http://www.wikidata.org/entity/Q3080044   male Federal People's Republic of Yugoslavia         1892.0
# http://www.wikidata.org/entity/Q3080044   male   Kingdom of Serbs, Croats and Slovenes         1892.0
# http://www.wikidata.org/entity/Q3080044   male                            Cisleithania         1892.0
# http://www.wikidata.org/entity/Q3080044   male                   Kingdom of Yugoslavia         1892.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q318734
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q318734   male  United States         1889.0
# http://www.wikidata.org/entity/Q318734   male United Kingdom         1889.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q320849
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q320849   male                    Kingdom of Great Britain         1780.0
# http://www.wikidata.org/entity/Q320849   male United Kingdom of Great Britain and Ireland         1780.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q325141
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q325141   male United Kingdom of Great Britain and Ireland         1914.0
# http://www.wikidata.org/entity/Q325141   male                              United Kingdom         1914.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3309911
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q3309911 female      Italy         1976.0
# http://www.wikidata.org/entity/Q3309911 female     Brazil         1976.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q356369
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q356369   male United Kingdom         1957.0
# http://www.wikidata.org/entity/Q356369   male        Ireland         1957.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q362251
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q362251   male United Kingdom         1979.0
# http://www.wikidata.org/entity/Q362251   male    New Zealand         1979.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3624123
# Number of occurrences: 2
#
# Full data:
#                                  entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q3624123 female Northern Cyprus         1984.0
# http://www.wikidata.org/entity/Q3624123 female          Turkey         1984.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q36838423
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q36838423   male        Israel         1985.0
# http://www.wikidata.org/entity/Q36838423   male United States         1985.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q37459
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q37459 female United States         1967.0
# http://www.wikidata.org/entity/Q37459 female     Australia         1967.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3802067
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q3802067 female Kingdom of Italy         1867.0
# http://www.wikidata.org/entity/Q3802067 female            Italy         1867.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q38082
# Number of occurrences: 2
#
# Full data:
#                                entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q38082   male United Kingdom of Great Britain and Ireland         1832.0
# http://www.wikidata.org/entity/Q38082   male                                     England         1832.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3809967
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q3809967 female            Italy         1896.0
# http://www.wikidata.org/entity/Q3809967 female Kingdom of Italy         1896.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3810178
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q3810178   male United States         1989.0
# http://www.wikidata.org/entity/Q3810178   male United States         1988.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3815161
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q3815161 female Kingdom of Italy         1907.0
# http://www.wikidata.org/entity/Q3815161 female            Italy         1907.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3838462
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q3838462 female Kingdom of Italy         1907.0
# http://www.wikidata.org/entity/Q3838462 female            Italy         1907.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3910
# Number of occurrences: 2
#
# Full data:
#                               entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q3910   male United States         1958.0
# http://www.wikidata.org/entity/Q3910   male        Monaco         1958.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3938542
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q3938542 female            Italy         1943.0
# http://www.wikidata.org/entity/Q3938542 female Kingdom of Italy         1943.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q4015600
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q4015600 female United Kingdom         1954.0
# http://www.wikidata.org/entity/Q4015600 female United Kingdom         1955.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q40504
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q40504   male United States         1962.0
# http://www.wikidata.org/entity/Q40504   male        Canada         1962.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q418575
# Number of occurrences: 2
#
# Full data:
#                                 entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q418575   male Empire of Japan         1943.0
# http://www.wikidata.org/entity/Q418575   male           Japan         1943.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q4280820
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q4280820   male United States         1945.0
# http://www.wikidata.org/entity/Q4280820   male        Canada         1945.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q430846
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q430846 female            Italy         1930.0
# http://www.wikidata.org/entity/Q430846 female Kingdom of Italy         1930.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q43393011
# Number of occurrences: 2
#
# Full data:
#                                   entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q43393011   male                    Morocco         1999.0
# http://www.wikidata.org/entity/Q43393011   male Kingdom of the Netherlands         1999.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q441825
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q441825 female Kingdom of Italy         1942.0
# http://www.wikidata.org/entity/Q441825 female            Italy         1942.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q4458211
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q4458211   male       Russia         1935.0
# http://www.wikidata.org/entity/Q4458211   male Soviet Union         1935.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q459637
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q459637 female Kingdom of Italy         1931.0
# http://www.wikidata.org/entity/Q459637 female            Italy         1931.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q461111
# Number of occurrences: 3
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q461111   male           France         1922.0
# http://www.wikidata.org/entity/Q461111   male Kingdom of Italy         1922.0
# http://www.wikidata.org/entity/Q461111   male            Italy         1922.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q463032
# Number of occurrences: 4
#
# Full data:
#                                 entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q463032 female    Nazi Germany         1899.0
# http://www.wikidata.org/entity/Q463032 female         Germany         1899.0
# http://www.wikidata.org/entity/Q463032 female   German Empire         1899.0
# http://www.wikidata.org/entity/Q463032 female Weimar Republic         1899.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q466158
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q466158 female United Kingdom         1973.0
# http://www.wikidata.org/entity/Q466158 female        Ireland         1973.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q472623
# Number of occurrences: 2
#
# Full data:
#                                 entity gender         provenance  year_of_birth
# http://www.wikidata.org/entity/Q472623   male             Norway         1972.0
# http://www.wikidata.org/entity/Q472623   male Kingdom of Denmark         1972.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q4831145
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q4831145 female United States         1964.0
# http://www.wikidata.org/entity/Q4831145 female        Israel         1964.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q485788
# Number of occurrences: 2
#
# Full data:
#                                 entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q485788   male  Indonesia         1968.0
# http://www.wikidata.org/entity/Q485788   male  Indonesia         1959.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q488353
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# ...
# Number of occurrences: 2
#
# Full data:
#                                   entity gender  provenance  year_of_birth
# http://www.wikidata.org/entity/Q57911410   male South Korea         1990.0
# http://www.wikidata.org/entity/Q57911410   male   Australia         1990.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6150518
# Number of occurrences: 2
#
# Full data:
#                                  entity         gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q6150518    genderfluid United States            NaN
# http://www.wikidata.org/entity/Q6150518 transmasculine United States            NaN
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6231539
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q6231539   male  United States         1957.0
# http://www.wikidata.org/entity/Q6231539   male United Kingdom         1957.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6245337
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q6245337   male Blackfeet Nation         1881.0
# http://www.wikidata.org/entity/Q6245337   male    United States         1881.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6378533
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q6378533 female United Kingdom         1980.0
# http://www.wikidata.org/entity/Q6378533 female          Wales         1980.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q64397
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q64397 female       Germany         1942.0
# http://www.wikidata.org/entity/Q64397 female United States         1942.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6519573
# Number of occurrences: 2
#
# Full data:
#                                  entity      gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q6519573 trans woman United States         1976.0
# http://www.wikidata.org/entity/Q6519573  non-binary United States         1976.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q65932
# Number of occurrences: 2
#
# Full data:
#                                entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q65932   male  United States         1937.0
# http://www.wikidata.org/entity/Q65932   male United Kingdom         1937.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q66828953
# Number of occurrences: 2
#
# Full data:
#                                   entity      gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q66828953  non-binary United States         1996.0
# http://www.wikidata.org/entity/Q66828953 trans woman United States         1996.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6688620
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q6688620 female        NaN         1979.0
# http://www.wikidata.org/entity/Q6688620 female        NaN         1980.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6765070
# Number of occurrences: 2
#
# Full data:
#                                  entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q6765070 female United Kingdom of Great Britain and Ireland         1865.0
# http://www.wikidata.org/entity/Q6765070 female                              United Kingdom         1865.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6780551
# Number of occurrences: 2
#
# Full data:
#                                  entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q6780551 female United Kingdom of Great Britain and Ireland         1925.0
# http://www.wikidata.org/entity/Q6780551 female                              United Kingdom         1925.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6831012
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q6831012   male United States         1938.0
# http://www.wikidata.org/entity/Q6831012   male United States         1935.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q700136
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q700136   male              United States         1911.0
# http://www.wikidata.org/entity/Q700136   male Kingdom of the Netherlands         1911.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q703216
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q703216 female People's Republic of China         1975.0
# http://www.wikidata.org/entity/Q703216 female          British Hong Kong         1975.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q714709
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q714709   male                              United Kingdom         1860.0
# http://www.wikidata.org/entity/Q714709   male United Kingdom of Great Britain and Ireland         1860.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7169124
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q7169124 female   Paraguay         1952.0
# http://www.wikidata.org/entity/Q7169124 female     Brazil         1952.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q735221
# Number of occurrences: 2
#
# Full data:
#                                 entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q735221   male Kingdom of Italy         1929.0
# http://www.wikidata.org/entity/Q735221   male            Italy         1929.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7461818
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q7461818 female         Iran         1927.0
# http://www.wikidata.org/entity/Q7461818 female Pahlavi Iran         1927.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7492921
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q7492921   male       Iran         1964.0
# http://www.wikidata.org/entity/Q7492921   male  Australia         1964.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7652898
# Number of occurrences: 3
#
# Full data:
#                                  entity gender        provenance  year_of_birth
# http://www.wikidata.org/entity/Q7652898   male             India         1942.0
# http://www.wikidata.org/entity/Q7652898   male       British Raj         1942.0
# http://www.wikidata.org/entity/Q7652898   male Dominion of India         1942.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q77471
# Number of occurrences: 2
#
# Full data:
#                                entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q77471 female German Democratic Republic         1979.0
# http://www.wikidata.org/entity/Q77471 female                    Germany         1979.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q77652385
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q77652385   male         India         1992.0
# http://www.wikidata.org/entity/Q77652385   male United States         1992.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7847237
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q7847237 female United States         1935.0
# http://www.wikidata.org/entity/Q7847237 female United States         1939.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q78475
# Number of occurrences: 2
#
# Full data:
#                                entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q78475   male      Austria         1885.0
# http://www.wikidata.org/entity/Q78475   male Cisleithania         1885.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7996
# Number of occurrences: 2
#
# Full data:
#                               entity gender                   provenance  year_of_birth
# http://www.wikidata.org/entity/Q7996   male            Tsardom of Russia         1530.0
# http://www.wikidata.org/entity/Q7996   male Grand Principality of Moscow         1530.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q80424
# Number of occurrences: 2
#
# Full data:
#                                entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q80424 female   Portugal         1978.0
# http://www.wikidata.org/entity/Q80424 female     Canada         1978.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q81324
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q81324   male United States         1957.0
# http://www.wikidata.org/entity/Q81324   male        Canada         1957.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q83174
# Number of occurrences: 2
#
# Full data:
#                                entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q83174   male            Italy         1896.0
# http://www.wikidata.org/entity/Q83174   male Kingdom of Italy         1896.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q83484
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q83484   male        Mexico         1915.0
# http://www.wikidata.org/entity/Q83484   male United States         1915.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q8442
# Number of occurrences: 2
#
# Full data:
#                               entity gender         provenance  year_of_birth
# http://www.wikidata.org/entity/Q8442   male       German Reich         1815.0
# http://www.wikidata.org/entity/Q8442   male Kingdom of Prussia         1815.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q856707
# Number of occurrences: 2
#
# Full data:
#                                 entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q856707   male     France         1885.0
# http://www.wikidata.org/entity/Q856707   male    Hungary         1885.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q89624
# Number of occurrences: 4
#
# Full data:
#                                entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q89624   male         Poland         1846.0
# http://www.wikidata.org/entity/Q89624   male      Australia         1846.0
# http://www.wikidata.org/entity/Q89624   male Russian Empire         1846.0
# http://www.wikidata.org/entity/Q89624   male   German Reich         1846.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q91059
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q91059   male       Germany         1910.0
# http://www.wikidata.org/entity/Q91059   male United States         1910.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q944894
# Number of occurrences: 2
#
# Full data:
#                                 entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q944894   male Empire of Japan         1927.0
# http://www.wikidata.org/entity/Q944894   male           Japan         1927.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q95686111
# Number of occurrences: 2
#
# Full data:
#                                   entity     gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q95686111     female United Kingdom         1995.0
# http://www.wikidata.org/entity/Q95686111 non-binary United Kingdom         1995.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q95883837
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q95883837   male        Mexico         1933.0
# http://www.wikidata.org/entity/Q95883837   male United States         1933.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q972585
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q972585   male  United States         1937.0
# http://www.wikidata.org/entity/Q972585   male United Kingdom         1937.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q98819388
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q98819388 female           Iraq         1990.0
# http://www.wikidata.org/entity/Q98819388 female United Kingdom         1990.0
# --------------------------------------------------------------------------------

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('creativiID.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?creativePerson'] = tsv_df['?creativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Merge the dataframes on entity IDs
    # Using left join to keep all TSV rows
    merged_df = pd.merge(
        tsv_df,  # Keep all rows from TSV
        csv_df,
        left_on='?creativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?creativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'creativi_full_info_rep.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?creativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: creativi_full_info_rep.tsv
#
# Statistics:
# Original TSV rows: 4873
# Original CSV rows: 1634
# Final merged rows: 5579
# Rows with matched gender info: 5567
# Unique persons in result: 1443

# %% [markdown]
# OR: drop duplicates in the csv before merging, keeping only the first occurrence:
# csv_df_unique = csv_df.drop_duplicates(subset=['entity'], keep='first')

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('creativiID.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?creativePerson'] = tsv_df['?creativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Remove duplicates from CSV while keeping the first occurrence
    csv_df_unique = csv_df.drop_duplicates(subset=['entity'], keep='first')
    
    # Merge the dataframes on entity IDs
    merged_df = pd.merge(
        tsv_df,
        csv_df_unique,
        left_on='?creativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?creativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'creativi_full_info.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"CSV rows after removing duplicates: {len(csv_df_unique)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?creativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: creativi_full_info.tsv
#
# Statistics:
# Original TSV rows: 4873
# Original CSV rows: 1634
# CSV rows after removing duplicates: 1443
# Final merged rows: 4873
# Rows with matched gender info: 4861
# Unique persons in result: 1443

# %% [markdown]
# # Merge new info in non-creatives

# %%
import pandas as pd

def analyze_duplicates():
    # Read the CSV file
    df = pd.read_csv('wikidata_results_non_creatives.csv')
    
    # Find duplicated entities
    duplicated_entities = df[df.duplicated(subset=['entity'], keep=False)].sort_values('entity')
    
    print(f"Total number of rows with duplicates: {len(duplicated_entities)}")
    print(f"Number of unique entities with duplicates: {len(duplicated_entities['entity'].unique())}")
    print("\nDetailed view of duplicates:")
    print("=" * 80)
    
    # Group by entity and show differences
    for entity in duplicated_entities['entity'].unique():
        entity_rows = duplicated_entities[duplicated_entities['entity'] == entity]
        print(f"\nEntity: {entity}")
        print(f"Number of occurrences: {len(entity_rows)}")
        print("\nFull data:")
        print(entity_rows.to_string(index=False))
        print("-" * 80)

if __name__ == "__main__":
    analyze_duplicates()
# Out:
# Total number of rows with duplicates: 175
# Number of unique entities with duplicates: 81
#
# Detailed view of duplicates:
# ================================================================================
#
# Entity: http://www.wikidata.org/entity/Q106604688
# Number of occurrences: 2
#
# Full data:
#                                    entity      gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q106604688  non-binary    Ireland         2003.0
# http://www.wikidata.org/entity/Q106604688 transgender    Ireland         2003.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q109635621
# Number of occurrences: 2
#
# Full data:
#                                    entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q109635621 female              United States         1998.0
# http://www.wikidata.org/entity/Q109635621 female People's Republic of China         1998.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q110230490
# Number of occurrences: 2
#
# Full data:
#                                    entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q110230490 female     Canada            NaN
# http://www.wikidata.org/entity/Q110230490 female     France            NaN
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q112111793
# Number of occurrences: 2
#
# Full data:
#                                    entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q112111793   male        Mexico         1979.0
# http://www.wikidata.org/entity/Q112111793   male United States         1979.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q113388923
# Number of occurrences: 2
#
# Full data:
#                                    entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q113388923 female Czech Republic         2004.0
# http://www.wikidata.org/entity/Q113388923 female     Seychelles         2004.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q114615561
# Number of occurrences: 2
#
# Full data:
#                                    entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q114615561 female        NaN         1859.0
# http://www.wikidata.org/entity/Q114615561 female        NaN         1860.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q119983938
# Number of occurrences: 2
#
# Full data:
#                                    entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q119983938   male     France         1945.0
# http://www.wikidata.org/entity/Q119983938   male    Austria         1945.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q126188
# Number of occurrences: 2
#
# Full data:
#                                 entity gender          provenance  year_of_birth
# http://www.wikidata.org/entity/Q126188   male  Kingdom of England         1633.0
# http://www.wikidata.org/entity/Q126188   male Kingdom of Scotland         1633.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q126672
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q126672   male                              United Kingdom         1906.0
# http://www.wikidata.org/entity/Q126672   male United Kingdom of Great Britain and Ireland         1906.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1273532
# Number of occurrences: 2
#
# Full data:
#                                  entity gender  provenance  year_of_birth
# http://www.wikidata.org/entity/Q1273532   male       India         1909.0
# http://www.wikidata.org/entity/Q1273532   male British Raj         1909.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q130586
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q130586   male                    Kingdom of Great Britain         1762.0
# http://www.wikidata.org/entity/Q130586   male United Kingdom of Great Britain and Ireland         1762.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1385826
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q1385826   male            Italy         1930.0
# http://www.wikidata.org/entity/Q1385826   male Kingdom of Italy         1930.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1423692
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q1423692   male Nazi Germany         1897.0
# http://www.wikidata.org/entity/Q1423692   male German Reich         1897.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q154912
# Number of occurrences: 2
#
# Full data:
#                                 entity gender         provenance  year_of_birth
# http://www.wikidata.org/entity/Q154912   male Kingdom of Denmark         1903.0
# http://www.wikidata.org/entity/Q154912   male             Norway         1903.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q16345551
# Number of occurrences: 3
#
# Full data:
#                                   entity gender        provenance  year_of_birth
# http://www.wikidata.org/entity/Q16345551   male             India         1946.0
# http://www.wikidata.org/entity/Q16345551   male       British Raj         1946.0
# http://www.wikidata.org/entity/Q16345551   male Dominion of India         1946.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q17174943
# Number of occurrences: 2
#
# Full data:
#                                   entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q17174943   male Pahlavi Iran         1928.0
# http://www.wikidata.org/entity/Q17174943   male         Iran         1928.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1791549
# Number of occurrences: 3
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q1791549   male        Brazil         1959.0
# http://www.wikidata.org/entity/Q1791549   male United States         1959.0
# http://www.wikidata.org/entity/Q1791549   male        Cyprus         1959.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1934042
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q1934042   male United States         1983.0
# http://www.wikidata.org/entity/Q1934042   male      Thailand         1983.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q193901
# Number of occurrences: 2
#
# Full data:
#                                 entity gender        provenance  year_of_birth
# http://www.wikidata.org/entity/Q193901   male  County of Sicily         1095.0
# http://www.wikidata.org/entity/Q193901   male Kingdom of Sicily         1095.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1981992
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q1981992   male Soviet Union         1940.0
# http://www.wikidata.org/entity/Q1981992   male       Canada         1940.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q20974136
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q20974136 female United States         1964.0
# http://www.wikidata.org/entity/Q20974136 female       Austria         1964.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q22976220
# Number of occurrences: 2
#
# Full data:
#                                   entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q22976220   male            Italy         1912.0
# http://www.wikidata.org/entity/Q22976220   male Kingdom of Italy         1912.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q23782666
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q23782666 female United States            NaN
# http://www.wikidata.org/entity/Q23782666 female        France            NaN
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q24010576
# Number of occurrences: 2
#
# Full data:
#                                   entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q24010576   male Soviet Union         1957.0
# http://www.wikidata.org/entity/Q24010576   male       Russia         1957.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q25720
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q25720   male United States         1973.0
# http://www.wikidata.org/entity/Q25720   male      Thailand         1973.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q25831414
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q25831414 female United States         1979.0
# http://www.wikidata.org/entity/Q25831414 female        France         1979.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2628647
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q2628647   male     France         1946.0
# http://www.wikidata.org/entity/Q2628647   male  Argentina         1946.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2640102
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q2640102   male Soviet Union         1959.0
# http://www.wikidata.org/entity/Q2640102   male       Russia         1959.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q264849
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q264849 female       Jamaica         1956.0
# http://www.wikidata.org/entity/Q264849 female United States         1956.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q26878341
# Number of occurrences: 2
#
# Full data:
#                                   entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q26878341   male Soviet Union         1982.0
# http://www.wikidata.org/entity/Q26878341   male       Russia         1982.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q273698
# Number of occurrences: 3
#
# Full data:
#                                 entity          gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q273698      non-binary United States         1962.0
# http://www.wikidata.org/entity/Q273698        neutrois United States         1962.0
# http://www.wikidata.org/entity/Q273698 intersex person United States         1962.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q27966300
# Number of occurrences: 2
#
# Full data:
#                                   entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q27966300   male Empire of Japan         1929.0
# http://www.wikidata.org/entity/Q27966300   male           Japan         1929.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q280856
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q280856   male United Kingdom of Great Britain and Ireland         1895.0
# http://www.wikidata.org/entity/Q280856   male                              United Kingdom         1895.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2825786
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q2825786   male    Belgium         1946.0
# http://www.wikidata.org/entity/Q2825786   male     France         1946.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q284784
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q284784   male        Ireland         1989.0
# http://www.wikidata.org/entity/Q284784   male United Kingdom         1989.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q294365
# Number of occurrences: 3
#
# Full data:
#                                 entity gender             provenance  year_of_birth
# http://www.wikidata.org/entity/Q294365   male Emirate of Transjordan         1909.0
# http://www.wikidata.org/entity/Q294365   male         Ottoman Empire         1909.0
# http://www.wikidata.org/entity/Q294365   male                 Jordan         1909.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q2992264
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q2992264   male      Ukraine         1952.0
# http://www.wikidata.org/entity/Q2992264   male Soviet Union         1952.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q317521
# Number of occurrences: 3
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q317521   male United States         1971.0
# http://www.wikidata.org/entity/Q317521   male        Canada         1971.0
# http://www.wikidata.org/entity/Q317521   male  South Africa         1971.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3617759
# Number of occurrences: 2
#
# Full data:
#                                  entity gender       provenance  year_of_birth
# http://www.wikidata.org/entity/Q3617759 female            Italy         1936.0
# http://www.wikidata.org/entity/Q3617759 female Kingdom of Italy         1936.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q368441
# Number of occurrences: 2
#
# Full data:
#                                 entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q368441   male      Spain         1991.0
# http://www.wikidata.org/entity/Q368441   male   Colombia         1991.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q378470
# Number of occurrences: 2
#
# Full data:
#                                 entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q378470   male    Cao Wei          205.0
# http://www.wikidata.org/entity/Q378470   male      China          205.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q3801341
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q3801341   male      Lithuania         1856.0
# http://www.wikidata.org/entity/Q3801341   male Russian Empire         1856.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q38575095
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q38575095 female United Kingdom         1923.0
# http://www.wikidata.org/entity/Q38575095 female      Australia         1923.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q436039
# Number of occurrences: 2
#
# Full data:
#                                 entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q436039   male United Kingdom of Great Britain and Ireland         1793.0
# http://www.wikidata.org/entity/Q436039   male                                     England         1793.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q44496
# Number of occurrences: 2
#
# Full data:
#                                entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q44496   male       Russia         1936.0
# http://www.wikidata.org/entity/Q44496   male Soviet Union         1936.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q4491326
# Number of occurrences: 2
#
# Full data:
#                                  entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q4491326   male Soviet Union         1935.0
# http://www.wikidata.org/entity/Q4491326   male       Russia         1935.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q452772
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q452772   male United States         1937.0
# http://www.wikidata.org/entity/Q452772   male        Canada         1937.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q4718824
# Number of occurrences: 2
#
# Full data:
#                                  entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q4718824   male        Hungary         1983.0
# http://www.wikidata.org/entity/Q4718824   male United Kingdom         1983.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q48953598
# Number of occurrences: 2
#
# Full data:
#                                   entity gender   provenance  year_of_birth
# http://www.wikidata.org/entity/Q48953598   male Soviet Union         1987.0
# http://www.wikidata.org/entity/Q48953598   male       Russia         1987.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q50825604
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q50825604   male        Israel         1989.0
# http://www.wikidata.org/entity/Q50825604   male United States         1989.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q5174247
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q5174247   male United States         1922.0
# http://www.wikidata.org/entity/Q5174247   male United States         1923.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q543755
# Number of occurrences: 2
#
# Full data:
#                                 entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q543755 female     Sweden         1955.0
# http://www.wikidata.org/entity/Q543755 female  Australia         1955.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q550368
# Number of occurrences: 2
#
# Full data:
#                                 entity gender  provenance  year_of_birth
# http://www.wikidata.org/entity/Q550368   male     Cao Wei          197.0
# http://www.wikidata.org/entity/Q550368   male Eastern Han          197.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q55859084
# Number of occurrences: 2
#
# Full data:
#                                   entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q55859084   male        NaN         1897.0
# http://www.wikidata.org/entity/Q55859084   male        NaN         1898.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q5670803
# Number of occurrences: 2
#
# Full data:
#                                  entity gender  provenance  year_of_birth
# http://www.wikidata.org/entity/Q5670803   male   Australia         1934.0
# http://www.wikidata.org/entity/Q5670803   male New Zealand         1934.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q57536
# Number of occurrences: 3
#
# Full data:
#                                entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q57536 female                    Kingdom of Great Britain         1766.0
# http://www.wikidata.org/entity/Q57536 female United Kingdom of Great Britain and Ireland         1766.0
# http://www.wikidata.org/entity/Q57536 female                      Kingdom of Württemberg         1766.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q57959
# Number of occurrences: 2
#
# Full data:
#                                entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q57959   male                    Germany         1973.0
# http://www.wikidata.org/entity/Q57959   male German Democratic Republic         1973.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q58869572
# Number of occurrences: 3
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q58869572   male       Slovakia         1983.0
# http://www.wikidata.org/entity/Q58869572   male Czechoslovakia         1983.0
# http://www.wikidata.org/entity/Q58869572   male    Switzerland         1983.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6112478
# Number of occurrences: 2
#
# Full data:
#                                  entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q6112478 female United Kingdom of Great Britain and Ireland         1859.0
# http://www.wikidata.org/entity/Q6112478 female United Kingdom of Great Britain and Ireland         1858.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q61710920
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q61710920   male         France         1956.0
# http://www.wikidata.org/entity/Q61710920   male United Kingdom         1956.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q6376534
# Number of occurrences: 2
#
# Full data:
#                                  entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q6376534 female United Kingdom of Great Britain and Ireland         1866.0
# http://www.wikidata.org/entity/Q6376534 female                              United Kingdom         1866.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q63929108
# Number of occurrences: 2
#
# Full data:
#                                   entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q63929108 female         Canada         1975.0
# http://www.wikidata.org/entity/Q63929108 female United Kingdom         1975.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q63973123
# Number of occurrences: 2
#
# Full data:
#                                   entity gender         provenance  year_of_birth
# http://www.wikidata.org/entity/Q63973123 female      United States         1815.0
# http://www.wikidata.org/entity/Q63973123 female Kingdom of Prussia         1815.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q68949
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q68949   male       Germany         1863.0
# http://www.wikidata.org/entity/Q68949   male United States         1863.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q69916868
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q69916868 female Guinea-Bissau         1982.0
# http://www.wikidata.org/entity/Q69916868 female      Portugal         1982.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q706548
# Number of occurrences: 2
#
# Full data:
#                                 entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q706548   male United States         1941.0
# http://www.wikidata.org/entity/Q706548   male        Canada         1941.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q713358
# Number of occurrences: 2
#
# Full data:
#                                 entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q713358   male United Kingdom         1929.0
# http://www.wikidata.org/entity/Q713358   male   South Africa         1929.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7154695
# Number of occurrences: 2
#
# Full data:
#                                  entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q7154695 female        NaN         1961.0
# http://www.wikidata.org/entity/Q7154695 female        NaN         1958.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q717983
# Number of occurrences: 2
#
# Full data:
#                                 entity gender        provenance  year_of_birth
# http://www.wikidata.org/entity/Q717983   male     United States         1960.0
# http://www.wikidata.org/entity/Q717983   male British Hong Kong         1960.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q73503445
# Number of occurrences: 2
#
# Full data:
#                                   entity gender                 provenance  year_of_birth
# http://www.wikidata.org/entity/Q73503445   male                    Belgium         1941.0
# http://www.wikidata.org/entity/Q73503445   male Kingdom of the Netherlands         1941.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7416
# Number of occurrences: 2
#
# Full data:
#                               entity gender                                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q7416 female                              United Kingdom         1925.0
# http://www.wikidata.org/entity/Q7416 female United Kingdom of Great Britain and Ireland         1925.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q7520267
# Number of occurrences: 2
#
# Full data:
#                                  entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q7520267 female United States         1997.0
# http://www.wikidata.org/entity/Q7520267 female        Belize         1997.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q76420
# Number of occurrences: 2
#
# Full data:
#                                entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q76420   male German Empire         1845.0
# http://www.wikidata.org/entity/Q76420   male  German Reich         1845.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q8479
# Number of occurrences: 2
#
# Full data:
#                               entity gender        provenance  year_of_birth
# http://www.wikidata.org/entity/Q8479   male    Russian Empire         1672.0
# http://www.wikidata.org/entity/Q8479   male Tsardom of Russia         1672.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q91212598
# Number of occurrences: 2
#
# Full data:
#                                   entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q91212598 female     Canada         1951.0
# http://www.wikidata.org/entity/Q91212598 female     Canada         1960.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q935
# Number of occurrences: 2
#
# Full data:
#                              entity gender               provenance  year_of_birth
# http://www.wikidata.org/entity/Q935   male Kingdom of Great Britain         1643.0
# http://www.wikidata.org/entity/Q935   male       Kingdom of England         1643.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q937
# Number of occurrences: 7
#
# Full data:
#                              entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q937   male Weimar Republic         1879.0
# http://www.wikidata.org/entity/Q937   male   United States         1879.0
# http://www.wikidata.org/entity/Q937   male    Cisleithania         1879.0
# http://www.wikidata.org/entity/Q937   male         Germany         1879.0
# http://www.wikidata.org/entity/Q937   male     Switzerland         1879.0
# http://www.wikidata.org/entity/Q937   male   statelessness         1879.0
# http://www.wikidata.org/entity/Q937   male   German Empire         1879.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q9391
# Number of occurrences: 2
#
# Full data:
#                               entity gender     provenance  year_of_birth
# http://www.wikidata.org/entity/Q9391   male        Austria         1889.0
# http://www.wikidata.org/entity/Q9391   male United Kingdom         1889.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q9455382
# Number of occurrences: 3
#
# Full data:
#                                  entity gender                  provenance  year_of_birth
# http://www.wikidata.org/entity/Q9455382   male  People's Republic of China         1996.0
# http://www.wikidata.org/entity/Q9455382   male           British Hong Kong         1996.0
# http://www.wikidata.org/entity/Q9455382   male British National (Overseas)         1996.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q94713622
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q94713622 female United States         1961.0
# http://www.wikidata.org/entity/Q94713622 female       Nigeria         1961.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q95190573
# Number of occurrences: 2
#
# Full data:
#                                   entity gender    provenance  year_of_birth
# http://www.wikidata.org/entity/Q95190573   male      Colombia         1949.0
# http://www.wikidata.org/entity/Q95190573   male United States         1949.0
# --------------------------------------------------------------------------------

# %%
import pandas as pd

# Read the files
tsv_data = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
csv_data = pd.read_csv('wikidata_results_non_creatives.csv')

# Strip <> from creativePerson in TSV and entity in CSV
tsv_data['?nonCreativePerson'] = tsv_data['?nonCreativePerson'].str.replace('<', '').str.replace('>', '')
csv_data['entity'] = csv_data['entity'].str.replace('<', '').str.replace('>', '')

# Merge files based on creativePerson and entity
merged_data = pd.merge(
    tsv_data, 
    csv_data,
    left_on='?nonCreativePerson',
    right_on='entity',
    how='left'
)

# Save as TSV
merged_data.to_csv('merged_results_non_creatives.tsv', sep='\t', index=False)

print("Files merged successfully!")
print(f"Found {len(merged_data)} rows in merged file")
# Out:
# Files merged successfully!
# Found 2316 rows in merged file

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results_non_creatives.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?nonCreativePerson'] = tsv_df['?nonCreativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Merge the dataframes on entity IDs
    # Using left join to keep all TSV rows
    merged_df = pd.merge(
        tsv_df,  # Keep all rows from TSV
        csv_df,
        left_on='?nonCreativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?nonCreativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'non_creativi_full_info_rep.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?nonCreativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: non_creativi_full_info_rep.tsv
#
# Statistics:
# Original TSV rows: 2088
# Original CSV rows: 917
# Final merged rows: 2316
# Rows with matched gender info: 2314
# Unique persons in result: 823

# %% [markdown]
# Drop duplicates in the CSV before merging.

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results_non_creatives.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?nonCreativePerson'] = tsv_df['?nonCreativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Remove duplicates from CSV while keeping the first occurrence
    csv_df_unique = csv_df.drop_duplicates(subset=['entity'], keep='first')
    
    # Merge the dataframes on entity IDs
    merged_df = pd.merge(
        tsv_df,
        csv_df_unique,
        left_on='?nonCreativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?nonCreativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'non_creativi_full_info.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"CSV rows after removing duplicates: {len(csv_df_unique)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?nonCreativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: non_creativi_full_info.tsv
#
# Statistics:
# Original TSV rows: 2088
# Original CSV rows: 917
# CSV rows after removing duplicates: 823
# Final merged rows: 2088
# Rows with matched gender info: 2086
# Unique persons in result: 823

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# TOTAL PEOPLE WIKIDATA:
