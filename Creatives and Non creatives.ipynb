# %% [markdown]
# # Total number of people with disturbs

# %%
SELECT  (COUNT (DISTINCT ?person) as ?peopleCount) 
WHERE { 
  # ?person wdt:P31 wd:Q5. 
  # ?person wdt:P1050 ?disorder.
  # ?disorder wdt:P279+ wd:Q12135.
}

# %% [markdown]
# Result is 2,387

# %% [markdown]
# # Total number of people with disturbs for which an occupation is specified

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT  (COUNT (DISTINCT ?person) as ?peopleCount) 
WHERE { 
  # ?person wdt:P31 wd:Q5. 
  # ?person wdt:P106 ?occupation.
  # ?person wdt:P1050 ?disorder.
  # ?disorder wdt:P279+ wd:Q12135.
}

# %% [markdown]
# Result is 2,268

# %% [markdown]
# # Creatives with disturbs

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?creativePerson ?occupationLabel ?disorderLabel 
WHERE {
  # ?creativePerson wdt:P31 wd:Q5.
  # ?creativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.
  # ?occupation wdt:P279* ?creativeOccupation.
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
  # ?creativePerson wdt:P1050 ?disorder.
   # ?disorder wdt:P279+ wd:Q12135.
   # ?disorder rdfs:label ?disorderLabel.
   FILTER (lang(?disorderLabel) = "en")
   FILTER (LANG(?occupationLabel) = "en") .
}

# %% [markdown]
# Results in 'creativiID.tsv'

# %%
from collections import Counter
import csv

def analyze_creative_persons(tsv_file_path):
    # Initialize Counter
    creative_person_counts = Counter()
    total_rows = 0
    
    # Read TSV file
    with open(tsv_file_path, 'r', encoding='utf-8') as file:
        # Create TSV reader
        tsv_reader = csv.DictReader(file, delimiter='\t')
        
        # Count each creative person occurrence and total rows
        for row in tsv_reader:
            creative_person = row['?creativePerson']
            creative_person_counts[creative_person] += 1
            total_rows += 1
    
    # Get total unique IDs
    total_unique = len(creative_person_counts)
    
    # Count how many IDs appear multiple times
    repeated_ids = sum(1 for count in creative_person_counts.values() if count > 1)
    
    return total_rows, total_unique, repeated_ids

# Example usage
if __name__ == "__main__":
    file_path = "creativiID.tsv"  
    total_rows, total_unique, repeated = analyze_creative_persons(file_path)
    
    print(f"Total number of rows: {total_rows}")
    print(f"Total number of unique creative persons: {total_unique}")
    print(f"Number of creative persons that appear multiple times: {repeated}")
# Out:
# Total number of rows: 5073
# Total number of unique creative persons: 1490
# Number of creative persons that appear multiple times: 1041

# %% [markdown]
# # Non creativi

# %% [markdown]
# Prima query: esclude le classi e sottoclassi di creativi

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?occupationLabel ?disorderLabel 
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.
  # Exclude creative professions and their subclasses
  
    MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
    }
   # ?nonCreativePerson wdt:P1050 ?disorder.
   # ?disorder wdt:P279+ wd:Q12135.
   # ?disorder rdfs:label ?disorderLabel.
   FILTER (lang(?disorderLabel) = "en")
   FILTER (LANG(?occupationLabel) = "en") .
}

# %% [markdown]
# Risultato: nonCreativiID1.tsv

# %% [markdown]
# ## Seconda query: include le sottoclassi di mestieri creativi escluse nelle ricerche sui creativi

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?occupationLabel ?disorderLabel 
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
  # ?nonCreativePerson wdt:P1050 ?disorder.
   # ?disorder wdt:P279+ wd:Q12135.
   # ?disorder rdfs:label ?disorderLabel.
   FILTER (lang(?disorderLabel) = "en")
   FILTER (LANG(?occupationLabel) = "en") .
}

# %% [markdown]
# Risultato: 'nonCreativiID2.tsv'

# %% [markdown]
# ## A code to merge the two non-creatives files and delete people identified as creative

# %% [markdown]
# The code:
# - First merges both non-creative files into one
# - Then checks for any IDs that appear in both the *merged non-creative file* and the *creatives file*
# - Removes any rows from the merged non-creative file where the ID appears in the creatives file
# - Save the result to a new file

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'merged_cleaned_noncreative.tsv') -> None:
    """
    Merge non-creative files and remove duplicates that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')
        
        # Step 1: Merge non-creative files
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        print(f"\nInitial merge:")
        print(f"- Rows from first non-creative file: {len(noncreative_df1)}")
        print(f"- Rows from second non-creative file: {len(noncreative_df2)}")
        print(f"- Total rows after merge: {len(merged_df)}")
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Find duplicate IDs
        duplicate_ids = set(merged_df['?nonCreativePerson']).intersection(creative_ids)
        
        # Remove rows with duplicate IDs from merged file
        cleaned_df = merged_df[~merged_df['?nonCreativePerson'].isin(duplicate_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print summary
        print(f"\nDuplicate removal:")
        print(f"- Found {len(duplicate_ids)} IDs that appear in both creative and non-creative files")
        '''if duplicate_ids:
            print("\nDuplicate IDs removed:")
            for id in sorted(duplicate_ids):
                print(f"- {id}")'''
        
        print(f"\nFinal results:")
        print(f"- Original total rows: {len(merged_df)}")
        print(f"- Rows after removing duplicates: {len(cleaned_df)}")
        print(f"- Rows removed: {len(merged_df) - len(cleaned_df)}")
        print(f"- Output saved to: {output_file}")
        
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativiID.tsv'
        noncreative_file1 = 'nonCreativiID1.tsv'
        noncreative_file2 = 'nonCreativiID2.tsv'
        output_file = 'merged_cleaned_noncreative.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Initial merge:
# - Rows from first non-creative file: 2388
# - Rows from second non-creative file: 1958
# - Total rows after merge: 4346
#
# Duplicate removal:
# - Found 786 IDs that appear in both creative and non-creative files
#
# Final results:
# - Original total rows: 4346
# - Rows after removing duplicates: 1869
# - Rows removed: 2477
# - Output saved to: merged_cleaned_noncreative.tsv

# %%
from collections import Counter
import csv

def analyze_creative_persons(tsv_file_path):
    # Initialize Counter
    creative_person_counts = Counter()
    total_rows = 0
    
    # Read TSV file
    with open(tsv_file_path, 'r', encoding='utf-8') as file:
        # Create TSV reader
        tsv_reader = csv.DictReader(file, delimiter='\t')
        
        # Count each creative person occurrence and total rows
        for row in tsv_reader:
            creative_person = row['?nonCreativePerson']
            creative_person_counts[creative_person] += 1
            total_rows += 1
    
    # Get total unique IDs
    total_unique = len(creative_person_counts)
    
    # Count how many IDs appear multiple times
    repeated_ids = sum(1 for count in creative_person_counts.values() if count > 1)
    
    return total_rows, total_unique, repeated_ids

# Example usage
if __name__ == "__main__":
    file_path = "merged_cleaned_noncreative.tsv" 
    total_rows, total_unique, repeated = analyze_creative_persons(file_path)
    
    print(f"Total number of rows: {total_rows}")
    print(f"Total number of unique non-creative persons: {total_unique}")
    print(f"Number of non-creative persons that appear multiple times: {repeated}")
# Out:
# Total number of rows: 1869
# Total number of unique non-creative persons: 776
# Number of non-creative persons that appear multiple times: 526

# %% [markdown]
# Total of creatives with disturbs (1490) and non-creatives with disturbs (776) sums up to 2266. The missing people do not have an occupation specified.

# %% [markdown]
# # Ask for creatives' gender, provenance, year of birth via a remote query

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from tqdm import tqdm
import time
import re

def extract_wikidata_id(uri):
    """Extract Q-identifier from full Wikidata URI"""
    match = re.search(r'Q\d+', uri)
    return match.group(0) if match else None

def chunk_list(lst, chunk_size):
    """Split list into chunks of specified size"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def create_query(wikidata_ids):
    """Create SPARQL query for multiple entities with optional properties"""
    # Create VALUES clause with wd: prefix for each Q-ID
    entities = ' '.join(f'(wd:{id_})' for id_ in wikidata_ids)
    
    query = f"""
    SELECT DISTINCT ?entity ?genderLabel ?provenanceLabel ?yearOfBirth
    WHERE {{
        VALUES (?entity) {{ {entities} }}
        
        OPTIONAL {{
            # ?entity wdt:P21 ?gender.
            # ?gender rdfs:label ?genderLabel.
            FILTER(LANG(?genderLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P27 ?provenance.
            # ?provenance rdfs:label ?provenanceLabel.
            FILTER(LANG(?provenanceLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P569 ?dateOfBirth.
            BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
        }}
    }}
    """
    return query

def query_wikidata(sparql, ids):
    """Query Wikidata and return results"""
    query = create_query(ids)
    sparql.setQuery(query)
    
    try:
        results = sparql.query().convert()
        return results['results']['bindings']
    except Exception as e:
        print(f"Error querying Wikidata: {e}")
        return []

def process_results(results):
    """Process SPARQL results into a list of dictionaries"""
    processed = []
    for result in results:
        processed.append({
            'entity': result['entity']['value'],
            'gender': result.get('genderLabel', {}).get('value', None),
            'provenance': result.get('provenanceLabel', {}).get('value', None),
            'year_of_birth': result.get('yearOfBirth', {}).get('value', None)
        })
    return processed

def main():
    # Initialize SPARQL endpoint
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader('User-Agent', 'MyWikidataBot/1.0')
    
    # Read TSV file - replace 'your_file.tsv' with actual filename
    # and 'wikidata_column' with the actual column name containing Wikidata IDs
    df = pd.read_csv('creativiID.tsv', sep='\t')
    
    # Extract unique Wikidata IDs and clean them
    wikidata_uris = df['?creativePerson'].unique()
    wikidata_ids = [extract_wikidata_id(uri) for uri in wikidata_uris if pd.notna(uri)]
    wikidata_ids = [id_ for id_ in wikidata_ids if id_ is not None]
    
    print(f"Found {len(wikidata_ids)} unique Wikidata IDs")
    
    # Process in chunks of 50 entities
    CHUNK_SIZE = 50
    chunks = chunk_list(wikidata_ids, CHUNK_SIZE)
    
    all_results = []
    
    # Process each chunk with progress bar
    for chunk in tqdm(chunks, desc="Processing Wikidata entities"):
        results = query_wikidata(sparql, chunk)
        processed_results = process_results(results)
        all_results.extend(processed_results)
        
        # Add delay to avoid hitting rate limits
        time.sleep(1)
    
    # Convert results to DataFrame and save
    results_df = pd.DataFrame(all_results)
    results_df.to_csv('wikidata_results.csv', index=False)
    print(f"Processed {len(all_results)} entities. Results saved to wikidata_results.csv")

if __name__ == "__main__":
    main()
# Out:
# Found 1490 unique Wikidata IDs
# Processing Wikidata entities: 100%|████████████████████████████████████████████████████| 30/30 [00:58<00:00,  1.95s/it]
# Processed 1682 entities. Results saved to wikidata_results.csv

# %% [markdown]
# # Ask for non-creatives' gender, provenance, year of birth via a remote query

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from tqdm import tqdm
import time
import re

def extract_wikidata_id(uri):
    """Extract Q-identifier from full Wikidata URI"""
    match = re.search(r'Q\d+', uri)
    return match.group(0) if match else None

def chunk_list(lst, chunk_size):
    """Split list into chunks of specified size"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def create_query(wikidata_ids):
    """Create SPARQL query for multiple entities with optional properties"""
    # Create VALUES clause with wd: prefix for each Q-ID
    entities = ' '.join(f'(wd:{id_})' for id_ in wikidata_ids)
    
    query = f"""
    SELECT DISTINCT ?entity ?genderLabel ?provenanceLabel ?yearOfBirth
    WHERE {{
        VALUES (?entity) {{ {entities} }}
        
        OPTIONAL {{
            # ?entity wdt:P21 ?gender.
            # ?gender rdfs:label ?genderLabel.
            FILTER(LANG(?genderLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P27 ?provenance.
            # ?provenance rdfs:label ?provenanceLabel.
            FILTER(LANG(?provenanceLabel) = "en")
        }}
        
        OPTIONAL {{
            # ?entity wdt:P569 ?dateOfBirth.
            BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
        }}
    }}
    """
    return query

def query_wikidata(sparql, ids):
    """Query Wikidata and return results"""
    query = create_query(ids)
    sparql.setQuery(query)
    
    try:
        results = sparql.query().convert()
        return results['results']['bindings']
    except Exception as e:
        print(f"Error querying Wikidata: {e}")
        return []

def process_results(results):
    """Process SPARQL results into a list of dictionaries"""
    processed = []
    for result in results:
        processed.append({
            'entity': result['entity']['value'],
            'gender': result.get('genderLabel', {}).get('value', None),
            'provenance': result.get('provenanceLabel', {}).get('value', None),
            'year_of_birth': result.get('yearOfBirth', {}).get('value', None)
        })
    return processed

def main():
    # Initialize SPARQL endpoint
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader('User-Agent', 'MyWikidataBot/1.0')
    
    # Read TSV file - replace 'your_file.tsv' with actual filename
    # and 'wikidata_column' with the actual column name containing Wikidata IDs
    df = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
    
    # Extract unique Wikidata IDs and clean them
    wikidata_uris = df['?nonCreativePerson'].unique()
    wikidata_ids = [extract_wikidata_id(uri) for uri in wikidata_uris if pd.notna(uri)]
    wikidata_ids = [id_ for id_ in wikidata_ids if id_ is not None]
    
    print(f"Found {len(wikidata_ids)} unique Wikidata IDs")
    
    # Process in chunks of 50 entities
    CHUNK_SIZE = 50
    chunks = chunk_list(wikidata_ids, CHUNK_SIZE)
    
    all_results = []
    
    # Process each chunk with progress bar
    for chunk in tqdm(chunks, desc="Processing Wikidata entities"):
        results = query_wikidata(sparql, chunk)
        processed_results = process_results(results)
        all_results.extend(processed_results)
        
        # Add delay to avoid hitting rate limits
        time.sleep(1)
    
    # Convert results to DataFrame and save
    results_df = pd.DataFrame(all_results)
    results_df.to_csv('wikidata_results_non_creatives.csv', index=False)
    print(f"Processed {len(all_results)} entities. Results saved to wikidata_results.csv")

if __name__ == "__main__":
    main()
# Out:
# Found 776 unique Wikidata IDs
# Processing Wikidata entities: 100%|████████████████████████████████████████████████████| 16/16 [00:29<00:00,  1.86s/it]
# Processed 869 entities. Results saved to wikidata_results.csv

# %% [markdown]
# # Merge new info in creatives' dataset

# %% [markdown]
# First note: in the csv, we have duplicates for people with multiple nationality or gender info. We keep it for now.

# %%
import pandas as pd

def analyze_duplicates():
    # Read the CSV file
    df = pd.read_csv('wikidata_results.csv')
    
    # Find duplicated entities
    duplicated_entities = df[df.duplicated(subset=['entity'], keep=False)].sort_values('entity')
    
    print(f"Total number of rows with duplicates: {len(duplicated_entities)}")
    print(f"Number of unique entities with duplicates: {len(duplicated_entities['entity'].unique())}")
    print("\nDetailed view of first 3 duplicates:")
    print("=" * 80)
    
    # Group by entity and show differences for first 3 only
    for entity in duplicated_entities['entity'].unique()[:3]:  # Added [:3] here
        entity_rows = duplicated_entities[duplicated_entities['entity'] == entity]
        print(f"\nEntity: {entity}")
        print(f"Number of occurrences: {len(entity_rows)}")
        print("\nFull data:")
        print(entity_rows.to_string(index=False))
        print("-" * 80)

if __name__ == "__main__":
    analyze_duplicates()
# Out:
# Total number of rows with duplicates: 358
# Number of unique entities with duplicates: 166
#
# Detailed view of first 3 duplicates:
# ...
#
# Entity: http://www.wikidata.org/entity/Q1040834
# Number of occurrences: 2
#
# Full data:
#                                  entity gender      provenance  year_of_birth
# http://www.wikidata.org/entity/Q1040834   male   German Empire         1831.0
# http://www.wikidata.org/entity/Q1040834   male Austria-Hungary         1831.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q1064
# Number of occurrences: 3
#
# Full data:
#                               entity gender          provenance  year_of_birth
# http://www.wikidata.org/entity/Q1064   male Kingdom of Sardinia         1785.0
# http://www.wikidata.org/entity/Q1064   male      Duchy of Milan         1785.0
# http://www.wikidata.org/entity/Q1064   male    Kingdom of Italy         1785.0
# ...

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('creativiID.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?creativePerson'] = tsv_df['?creativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Merge the dataframes on entity IDs
    # Using left join to keep all TSV rows
    merged_df = pd.merge(
        tsv_df,  # Keep all rows from TSV
        csv_df,
        left_on='?creativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?creativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'creativi_full_info_rep.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?creativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: creativi_full_info_rep.tsv
#
# Statistics:
# Original TSV rows: 5073
# Original CSV rows: 1682
# Final merged rows: 5792
# Rows with matched gender info: 5780
# Unique persons in result: 1490

# %% [markdown]
# OR: drop duplicates in the csv before merging, keeping only the first occurrence:
# csv_df_unique = csv_df.drop_duplicates(subset=['entity'], keep='first')

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('creativiID.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?creativePerson'] = tsv_df['?creativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Remove duplicates from CSV while keeping the first occurrence
    csv_df_unique = csv_df.drop_duplicates(subset=['entity'], keep='first')
    
    # Merge the dataframes on entity IDs
    merged_df = pd.merge(
        tsv_df,
        csv_df_unique,
        left_on='?creativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?creativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'creativi_full_info.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"CSV rows after removing duplicates: {len(csv_df_unique)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?creativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: creativi_full_info.tsv
#
# Statistics:
# Original TSV rows: 5073
# Original CSV rows: 1682
# CSV rows after removing duplicates: 1490
# Final merged rows: 5073
# Rows with matched gender info: 5061
# Unique persons in result: 1490

# %% [markdown]
# # Merge new info in non-creatives

# %%
import pandas as pd

def analyze_duplicates():
    # Read the CSV file
    df = pd.read_csv('wikidata_results_non_creatives.csv')
    
    # Find duplicated entities
    duplicated_entities = df[df.duplicated(subset=['entity'], keep=False)].sort_values('entity')
    
    print(f"Total number of rows with duplicates: {len(duplicated_entities)}")
    print(f"Number of unique entities with duplicates: {len(duplicated_entities['entity'].unique())}")
    print("\nDetailed view of first 3 duplicates:")
    print("=" * 80)
    
    # Group by entity and show differences for first 3 only
    for entity in duplicated_entities['entity'].unique()[:3]:  # Added [:3] here
        entity_rows = duplicated_entities[duplicated_entities['entity'] == entity]
        print(f"\nEntity: {entity}")
        print(f"Number of occurrences: {len(entity_rows)}")
        print("\nFull data:")
        print(entity_rows.to_string(index=False))
        print("-" * 80)

if __name__ == "__main__":
    analyze_duplicates()
# Out:
# Total number of rows with duplicates: 173
# Number of unique entities with duplicates: 80
#
# Detailed view of first 3 duplicates:
# ...
#
# Entity: http://www.wikidata.org/entity/Q106604688
# Number of occurrences: 2
#
# Full data:
#                                    entity      gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q106604688 transgender    Ireland         2003.0
# http://www.wikidata.org/entity/Q106604688  non-binary    Ireland         2003.0
# --------------------------------------------------------------------------------
#
# Entity: http://www.wikidata.org/entity/Q110230490
# Number of occurrences: 2
#
# Full data:
#                                    entity gender provenance  year_of_birth
# http://www.wikidata.org/entity/Q110230490 female     France            NaN
# http://www.wikidata.org/entity/Q110230490 female     Canada            NaN
# --------------------------------------------------------------------------------
#
# ...

# %%
import pandas as pd

# Read the files
tsv_data = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
csv_data = pd.read_csv('wikidata_results_non_creatives.csv')

# Strip <> from creativePerson in TSV and entity in CSV
tsv_data['?nonCreativePerson'] = tsv_data['?nonCreativePerson'].str.replace('<', '').str.replace('>', '')
csv_data['entity'] = csv_data['entity'].str.replace('<', '').str.replace('>', '')

# Merge files based on creativePerson and entity
merged_data = pd.merge(
    tsv_data, 
    csv_data,
    left_on='?nonCreativePerson',
    right_on='entity',
    how='left'
)

# Save as TSV
merged_data.to_csv('merged_results_non_creatives.tsv', sep='\t', index=False)

print("Files merged successfully!")
print(f"Found {len(merged_data)} rows in merged file")
# Out:
# Files merged successfully!
# Found 2093 rows in merged file

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results_non_creatives.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?nonCreativePerson'] = tsv_df['?nonCreativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Merge the dataframes on entity IDs
    # Using left join to keep all TSV rows
    merged_df = pd.merge(
        tsv_df,  # Keep all rows from TSV
        csv_df,
        left_on='?nonCreativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?nonCreativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'non_creativi_full_info_rep.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?nonCreativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: non_creativi_full_info_rep.tsv
#
# Statistics:
# Original TSV rows: 1869
# Original CSV rows: 869
# Final merged rows: 2093
# Rows with matched gender info: 2091
# Unique persons in result: 776

# %% [markdown]
# Drop duplicates in the CSV before merging.

# %%
import pandas as pd

def clean_entity_id(entity):
    """Clean entity ID by removing <> brackets if present"""
    if isinstance(entity, str):
        return entity.strip('<>').strip()
    return entity

def merge_files():
    # Read the TSV file
    tsv_df = pd.read_csv('merged_cleaned_noncreative.tsv', sep='\t')
    
    # Read the CSV file
    csv_df = pd.read_csv('wikidata_results_non_creatives.csv')
    
    # Clean entity IDs in both dataframes
    tsv_df['?nonCreativePerson'] = tsv_df['?nonCreativePerson'].apply(clean_entity_id)
    csv_df['entity'] = csv_df['entity'].apply(clean_entity_id)
    
    # Remove duplicates from CSV while keeping the first occurrence
    csv_df_unique = csv_df.drop_duplicates(subset=['entity'], keep='first')
    
    # Merge the dataframes on entity IDs
    merged_df = pd.merge(
        tsv_df,
        csv_df_unique,
        left_on='?nonCreativePerson',
        right_on='entity',
        how='left'
    )
    
    # Select and rename columns as needed
    final_df = merged_df[[
        '?nonCreativePerson',
        '?occupationLabel',
        '?disorderLabel',
        'gender',
        'provenance',
        'year_of_birth'
    ]]
    
    # Save to TSV
    output_filename = 'non_creativi_full_info.tsv'
    final_df.to_csv(output_filename, sep='\t', index=False)
    print(f"Merged file saved as: {output_filename}")
    
    # Print some statistics
    print(f"\nStatistics:")
    print(f"Original TSV rows: {len(tsv_df)}")
    print(f"Original CSV rows: {len(csv_df)}")
    print(f"CSV rows after removing duplicates: {len(csv_df_unique)}")
    print(f"Final merged rows: {len(final_df)}")
    print(f"Rows with matched gender info: {final_df['gender'].notna().sum()}")
    print(f"Unique persons in result: {final_df['?nonCreativePerson'].nunique()}")

if __name__ == "__main__":
    merge_files()
# Out:
# Merged file saved as: non_creativi_full_info.tsv
#
# Statistics:
# Original TSV rows: 1869
# Original CSV rows: 869
# CSV rows after removing duplicates: 776
# Final merged rows: 1869
# Rows with matched gender info: 1867
# Unique persons in result: 776

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# # Total people in wikidata

# %%
SELECT (COUNT(?person) AS ?peopleCount)
WHERE {
	# ?person wdt:P31/wdt:P279* wd:Q5  .
}

# %% [markdown]
# 11,719,028

# %% [markdown]
# # Total people in wikidata for whom an occupation is specified

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>

SELECT (COUNT(DISTINCT ?person) as ?count)
WHERE {
  # ?person wdt:P31 wd:Q5.  # is a human
  # ?person wdt:P106 ?occupation.  # has any occupation
}

# %% [markdown]
# 8,439,041

# %% [markdown]
# # Total creatives

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?creativePerson ?occupation 
WHERE {
 # ?creativePerson wdt:P31 wd:Q5.
 # ?creativePerson wdt:P106 ?occupation.
 # ?occupation wdt:P279* ?creativeOccupation.
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
}

# %% [markdown]
# Result saved in 'creativi_tot.tsv'

# %%
from collections import Counter
import csv

def analyze_creative_persons(tsv_file_path):
    # Initialize Counter
    creative_person_counts = Counter()
    total_rows = 0
    
    # Read TSV file
    with open(tsv_file_path, 'r', encoding='utf-8') as file:
        # Create TSV reader
        tsv_reader = csv.DictReader(file, delimiter='\t')
        
        # Count each creative person occurrence and total rows
        for row in tsv_reader:
            creative_person = row['?creativePerson']
            creative_person_counts[creative_person] += 1
            total_rows += 1
    
    # Get total unique IDs
    total_unique = len(creative_person_counts)
    
    # Count how many IDs appear multiple times
    repeated_ids = sum(1 for count in creative_person_counts.values() if count > 1)
    
    return total_rows, total_unique, repeated_ids

# Example usage
if __name__ == "__main__":
    file_path = "creativi_tot.tsv"  
    total_rows, total_unique, repeated = analyze_creative_persons(file_path)
    
    print(f"Total number of rows: {total_rows}")
# Out:
# Total number of rows: 2007687

# %% [markdown]
# ## Creatives: gender.

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT (COUNT(DISTINCT ?creativePerson) as ?creativeCount) ?gender
where {
  # ?creativePerson wdt:P31 wd:Q5.
  # ?creativePerson wdt:P21 ?gender.
  # ?creativePerson  wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?creativeOccupation.
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
}  
GROUP BY ?gender
ORDER BY DESC (?creativeCount)

# %% [markdown]
# Result: 'creativesGender.tsv'

# %% [markdown]
# Looking at the complete dataset of 1,887,233 entries:
#
# Male: 71.12% (1,342,278 people)\
# Female: 28.66% (540,920 people)\
# Other/Unspecified: 0.21% (4,035 people)

# %% [markdown]
# ## Creatives: nationality.

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT (COUNT(DISTINCT ?creativePerson) as ?creativeCount)?provenance
where {
  # ?creativePerson wdt:P31 wd:Q5.
  # ?creativePerson wdt:P27 ?provenance. #country of citizenship
  # ?creativePerson  wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?creativeOccupation.
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
}  
GROUP BY ?provenance
ORDER BY DESC (?creativeCount)

# %% [markdown]
# Results saved to 'creativesProvenance.tsv'

# %% [markdown]
# Total sum of all entries in ?creativeCount: 1,478,089
# Top 10 nationalities:
#
# USA (Q30): 191,919 (12.98%)\
# Germany (Q183): 93,823 (6.35%)\
# France (Q142): 92,456 (6.26%)\
# Japan (Q17): 75,031 (5.08%)\
# United Kingdom (Q145): 60,666 (4.10%)\
# Spain (Q29): 47,980 (3.25%)\
# Italy (Q38): 42,615 (2.88%)\
# Soviet Union (Q15180): 39,915 (2.70%)\
# Poland (Q29999): 38,184 (2.58%)\
# Sweden (Q34): 36,155 (2.45%)
#
# The top 10 nationalities sum to 718,744, which represents 48.63% of the total entries in the dataset.

# %% [markdown]
# ## Creatives: birth.

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?creativePerson ?yearOfBirth 
where {
  # ?creativePerson wdt:P31 wd:Q5.
  # ?creativePerson  wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?creativeOccupation.
  # ?creativePerson wdt:P569 ?dateOfBirth.
  BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
}

# %% [markdown]
# Results in 'creativesBirth.tsv'.

# %% [markdown]
# ## Analyse (birth)

# %%
import pandas as pd
from collections import Counter

def get_century(year):
    if pd.isna(year):
        return None
    try:
        return (int(float(year)) - 1) // 100 + 1
    except (ValueError, TypeError):
        return None

def analyze_birth_centuries(file_path):
    # Read the TSV file
    df = pd.read_csv(file_path, sep='\t')
    
    # Calculate century for each birth year
    df['century'] = df['?yearOfBirth'].apply(get_century)
    
    # Count people per century
    century_counts = Counter(df['century'].dropna())
    
    # Calculate total
    total_people = sum(century_counts.values())
    
    # Print results
    print("\nNumber of people born in each century:")
    for century, count in sorted(century_counts.items()):
        percentage = (count / total_people) * 100
        print(f"{int(century)}th century: {count} people ({percentage:.2f}%)")
    
    print(f"\nTotal number of people: {total_people}")
    
    return century_counts

# Example usage
if __name__ == "__main__":
    file_path = "creativesBirth.tsv"  # Replace with your file path
    century_distribution = analyze_birth_centuries(file_path)
# Out:
# Number of people born in each century:
# -42th century: 2 people (0.00%)
# -40th century: 1 people (0.00%)
# -31th century: 2 people (0.00%)
# -30th century: 1 people (0.00%)
# -28th century: 2 people (0.00%)
# -26th century: 1 people (0.00%)
# -25th century: 4 people (0.00%)
# -24th century: 1 people (0.00%)
# -23th century: 3 people (0.00%)
# -22th century: 2 people (0.00%)
# -20th century: 4 people (0.00%)
# -19th century: 1 people (0.00%)
# -16th century: 3 people (0.00%)
# -15th century: 7 people (0.00%)
# -14th century: 6 people (0.00%)
# -13th century: 17 people (0.00%)
# -12th century: 3 people (0.00%)
# -11th century: 2 people (0.00%)
# -10th century: 8 people (0.00%)
# -9th century: 1 people (0.00%)
# -8th century: 13 people (0.00%)
# -7th century: 47 people (0.00%)
# -6th century: 153 people (0.01%)
# -5th century: 252 people (0.02%)
# -4th century: 190 people (0.01%)
# -3th century: 158 people (0.01%)
# -2th century: 103 people (0.01%)
# -1th century: 139 people (0.01%)
# ...

# %%
import pandas as pd
from collections import Counter

def get_century(year):
    if pd.isna(year):
        return None
    try:
        return (int(float(year)) - 1) // 100 + 1
    except (ValueError, TypeError):
        return None

def analyze_birth_centuries(file_path):
    # Read the TSV file
    df = pd.read_csv(file_path, sep='\t')
    
    # Calculate century for each birth year
    df['century'] = df['?yearOfBirth'].apply(get_century)
    
    # Count people per century
    century_counts = Counter(df['century'].dropna())
    
    # Calculate total
    total_people = sum(century_counts.values())
    
    # Print results
    print("\nNumber of people born in each century (>1%):")
    others_count = 0
    
    for century, count in sorted(century_counts.items()):
        percentage = (count / total_people) * 100
        if percentage >= 1:  # Changed from > to >= to include 1%
            print(f"{int(century)}th century: {count} people ({percentage:.2f}%)")
        else:
            others_count += count
    
    # Print others
    others_percentage = (others_count / total_people) * 100
    print(f"Others: {others_count} people ({others_percentage:.2f}%)")
    
    print(f"\nTotal number of people: {total_people}")
    
    return century_counts

# Example usage
if __name__ == "__main__":
    file_path = "creativesBirth.tsv"  # Replace with your file path
    century_distribution = analyze_birth_centuries(file_path)
# Out:
# Number of people born in each century (>1%):
# 17th century: 20265 people (1.31%)
# 18th century: 51283 people (3.30%)
# 19th century: 308371 people (19.86%)
# 20th century: 1134209 people (73.05%)
# Others: 38491 people (2.48%)
#
# Total number of people: 1552619

# %% [markdown]
# # Most common occupations (creatives)

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT (COUNT(DISTINCT ?creativePerson) as ?creativeCount)?occupation
where {
  # ?creativePerson wdt:P31 wd:Q5.
  # ?creativePerson  wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?creativeOccupation.
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
}  
GROUP BY ?occupation
ORDER BY DESC (?creativeCount)

# %% [markdown]
# Result saved to 'creativeOccupations.tsv'

# %%
import pandas as pd

def analyze_creative_counts(file_path: str) -> pd.DataFrame:
    """
    Analyze creative counts and calculate percentages for each occupation,
    showing the top 15 most common occupations.
    """
    try:
        # Read data
        df = pd.read_csv(file_path, sep='\t')
        
        # Calculate total sum and percentages
        total_creatives = df['?creativeCount'].sum()
        df['percentage'] = (df['?creativeCount'] / total_creatives * 100).round(2)
        
        # Sort by count in descending order
        df = df.sort_values('?creativeCount', ascending=False)
        
        # Print summary and top 15
        print(f"\nTotal number of creative individuals: {total_creatives:,}")
        print(f"Number of unique occupations: {len(df):,}")
        print("\nTop 15 Creative Occupations:")
        print("-" * 100)
        
        cumulative_percentage = 0
        for idx, row in df.head(15).iterrows():
            cumulative_percentage += row['percentage']
            print(f"Occupation: {row['?occupation']}")
            print(f"Count: {row['?creativeCount']:,}")
            print(f"Percentage: {row['percentage']:.2f}%")
            print(f"Cumulative percentage: {cumulative_percentage:.2f}%")
            print("-" * 100)
        
        return df
    
    except FileNotFoundError:
        print(f"Error: Could not find file {file_path}")
        return None
    except pd.errors.EmptyDataError:
        print("Error: File is empty")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

if __name__ == "__main__":
    result_df = analyze_creative_counts('creativesOccupations.tsv')
# Out:
# Total number of creative individuals: 2,919,855
# Number of unique occupations: 1,309
#
# Top 15 Creative Occupations:
# ----------------------------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q36180>
# Count: 375,198
# Percentage: 12.85%
# Cumulative percentage: 12.85%
# ----------------------------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q33999>
# Count: 335,895
# Percentage: 11.50%
# Cumulative percentage: 24.35%
# ----------------------------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q1028181>
# Count: 211,567
# Percentage: 7.25%
# Cumulative percentage: 31.60%
# ----------------------------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q49757>
# Count: 120,539
# Percentage: 4.13%
# ...

# %% [markdown]
# Total number of creative individuals: 2,919,855\
# Number of unique occupations: 1,309
#
# Top 15 Creative Occupations:
#
# Occupation: Writer\
# Count: 375,198\
# Percentage: 12.85%\
# Cumulative percentage: 12.85%
#
# Occupation: Actor\
# Count: 335,895\
# Percentage: 11.50%\
# Cumulative percentage: 24.35%
#
# Occupation: Painter\
# Count: 211,567\
# Percentage: 7.25%\
# Cumulative percentage: 31.60%
#
# Occupation: Poet\
# Count: 120,539\
# Percentage: 4.13%\
# Cumulative percentage: 35.73%
#
# Occupation: Singer\
# Count: 115,984\
# Percentage: 3.97%\
# Cumulative percentage: 39.70%
#
# Occupation: Composer\
# Count: 110,111\
# Percentage: 3.77%\
# Cumulative percentage: 43.47%
#
# Occupation: Film director\
# Count: 96,024\
# Percentage: 3.29%\
# Cumulative percentage: 46.76%
#
# Occupation: Musician\
# Count: 92,005\
# Percentage: 3.15%\
# Cumulative percentage: 49.91%
#
# Occupation: Architect\
# Count: 84,465\
# Percentage: 2.89%\
# Cumulative percentage: 52.80%
#
# Occupation: Artist\
# Count: 79,005\
# Percentage: 2.71%\
# Cumulative percentage: 55.51%
#
# Occupation: Film actor\
# Count: 78,828\
# Percentage: 2.70%\
# Cumulative percentage: 58.21%
#
# Occupation: Screenwriter\
# Count: 78,708\
# Percentage: 2.70%\
# Cumulative percentage: 60.91%
#
# Occupation: Photographer\
# Count: 75,153\
# Percentage: 2.57%\
# Cumulative percentage: 63.48%
#
# Occupation: Visual artist\
# Count: 64,420\
# Percentage: 2.21%\
# Cumulative percentage: 65.69%
#
# Occupation: Author\
# Count: 63,969\
# Percentage: 2.19%\
# Cumulative percentage: 67.88%

# %% [markdown]
# # Total non creatives

# %% [markdown]
# ## First query (total)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson 
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  
  # Exclude creative professions and their subclasses
  MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
}

# %% [markdown]
# Result in 'non_creativi_tot1.tsv'

# %% [markdown]
# ## Second query (total)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson 
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
}

# %% [markdown]
# Result in 'non_creativi_tot2.tsv'

# %%
import pandas as pd

def find_common_rows(file1: str, file2: str, output_file: str = 'common_rows.tsv') -> None:
    """
    Find rows that appear in both input TSV files and save them to a new file.
    
    Args:
        file1: Path to first TSV file
        file2: Path to second TSV file
        output_file: Path for output TSV file containing common rows
    """
    try:
        # Read the TSV files
        df1 = pd.read_csv(file1, sep='\t')
        df2 = pd.read_csv(file2, sep='\t')
        
        # Print initial counts
        print(f"\nInitial counts:")
        print(f"Rows in first file: {len(df1)}")
        print(f"Rows in second file: {len(df2)}")
        
        # Find common rows based on the ?nonCreativePerson column
        common_rows = pd.merge(df1, df2, on='?nonCreativePerson', how='inner')
        
        # Save common rows to new file
        common_rows.to_csv(output_file, sep='\t', index=False)
        
        # Print summary
        print(f"\nResults:")
        print(f"Number of common rows found: {len(common_rows)}")
        print(f"Common rows saved to: {output_file}")
        
        # Print a few examples
        if len(common_rows) > 0:
            print(f"\nFirst few common entries:")
            print(common_rows['?nonCreativePerson'].head().to_string())
        
    except Exception as e:
        print(f"Error processing files: {str(e)}")

if __name__ == "__main__":
    # Example usage
    file1 = 'non_creativi_tot1.tsv'
    file2 = 'non_creativi_tot2.tsv'
    find_common_rows(file1, file2)
# Out:
# Initial counts:
# Rows in first file: 4046072
# Rows in second file: 4761115
#
# Results:
# Number of common rows found: 1840439
# Common rows saved to: common_rows.tsv
#
# First few common entries:
# 0    <http://www.wikidata.org/entity/Q1000006>
# 1    <http://www.wikidata.org/entity/Q1000045>
# 2    <http://www.wikidata.org/entity/Q1000048>
# 3    <http://www.wikidata.org/entity/Q1000050>
# 4    <http://www.wikidata.org/entity/Q1000051>

# %% [markdown]
# # Merge the two tsv files cancelling duplicates and compare with creatives (total)

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'merged_cleaned_noncreative.tsv') -> None:
    """
    Merge non-creative files (removing duplicates) and remove entries that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')
        
        # Step 1: Merge non-creative files and remove duplicates
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        merged_df_no_dupes = merged_df.drop_duplicates(subset=['?nonCreativePerson'])
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Remove rows that appear in creative file
        cleaned_df = merged_df_no_dupes[~merged_df_no_dupes['?nonCreativePerson'].isin(creative_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print only the final total
        print(f"TOTAL ROWS IN FINAL OUTPUT: {len(cleaned_df)}")
    
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativi_tot.tsv'
        noncreative_file1 = 'non_creativi_tot1.tsv'
        noncreative_file2 = 'non_creativi_tot2.tsv'
        output_file = 'non_creativi_final_tot.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# TOTAL ROWS IN FINAL OUTPUT: 6431354

# %% [markdown]
# ## Final breakdown (total):
#
# Creative people: 2,007,687\
# Non-creative people (after merging and cleaning): 6,431,354\
# People with no occupation listed: 3,279,756\
# Total accounted for: 11,718,797\
# Remaining difference: 231 people
#
# This accounts for essentially all 11.7M people in Wikidata:
#
# ~17.1% are creative professionals\
# ~54.9% are non-creative professionals\
# ~28% have no occupation listed\
# ~0.002% (231 people) fall into edge cases

# %% [markdown]
# # Non-creatives gender

# %% [markdown]
# ## First query (gender)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT DISTINCT ?nonCreativePerson ?gender
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?nonCreativePerson wdt:P21 ?gender
  # Exclude creative professions and their subclasses
  MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
}

# %% [markdown]
# Results in 'nonCreativesGender1.tsv'

# %% [markdown]
# ## Second query (gender)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?gender
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P21 ?gender.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation rdfs:label ?occupationLabel.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
}

# %% [markdown]
# Results in 'nonCreativesGender2.tsv'

# %% [markdown]
# ## Merge and compare with creatives (gender)

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'nonCreativesGenderTot.tsv') -> None:
    """
    Merge non-creative files (removing duplicates) and remove entries that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')

        # Print initial file sizes
        print(f"TOTAL ROWS IN FIRST NON-CREATIVE FILE: {len(noncreative_df1)}")
        print(f"TOTAL ROWS IN SECOND NON-CREATIVE FILE: {len(noncreative_df2)}")
        
        # Step 1: Merge non-creative files and remove duplicates
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        merged_df_no_dupes = merged_df.drop_duplicates(subset=['?nonCreativePerson'])
        
        #Print total before removing creative entries
        print(f"TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: {len(merged_df_no_dupes)}")
        
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Remove rows that appear in creative file
        cleaned_df = merged_df_no_dupes[~merged_df_no_dupes['?nonCreativePerson'].isin(creative_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print only the final total
        print(f"TOTAL ROWS IN FINAL OUTPUT: {len(cleaned_df)}")
    
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativi_tot.tsv'
        noncreative_file1 = 'nonCreativesGender1.tsv'
        noncreative_file2 = 'nonCreativesGender2.tsv'
        output_file = 'nonCreativesGenderTot.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# TOTAL ROWS IN FIRST NON-CREATIVE FILE: 3914990
# TOTAL ROWS IN SECOND NON-CREATIVE FILE: 3288367
# TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: 5389550
# TOTAL ROWS IN FINAL OUTPUT: 4866360

# %% [markdown]
# ## Analyse (gender)

# %%
import pandas as pd

def count_gender_occurrences(file_path: str):
   """
   Count occurrences of male (Q6581097), female (Q6581072) and others in gender column
   and calculate percentages against total rows
   """
   try:
       # Read TSV file
       df = pd.read_csv(file_path, sep='\t')
       
       # Get total number of rows
       total_rows = len(df)
       
       # Define the gender values to look for
       male_id = '<http://www.wikidata.org/entity/Q6581097>'
       female_id = '<http://www.wikidata.org/entity/Q6581072>'
       
       # Count occurrences
       male_count = len(df[df['?gender'] == male_id])
       female_count = len(df[df['?gender'] == female_id])
       others_count = total_rows - male_count - female_count
       
       # Print results
       print(f"Total rows in dataset: {total_rows:,}")
       print(f"\nCounts and percentages of total rows:")
       print(f"Male (Q6581097): {male_count:,} ({(male_count/total_rows)*100:.2f}%)")
       print(f"Female (Q6581072): {female_count:,} ({(female_count/total_rows)*100:.2f}%)")
       print(f"Others: {others_count:,} ({(others_count/total_rows)*100:.2f}%)")
       
   except Exception as e:
       print(f"Error processing file: {str(e)}")
       raise

if __name__ == "__main__":
   count_gender_occurrences('nonCreativesGenderTot.tsv')
# Out:
# Total rows in dataset: 4,866,360
#
# Counts and percentages of total rows:
# Male (Q6581097): 3,808,073 (78.25%)
# Female (Q6581072): 1,055,391 (21.69%)
# Others: 2,896 (0.06%)

# %% [markdown]
# # Non-creatives: nationality

# %% [markdown]
# ## First query (nationality)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT DISTINCT ?nonCreativePerson ?provenance
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.   
  # ?nonCreativePerson wdt:P27 ?provenance. #country of citizenship
  # Exclude creative professions and their subclasses
  MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
}

# %% [markdown]
# Results in 'nonCreativesProvenance1.tsv'

# %% [markdown]
# ## Second query (nationality)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?provenance
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P27 ?provenance. #country of citizenship
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
}

# %% [markdown]
# Results in 'nonCreativesProvenance2.tsv'

# %% [markdown]
# ## Merge and compare with creatives (nationality)

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'nonCreativesProvenanceTot.tsv') -> None:
    """
    Merge non-creative files (removing duplicates) and remove entries that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')

        # Print initial file sizes
        print(f"TOTAL ROWS IN FIRST NON-CREATIVE FILE: {len(noncreative_df1)}")
        print(f"TOTAL ROWS IN SECOND NON-CREATIVE FILE: {len(noncreative_df2)}")
        
        # Step 1: Merge non-creative files and remove duplicates
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        merged_df_no_dupes = merged_df.drop_duplicates(subset=['?nonCreativePerson'])
        
        #Print total before removing creative entries
        print(f"TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: {len(merged_df_no_dupes)}")
        
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Remove rows that appear in creative file
        cleaned_df = merged_df_no_dupes[~merged_df_no_dupes['?nonCreativePerson'].isin(creative_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print only the final total
        print(f"TOTAL ROWS IN FINAL OUTPUT: {len(cleaned_df)}")
    
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativi_tot.tsv'
        noncreative_file1 = 'nonCreativesProvenance1.tsv'
        noncreative_file2 = 'nonCreativesProvenance2.tsv'
        output_file = 'nonCreativesProvenanceTot.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# TOTAL ROWS IN FIRST NON-CREATIVE FILE: 3097222
# TOTAL ROWS IN SECOND NON-CREATIVE FILE: 2162303
# TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: 3461605
# TOTAL ROWS IN FINAL OUTPUT: 3056555

# %% [markdown]
# ## Analyse (nationality)

# %%
import pandas as pd
from collections import Counter

def analyze_provenance(tsv_file):
    # Read TSV file
    df = pd.read_csv(tsv_file, sep='\t')
    
    # Check if provenance column exists
    if '?provenance' not in df.columns:
        print("Error: '?provenance' column not found in the TSV file")
        return
    
    # Count occurrences using Counter
    provenance_counts = Counter(df['?provenance'].dropna())
    
    # Sort by count in descending order
    sorted_counts = dict(sorted(provenance_counts.items(), key=lambda x: x[1], reverse=True))
    
    # Calculate total occurrences
    total = sum(provenance_counts.values())
    
    # Print top 10 results with percentages
    print("\nTop 10 provenance values by frequency:")
    print("-" * 60)
    print(f"{'Value':<30} {'Count':>8} {'Percentage':>12}")
    print("-" * 60)
    
    for i, (value, count) in enumerate(sorted_counts.items()):
        if i >= 10:  # Only show top 10
            break
        percentage = (count / total) * 100
        print(f"{value:<30} {count:>8} {percentage:>11.2f}%")
    
    print("-" * 60)
    print(f"Total occurrences: {total}")

# Usage
if __name__ == "__main__":
    file_path = "nonCreativesProvenanceTot.tsv"  
    analyze_provenance(file_path)
# Out:
# Top 10 provenance values by frequency:
# ------------------------------------------------------------
# Value                             Count   Percentage
# ------------------------------------------------------------
# <http://www.wikidata.org/entity/Q30>   373209       12.21%
# <http://www.wikidata.org/entity/Q142>   238630        7.81%
# <http://www.wikidata.org/entity/Q183>   190057        6.22%
# <http://www.wikidata.org/entity/Q17>   135756        4.44%
# <http://www.wikidata.org/entity/Q145>   132163        4.32%
# <http://www.wikidata.org/entity/Q29>   102607        3.36%
# <http://www.wikidata.org/entity/Q252>    82224        2.69%
# <http://www.wikidata.org/entity/Q36>    80274        2.63%
# <http://www.wikidata.org/entity/Q15180>    74858        2.45%
# <http://www.wikidata.org/entity/Q38>    73059        2.39%
# ------------------------------------------------------------
# Total occurrences: 3056555

# %% [markdown]
# United States of America         12.21%\
# France                         7.81%\
# Germany                      6.22%\
# Japan                            4.44%\
# United Kingdom                   4.32%\
# Spain                            3.36%\
# Indonesia                         2.69%\
# Poland                            2.63%\
# Soviet Union                      2.45%\
# Italy                             2.39%

# %% [markdown]
# # Non creatives: year of birth

# %% [markdown]
# ## First query (birth)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT DISTINCT ?nonCreativePerson ?yearOfBirth
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.   
  # ?nonCreativePerson wdt:P569 ?dateOfBirth.
  BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
  # Exclude creative professions and their subclasses
  MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
}

# %% [markdown]
# Results in 'birthNonCreatives1.tsv'

# %% [markdown]
# ## Second query (birth)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT DISTINCT ?nonCreativePerson ?yearOfBirth
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
 # ?nonCreativePerson wdt:P569 ?dateOfBirth.
  BIND(YEAR(?dateOfBirth) AS ?yearOfBirth)
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
}

# %% [markdown]
# Results in 'birthNonCreatives2.tsv'

# %% [markdown]
# ## Merge and compare with creatives (birth)

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'nonCreativesBirthTot.tsv') -> None:
    """
    Merge non-creative files (removing duplicates) and remove entries that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')

        # Print initial file sizes
        print(f"TOTAL ROWS IN FIRST NON-CREATIVE FILE: {len(noncreative_df1)}")
        print(f"TOTAL ROWS IN SECOND NON-CREATIVE FILE: {len(noncreative_df2)}")
        
        # Step 1: Merge non-creative files and remove duplicates
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        merged_df_no_dupes = merged_df.drop_duplicates(subset=['?nonCreativePerson'])
        
        #Print total before removing creative entries
        print(f"TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: {len(merged_df_no_dupes)}")
        
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Remove rows that appear in creative file
        cleaned_df = merged_df_no_dupes[~merged_df_no_dupes['?nonCreativePerson'].isin(creative_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print only the final total
        print(f"TOTAL ROWS IN FINAL OUTPUT: {len(cleaned_df)}")
    
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativi_tot.tsv'
        noncreative_file1 = 'nonCreativesBirth1.tsv'
        noncreative_file2 = 'nonCreativesBirth2.tsv'
        output_file = 'nonCreativesBirthTot.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# TOTAL ROWS IN FIRST NON-CREATIVE FILE: 3268133
# TOTAL ROWS IN SECOND NON-CREATIVE FILE: 2305006
# TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: 4016300
# TOTAL ROWS IN FINAL OUTPUT: 3542985

# %% [markdown]
# ## Analyse (birth)

# %%
import pandas as pd
from collections import Counter

def get_century(year):
    if pd.isna(year):
        return None
    try:
        return (int(float(year)) - 1) // 100 + 1
    except (ValueError, TypeError):
        return None

def analyze_birth_centuries(file_path):
    # Read the TSV file
    df = pd.read_csv(file_path, sep='\t')
    
    # Calculate century for each birth year
    df['century'] = df['?yearOfBirth'].apply(get_century)
    
    # Count people per century
    century_counts = Counter(df['century'].dropna())
    
    # Calculate total
    total_people = sum(century_counts.values())
    
    # Print results
    print("\nNumber of people born in each century:")
    for century, count in sorted(century_counts.items()):
        percentage = (count / total_people) * 100
        print(f"{int(century)}th century: {count} people ({percentage:.2f}%)")
    
    print(f"\nTotal number of people: {total_people}")
    
    return century_counts

# Example usage
if __name__ == "__main__":
    file_path = "nonCreativesBirthTot.tsv"  # Replace with your file path
    century_distribution = analyze_birth_centuries(file_path)
# Out:
# Number of people born in each century:
# -90th century: 1 people (0.00%)
# -50th century: 1 people (0.00%)
# -40th century: 2 people (0.00%)
# -35th century: 7 people (0.00%)
# -32th century: 4 people (0.00%)
# -31th century: 4 people (0.00%)
# -30th century: 10 people (0.00%)
# -29th century: 8 people (0.00%)
# -28th century: 11 people (0.00%)
# -27th century: 22 people (0.00%)
# -26th century: 44 people (0.00%)
# -25th century: 43 people (0.00%)
# -24th century: 29 people (0.00%)
# -23th century: 30 people (0.00%)
# -22th century: 27 people (0.00%)
# -21th century: 28 people (0.00%)
# -20th century: 42 people (0.00%)
# -19th century: 29 people (0.00%)
# -18th century: 48 people (0.00%)
# -17th century: 50 people (0.00%)
# -16th century: 77 people (0.00%)
# -15th century: 71 people (0.00%)
# -14th century: 63 people (0.00%)
# -13th century: 99 people (0.00%)
# -12th century: 58 people (0.00%)
# -11th century: 54 people (0.00%)
# -10th century: 37 people (0.00%)
# ...

# %%
import pandas as pd
from collections import Counter

def get_century(year):
   if pd.isna(year):
       return None
   try:
       return (int(float(year)) - 1) // 100 + 1
   except (ValueError, TypeError):
       return None

def analyze_birth_centuries(file_path):
   # Read the TSV file
   df = pd.read_csv(file_path, sep='\t')
   
   # Calculate century for each birth year
   df['century'] = df['?yearOfBirth'].apply(get_century)
   
   # Count people per century
   century_counts = Counter(df['century'].dropna())
   
   # Calculate total
   total_people = sum(century_counts.values())
   
   # Print results
   print("\nNumber of people born in each century (>1%):")
   others_count = 0
   
   for century, count in sorted(century_counts.items()):
       percentage = (count / total_people) * 100
       if percentage > 1:
           print(f"{int(century)}th century: {count} people ({percentage:.2f}%)")
       else:
           others_count += count
   
   # Print others
   others_percentage = (others_count / total_people) * 100
   print(f"Others: {others_count} people ({others_percentage:.2f}%)")
   
   print(f"\nTotal number of people: {total_people}")
   
   return century_counts

# Example usage
if __name__ == "__main__":
   file_path = "nonCreativesBirthTot.tsv"  # Replace with your file path
   century_distribution = analyze_birth_centuries(file_path)
# Out:
# Number of people born in each century (>1%):
# 16th century: 39403 people (1.12%)
# 17th century: 54377 people (1.54%)
# 18th century: 140547 people (3.98%)
# 19th century: 654334 people (18.54%)
# 20th century: 2510380 people (71.11%)
# 21th century: 69845 people (1.98%)
# Others: 61222 people (1.73%)
#
# Total number of people: 3530108

# %% [markdown]
# # Most common occupations non creatives

# %% [markdown]
# ## Query one (occupations count)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT (COUNT (DISTINCT ?nonCreativePerson) as ?nonCreativesCount) ?occupation
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.   
  # Exclude creative professions and their subclasses
  MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
}
GROUP BY ?occupation 
ORDER BY DESC(?nonCreativesCount)

# %% [markdown]
# Results in 'nonCreativesOccupations1.tsv'

# %% [markdown]
# ## Query two (occupations count)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT (COUNT (DISTINCT ?nonCreativePerson) as ?nonCreativesCount) ?occupation
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
}
GROUP BY ?occupation 
ORDER BY DESC(?nonCreativesCount)

# %% [markdown]
# Results in 'nonCreativesOccupations2.tsv'

# %% [markdown]
# ## Merge and compare with creatives

# %%
import pandas as pd
import logging

def merge_and_clean_files(creative_file: str, noncreative_file1: str, noncreative_file2: str, 
                         output_file: str = 'nonCreativesOccupationsTot.tsv') -> None:
    """
    Merge non-creative files (removing duplicates) and remove entries that appear in creative file.
    
    Args:
        creative_file: Path to creativiID.tsv
        noncreative_file1: Path to first nonCreativiID.tsv
        noncreative_file2: Path to second nonCreativiID2.tsv
        output_file: Path for the merged and cleaned output file
    """
    try:
        # Read all TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        noncreative_df1 = pd.read_csv(noncreative_file1, sep='\t')
        noncreative_df2 = pd.read_csv(noncreative_file2, sep='\t')

        # Print initial file sizes
        print(f"TOTAL ROWS IN FIRST NON-CREATIVE FILE: {len(noncreative_df1)}")
        print(f"TOTAL ROWS IN SECOND NON-CREATIVE FILE: {len(noncreative_df2)}")
        
        # Step 1: Merge non-creative files and remove duplicates
        merged_df = pd.concat([noncreative_df1, noncreative_df2], axis=0)
        merged_df_no_dupes = merged_df.drop_duplicates(subset=['?nonCreativePerson'])
        
        #Print total before removing creative entries
        print(f"TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: {len(merged_df_no_dupes)}")
        
        
        # Get unique IDs from creative file
        creative_ids = set(creative_df['?creativePerson'])
        
        # Remove rows that appear in creative file
        cleaned_df = merged_df_no_dupes[~merged_df_no_dupes['?nonCreativePerson'].isin(creative_ids)]
        
        # Save the cleaned merged file
        cleaned_df.to_csv(output_file, sep='\t', index=False)
        
        # Print only the final total
        print(f"TOTAL ROWS IN FINAL OUTPUT: {len(cleaned_df)}")
    
    except Exception as e:
        logging.error(f"Error processing files: {str(e)}")
        raise

if __name__ == "__main__":
    try:
        # File paths
        creative_file = 'creativi_tot.tsv'
        noncreative_file1 = 'nonCreativesOccupations1.tsv'
        noncreative_file2 = 'nonCreativesOccupations2.tsv'
        output_file = 'nonCreativesOccupationsTot.tsv'
        
        merge_and_clean_files(creative_file, noncreative_file1, noncreative_file2, output_file)
        
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# TOTAL ROWS IN FIRST NON-CREATIVE FILE: 4991429
# TOTAL ROWS IN SECOND NON-CREATIVE FILE: 5270131
# TOTAL NON-CREATIVE ROWS BEFORE REMOVING CREATIVES: 6966748
# TOTAL ROWS IN FINAL OUTPUT: 6431354

# %% [markdown]
# ## Analyse (occupations)

# %%
import pandas as pd

def analyze_occupations(file_path: str):
    """
    Analyze occupation frequencies from TSV file and calculate percentages.
    
    Args:
        file_path (str): Path to TSV file
    """
    try:
        # Read TSV file
        df = pd.read_csv(file_path, sep='\t')
        
        # Count total rows before cleaning
        total_rows = len(df)
        
        # Remove rows where occupation is missing
        df = df.dropna(subset=['?occupation'])
        
        # Count frequencies of each occupation
        occupation_counts = df['?occupation'].value_counts()
        
        # Calculate percentages
        occupation_percentages = (occupation_counts / total_rows * 100)
        
        # Create DataFrame with results
        results_df = pd.DataFrame({
            'Occupation': occupation_counts.index,
            'Count': occupation_counts.values,
            'Percentage': occupation_percentages.values
        })
        
        # Display top 10 results
        print("\nTop 10 Most Common Occupations:")
        print("-" * 80)
        for idx, row in results_df.head(10).iterrows():
            print(f"Occupation: {row['Occupation']}")
            print(f"Count: {row['Count']:,}")
            print(f"Percentage: {row['Percentage']:.2f}%")
            print("-" * 80)
            
        # Print total statistics
        print(f"\nTotal unique occupations: {len(occupation_counts):,}")
        print(f"Total people analyzed: {total_rows:,}")
        
    except FileNotFoundError:
        print(f"Error: Could not find file - {file_path}")
    except pd.errors.EmptyDataError:
        print("Error: File is empty")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    file_path = 'nonCreativesOccupationsTot.tsv'
    analyze_occupations(file_path)
# Out:
# Top 10 Most Common Occupations:
# --------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q1650915>
# Count: 1,952,977
# Percentage: 30.37%
# --------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q82955>
# Count: 607,446
# Percentage: 9.45%
# --------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q937857>
# Count: 332,414
# Percentage: 5.17%
# --------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q1622272>
# Count: 214,554
# Percentage: 3.34%
# --------------------------------------------------------------------------------
# Occupation: <http://www.wikidata.org/entity/Q3665646>
# Count: 169,574
# Percentage: 2.64%
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# Occupation: Researcher\
# Count: 1,952,977\
# Percentage: 30.37%
#
# Occupation: Politician\
# Count: 607,446\
# Percentage: 9.45%
#
# Occupation: Association football player\
# Count: 332,414\
# Percentage: 5.17%
#
# Occupation: University teacher\
# Count: 214,554\
# Percentage: 3.34%
#
# Occupation: Basketball player\
# Count: 169,574\
# Percentage: 2.64%
#
# Occupation: Military personnel\
# Count: 83,050\
# Percentage: 1.29%
#
# Occupation: Journalist\
# Count: 67,228\
# Percentage: 1.05%
#
# Occupation: Businessperson\
# Count: 64,050\
# Percentage: 1.00%
#
# Occupation: Physician\
# Count: 63,821\
# Percentage: 0.99%
#
# Occupation: Catholic priest\
# Count: 61,790\
# Percentage: 0.96%

# %% [markdown]
# # Total percentages
# Creatives with disturbs: 1490\
# Creatives: 2,007,687
#
# Non-creatives with disturbs: 776\
# Non-creatives: 6,431,354
#
# Total people with disturbs: 2387\
# Total people: 11,719,028\
# Total with occupation specified:8,439,041
#
# ### Creatives with disturbs vs total Creatives:
# 1,490 / 2,007,687 = 0.074% have disturbs
#
# ### Non-creatives with disturbs vs total Non-creatives:
# 776 / 6,431,354 = 0.012% have disturbs
#
# ### Total people with disturbs vs total people:
# 2,387 / 11,719,028 = 0.020% have disturbs
#
# #### Total with disturbs vs total with occupation:
# 2,387 / 8,439,041 = 0.028% of people with occupations have disturbs
#
# ### People with occupation vs total people:
# 8,439,041 / 11,719,028 = 72.01% have an occupation specified
#
# Observations:
# 1. Creatives have a higher rate of disturbs (0.074%) compared to non-creatives (0.012%) - about 6 times higher
# 2. Only a very small fraction of the total population (0.020%) has disturbs
# 4. The disturbs seem to be more concentrated in the creative population despite creatives being a smaller group overall
#
# ## Distribution of disturbed people between creative and non-creative categories:
#
# Of the total 2,387 people with disturbs:
# * Creative disturbed: 1,490 / 2,387 = 62.42%
# * Non-creative disturbed: 776 / 2,387 = 32.51%
#
# This is particularly striking because:
# 1. The creative population (2,007,687) is much smaller than the non-creative population (6,431,354)
# 2. Yet they represent nearly 2/3 of all disturbed people
#
# Note: There's a small discrepancy in the numbers:
# * 1,490 + 776 = 2,266 (disturbed creatives + non-creatives)
# * Total disturbed reported: 2,387
# * Difference: 121 people (about 5.07% of disturbed people) are in unclassified occupations

# %% [markdown]
# # Align with dsm-5.
# First we extract all values from the ?disorderLabel column in the 'creativi_full_info.tsv' and 'non_creativi_full_info.tsv', then we align them to the DSM-5 taxonomy:

# %% [markdown]
# ## Extract all disorders from creatives

# %%
import pandas as pd

# Read the TSV file
df = pd.read_csv('creativi_full_info.tsv', sep='\t')

# Extract unique values from ?disorderLabel column, remove '@en' suffix and sort
unique_disorders = sorted(df['?disorderLabel'].str.replace('@en', '').str.strip().unique())

# Print each unique disorder
for disorder in unique_disorders:
    print(disorder)
# Out:
# Asperger syndrome
# Attention deficit hyperactivity disorder predominantly inattentive
# Cotard delusion
# Diogenes syndrome
# Hallermann-Streiff syndrome
# Huntington's disease
# Joubert syndrome
# Korsakoff's syndrome
# Language-based learning disability
# Lewy body dementia
# Non-Verbal Learning Disorder
# REM sleep behavior disorder
# Tourette syndrome
# Wiedemann-Rautenstrauch syndrome
# Williams-Beuren syndrome
# Wilson disease
# XXXY syndrome
# agoraphobia
# alcohol abuse
# alcohol dependence
# alcoholic hepatitis
# alcoholism
# amnesia
# anorexia nervosa
# anterograde amnesia
# antisocial personality disorder
# anxiety
# anxiety disorder
# aphasia
# aphonia
# attention deficit hyperactivity disorder
# atypical autism
# autism
# autism spectrum disorder
# autistic savant
# benzodiazepine withdrawal syndrome
# binge eating disorder
# bipolar I disorder
# bipolar II disorder
# bipolar disorder
# body dysmorphic disorder
# borderline personality disorder
# bulimia nervosa
# ...

# %% [markdown]
# # Creatives: count total occurrences and individual (without duplicates) occurrences per disorder.

# %%
import pandas as pd

# DSM-5 categorization mapping
dsm5_mapping = {
    # Neurodevelopmental Disorders
    'Asperger syndrome': 'Neurodevelopmental Disorders',
    'attention deficit hyperactivity disorder': 'Neurodevelopmental Disorders',
    'attention deficit hyperactivity disorder predominantly inattentive': 'Neurodevelopmental Disorders',
    'autism': 'Neurodevelopmental Disorders',
    'autism spectrum disorder': 'Neurodevelopmental Disorders',
    'atypical autism': 'Neurodevelopmental Disorders',
    'autistic savant': 'Neurodevelopmental Disorders',
    'developmental coordination disorder': 'Neurodevelopmental Disorders',
    'dyscalculia': 'Neurodevelopmental Disorders',
    'dyslexia': 'Neurodevelopmental Disorders',
    'hyperactivity': 'Neurodevelopmental Disorders',
    'hyperlexia': 'Neurodevelopmental Disorders',
    'intellectual disability': 'Neurodevelopmental Disorders',
    'Language-based learning disability': 'Neurodevelopmental Disorders',
    'Non-Verbal Learning Disorder': 'Neurodevelopmental Disorders',
    'pervasive developmental disorder': 'Neurodevelopmental Disorders',
    'savant syndrome': 'Neurodevelopmental Disorders',
    'Tourette syndrome': 'Neurodevelopmental Disorders',

    # Schizophrenia Spectrum and Other Psychotic Disorders  
    'paranoid schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizoaffective disorder': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',

    # Bipolar and Related Disorders
    'bipolar disorder': 'Bipolar and Related Disorders',
    'bipolar I disorder': 'Bipolar and Related Disorders', 
    'bipolar II disorder': 'Bipolar and Related Disorders',

    # Depressive Disorders
    'chronic depressive disorder': 'Depressive Disorders',
    'dysthymic disorder': 'Depressive Disorders',
    'major depressive disorder': 'Depressive Disorders',
    'mental depression': 'Depressive Disorders',

    # Anxiety Disorders
    'agoraphobia': 'Anxiety Disorders',
    'anxiety': 'Anxiety Disorders',
    'anxiety disorder': 'Anxiety Disorders',
    'claustrophobia': 'Anxiety Disorders',
    'panic attack': 'Anxiety Disorders',
    'panic disorder': 'Anxiety Disorders',

    # Obsessive-Compulsive and Related Disorders
    'body dysmorphic disorder': 'Obsessive-Compulsive and Related Disorders',
    'excoriation disorder': 'Obsessive-Compulsive and Related Disorders',
    'obsessive-compulsive disorder': 'Obsessive-Compulsive and Related Disorders',
    'trichotillomania': 'Obsessive-Compulsive and Related Disorders',

    # Trauma and Stressor-Related Disorders
    'complex post-traumatic stress disorder': 'Trauma and Stressor-Related Disorders',
    'post-traumatic stress disorder': 'Trauma and Stressor-Related Disorders',

    # Dissociative Disorders
    'dissociative disorder': 'Dissociative Disorders',
    'dissociative disorder not otherwise specified': 'Dissociative Disorders',
    'dissociative identity disorder': 'Dissociative Disorders',
    'amnesia': 'Dissociative Disorders',
    'anterograde amnesia': 'Dissociative Disorders',
    'retrograde amnesia': 'Dissociative Disorders',

    # Feeding and Eating Disorders
    'anorexia nervosa': 'Feeding and Eating Disorders',
    'binge eating disorder': 'Feeding and Eating Disorders',
    'bulimia nervosa': 'Feeding and Eating Disorders',
    'eating disorder': 'Feeding and Eating Disorders',

    # Sleep-Wake Disorders
    'hypersomnia': 'Sleep-Wake Disorders',
    'insomnia': 'Sleep-Wake Disorders',
    'narcolepsy': 'Sleep-Wake Disorders',
    'REM sleep behavior disorder': 'Sleep-Wake Disorders',
    'sleep apnea': 'Sleep-Wake Disorders',
    'sleep paralysis': 'Sleep-Wake Disorders',
    'sleepwalking': 'Sleep-Wake Disorders',

    # Gender Dysphoria
    'gender dysphoria': 'Gender Dysphoria',

    # Disruptive, Impulse-Control, and Conduct Disorders
    'kleptomania': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'oppositional defiant disorder': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'pathological lying': 'Disruptive, Impulse-Control, and Conduct Disorders',

    # Substance-Related and Addictive Disorders
    'alcohol abuse': 'Substance-Related and Addictive Disorders',
    'alcohol dependence': 'Substance-Related and Addictive Disorders',
    'alcoholism': 'Substance-Related and Addictive Disorders',
    'benzodiazepine withdrawal syndrome': 'Substance-Related and Addictive Disorders',
    'cannabis dependence': 'Substance-Related and Addictive Disorders',
    'cocaine dependence': 'Substance-Related and Addictive Disorders',
    'hallucinogen persisting perception disorder': 'Substance-Related and Addictive Disorders',
    'heroin dependence': 'Substance-Related and Addictive Disorders',
    'ketamine dependence': 'Substance-Related and Addictive Disorders',
    'nicotine dependence': 'Substance-Related and Addictive Disorders',
    'non-controlled substance abuse': 'Substance-Related and Addictive Disorders',
    'opioid use disorder': 'Substance-Related and Addictive Disorders',
    'substance dependence': 'Substance-Related and Addictive Disorders',

    # Neurocognitive Disorders
    'chronic traumatic encephalopathy': 'Neurocognitive Disorders',
    'corticobasal degeneration': 'Neurocognitive Disorders',
    'dementia': 'Neurocognitive Disorders',
    'dementia with Lewy bodies': 'Neurocognitive Disorders',
    'frontotemporal dementia': 'Neurocognitive Disorders',
    "Huntington's disease": 'Neurocognitive Disorders',
    "Korsakoff's syndrome": 'Neurocognitive Disorders',
    'Lewy body dementia': 'Neurocognitive Disorders',
    'memory disorder': 'Neurocognitive Disorders',
    'progressive supranuclear palsy': 'Neurocognitive Disorders',
    'vascular dementia': 'Neurocognitive Disorders',

    # Personality Disorders
    'antisocial personality disorder': 'Personality Disorders',
    'borderline personality disorder': 'Personality Disorders',
    'histrionic personality disorder': 'Personality Disorders',
    'narcissistic personality disorder': 'Personality Disorders',
    'obsessive-compulsive personality disorder': 'Personality Disorders',
    'organic personality disorder': 'Personality Disorders',

    # Communication Disorders
    'aphasia': 'Communication Disorders',
    'aphonia': 'Communication Disorders',
    'coprolalia': 'Communication Disorders',
    'foreign accent syndrome': 'Communication Disorders',
    'lisp': 'Communication Disorders',
    'muteness': 'Communication Disorders',
    'speech disorder': 'Communication Disorders',
    'stuttering': 'Communication Disorders',

    # Other Conditions/Not Classified
    'alcoholic hepatitis': 'Other Medical Conditions',
    'Cotard delusion': 'Other Conditions',
    'delusion': 'Other Conditions',
    'Diogenes syndrome': 'Other Conditions',
    'emotional disorder': 'Other Conditions',
    'grandiose delusions': 'Other Conditions',
    'Hallermann-Streiff syndrome': 'Other Conditions',
    'hyperthymesia': 'Other Conditions',
    'Joubert syndrome': 'Other Conditions',
    'mental breakdown': 'Other Conditions',
    'myotonic dystrophy': 'Other Conditions',
    'neurasthenia': 'Other Conditions',
    'oral galvanism': 'Other Conditions',
    'paranoia': 'Other Conditions',
    'paranoid delusion': 'Other Conditions',
    'post-concussion syndrome': 'Other Conditions',
    'prosopagnosia': 'Other Conditions',
    'pseudobulbar affect': 'Other Conditions',
    'school refusal': 'Other Conditions',
    'Wiedemann-Rautenstrauch syndrome': 'Other Conditions',
    'Williams-Beuren syndrome': 'Other Conditions',
    'Wilson disease': 'Other Conditions',
    'XXXY syndrome': 'Other Conditions',
    'deaf-mute': 'Other Conditions'
}
def clean_label(label):
    """Clean label by removing @en and trimming"""
    if pd.isna(label):
        return ''
    return label.replace('@en', '').strip()

def get_dsm5_category(disorder):
    """Get DSM-5 category for a disorder"""
    if pd.isna(disorder):
        return ''
    clean_disorder = clean_label(disorder)
    return dsm5_mapping.get(clean_disorder, 'Uncategorized')

# Read and process the original TSV file
df = pd.read_csv('creativi_full_info.tsv', sep='\t')

# Clean disorder labels and add DSM-5 categories
df['clean_disorder'] = df['?disorderLabel'].apply(clean_label)
df['dsm-5'] = df['?disorderLabel'].apply(get_dsm5_category)

# Save the enhanced dataset
df.to_csv('creativi_full_info_with_dsm5.tsv', sep='\t', index=False)

def create_category_summary(df_all, df_unique):
    """Create summary using both all occurrences and unique people counts"""
    # Count raw occurrences per disorder
    disorder_counts_all = df_all['clean_disorder'].value_counts()
    disorder_counts_unique = df_unique['clean_disorder'].value_counts()
    
    # Create reverse mapping (category to disorders)
    category_to_disorders = {}
    for disorder, category in dsm5_mapping.items():
        if category not in category_to_disorders:
            category_to_disorders[category] = []
        category_to_disorders[category].append(disorder)
    
    # Sort categories and their disorders
    summary = {}
    for category in sorted(category_to_disorders.keys()):
        summary[category] = sorted(category_to_disorders[category])

    # Save summary to file
    with open('creativi_dsm5_categories_summary.txt', 'w', encoding='utf-8') as f:
        f.write("DSM-5 CATEGORIES SUMMARY\n")
        f.write("=" * 50 + "\n\n")
        
        # Count occurrences per category
        category_counts_all = df_all['dsm-5'].value_counts()
        category_counts_unique = df_unique['dsm-5'].value_counts()
        
        f.write("OVERALL STATISTICS\n")
        f.write("-" * 30 + "\n")
        f.write(f"Total disorder occurrences: {len(df_all)}\n")
        f.write(f"Total unique individuals: {len(df_unique)}\n")
        f.write(f"Total DSM-5 categories: {len(summary)}\n\n")

        # Write counts for both all occurrences and unique individuals
        f.write("CATEGORY DISTRIBUTION\n")
        f.write("-" * 30 + "\n")
        for category in sorted(summary.keys()):
            count_all = category_counts_all.get(category, 0)
            count_unique = category_counts_unique.get(category, 0)
            if count_all > 0:
                f.write(f"{category}:\n")
                f.write(f"  Total occurrences: {count_all}\n")
                f.write(f"  Unique individuals: {count_unique}\n")
        f.write("\n")

        # Write detailed category contents with both counts
        f.write("DETAILED CATEGORY CONTENTS AND COUNTS\n")
        f.write("-" * 30 + "\n")
        
        for category, disorders in summary.items():
            count_all = category_counts_all.get(category, 0)
            count_unique = category_counts_unique.get(category, 0)
            if count_all > 0:
                f.write(f"\n{category}:\n")
                f.write(f"Total occurrences: {count_all} | Unique individuals: {count_unique}\n")
                
                for disorder in disorders:
                    clean_disorder = clean_label(disorder)
                    count_all_disorder = disorder_counts_all.get(clean_disorder, 0)
                    count_unique_disorder = disorder_counts_unique.get(clean_disorder, 0)
                    if count_all_disorder > 0:
                        f.write(f"  - {disorder}:\n")
                        f.write(f"    Occurrences: {count_all_disorder} | Unique individuals: {count_unique_disorder}\n")

    return summary

# Create dataset with unique individuals
df_unique = df.drop_duplicates(subset=['?creativePerson'])

# Create the summary using both datasets
summary = create_category_summary(df, df_unique)

# Save distribution counts to CSV
dsm5_distribution_all = df['dsm-5'].value_counts()
dsm5_distribution_unique = df_unique['dsm-5'].value_counts()

# Create a DataFrame with both counts
distribution_df = pd.DataFrame({
    'all_occurrences': dsm5_distribution_all,
    'unique_individuals': dsm5_distribution_unique
})
distribution_df.to_csv('creatives_dsm5_counts.csv')

# Print detailed contents
print("\nDETAILED CATEGORY CONTENTS AND COUNTS")
print("-" * 30)

for category, disorders in sorted(summary.items()):
    category_count_all = df['dsm-5'].value_counts().get(category, 0)
    category_count_unique = df_unique['dsm-5'].value_counts().get(category, 0)
    
    if category_count_all > 0:
        print(f"\n{category}:")
        print(f"Total occurrences: {category_count_all} | Unique individuals: {category_count_unique}")
        
        for disorder in disorders:
            clean_disorder = clean_label(disorder)
            count_all = df['clean_disorder'].value_counts().get(clean_disorder, 0)
            count_unique = df_unique['clean_disorder'].value_counts().get(clean_disorder, 0)
            if count_all > 0:
                print(f"  - {disorder}:")
                print(f"    Occurrences: {count_all} | Unique individuals: {count_unique}")
# Out:
# DETAILED CATEGORY CONTENTS AND COUNTS
# ------------------------------
#
# Anxiety Disorders:
# Total occurrences: 91 | Unique individuals: 31
#   - agoraphobia:
#     Occurrences: 23 | Unique individuals: 7
#   - anxiety:
#     Occurrences: 10 | Unique individuals: 3
#   - anxiety disorder:
#     Occurrences: 36 | Unique individuals: 16
#   - claustrophobia:
#     Occurrences: 8 | Unique individuals: 1
#   - panic attack:
#     Occurrences: 4 | Unique individuals: 0
#   - panic disorder:
#     Occurrences: 10 | Unique individuals: 4
#
# Bipolar and Related Disorders:
# Total occurrences: 839 | Unique individuals: 248
#   - bipolar I disorder:
#     Occurrences: 1 | Unique individuals: 0
#   - bipolar II disorder:
#     Occurrences: 6 | Unique individuals: 2
#   - bipolar disorder:
#     Occurrences: 832 | Unique individuals: 246
#
# Communication Disorders:
# Total occurrences: 407 | Unique individuals: 108
#   - aphasia:
#     Occurrences: 13 | Unique individuals: 4
#   - aphonia:
# ...

# %% [markdown]
# ## Percentages.

# %% [markdown]
# Based on the analysis, here are the macro-disorders ranked by their percentage of total unique individuals (1,483 total):
#
# Neurodevelopmental Disorders: 646 (43.6%)\
# Bipolar and Related Disorders: 248 (16.7%)\
# Depressive Disorders: 122 (8.2%)\
# Communication Disorders: 108 (7.3%)
# Schizophrenia Spectrum and Other Psychotic Disorders: 80 (5.4%)\
# Substance-Related and Addictive Disorders: 60 (4.0%)\
# Other Conditions: 51 (3.4%)\
# Neurocognitive Disorders: 47 (3.2%)\
# Anxiety Disorders: 31 (2.1%)\
# Obsessive-Compulsive and Related Disorders: 23 (1.6%)\
# Personality Disorders: 22 (1.5%)\
# Feeding and Eating Disorders: 15 (1.0%)\
# Sleep-Wake Disorders: 9 (0.6%)\
# Trauma and Stressor-Related Disorders: 9 (0.6%)\
# Dissociative Disorders: 7 (0.5%)\
# Disruptive, Impulse-Control, and Conduct Disorders: 2 (0.1%)\
# Other Medical Conditions: 2 (0.1%)\
# Gender Dysphoria: 1 (0.1%)

# %% [markdown]
# ### Breakdown on Neurodevelopmental disorders:
# autism (204 individuals, 550 occurrences)\
# dyslexia (177 individuals, 697 occurrences)\
# attention deficit hyperactivity disorder (129 individuals, 375 occurrences)\
# Asperger syndrome (100 individuals, 268 occurrences)\
# Tourette syndrome (13 individuals, 67 occurrences)\
# autism spectrum disorder (13 individuals, 35 occurrences)\
# developmental coordination disorder (4 individuals, 26 occurrences)\
# Language-based learning disability (1 individual, 1 occurrence)\
# Non-Verbal Learning Disorder (1 individual, 9 occurrences)\
# atypical autism (1 individual, 6 occurrences)\
# dyscalculia (1 individual, 8 occurrences)\
# pervasive developmental disorder (1 individual, 2 occurrences)\
# savant syndrome (1 individual, 9 occurrences)\
# autistic savant (0 individuals, 1 occurrence)\
# hyperactivity (0 individuals, 4 occurrences)\
# hyperlexia (0 individuals, 3 occurrences)\
# intellectual disability (0 individuals, 2 occurrences)
#
# Note that the four most common conditions (autism, dyslexia, ADHD, and Asperger syndrome) account for the majority of unique individuals in this category.

# %% [markdown]
# # Extract all disorders from non-creatives

# %%
import pandas as pd

# Read the TSV file
df = pd.read_csv('non_creativi_full_info.tsv', sep='\t')

# Extract unique values from ?disorderLabel column, remove '@en' suffix and sort
unique_disorders = sorted(df['?disorderLabel'].str.replace('@en', '').str.strip().unique())

# Print each unique disorder
for disorder in unique_disorders:
    print(disorder)
# Out:
# Asperger syndrome
# Clinical lycanthropy
# Creutzfeldt-Jakob disease
# Huntington's disease
# Kleine-Levin syndrome
# Lewy body dementia
# Muscle dysmorphia
# Münchausen syndrome
# Tourette syndrome
# adjustment disorder
# alcohol dependence
# alcoholism
# anorexia
# anorexia nervosa
# anterograde amnesia
# antisocial personality disorder
# anxiety
# anxiety disorder
# aphasia
# attention deficit hyperactivity disorder
# autism
# autism spectrum disorder
# bipolar I disorder
# bipolar II disorder
# bipolar disorder
# body dysmorphic disorder
# borderline personality disorder
# bulimia nervosa
# chronic traumatic encephalopathy
# chronophilia
# combat disorder
# complex post-traumatic stress disorder
# conduct disorder
# coprophilia
# deaf-mute
# delirium
# delirium tremens
# delusion
# dementia
# dementia with Lewy bodies
# developmental coordination disorder
# disability affecting intellectual abilities
# disorganized schizophrenia
# dyslexia
# eating disorder
# ...

# %% [markdown]
# # Non-creatives: count total occurrences and individual (without duplicates) occurrences per disorder.

# %%
import pandas as pd

# DSM-5 categorization mapping
dsm5_mapping = {
    # Neurodevelopmental Disorders
    'Asperger syndrome': 'Neurodevelopmental Disorders',
    'attention deficit hyperactivity disorder': 'Neurodevelopmental Disorders',
    'autism': 'Neurodevelopmental Disorders',
    'autism spectrum disorder': 'Neurodevelopmental Disorders',
    'developmental coordination disorder': 'Neurodevelopmental Disorders',
    'disability affecting intellectual abilities': 'Neurodevelopmental Disorders',
    'dyslexia': 'Neurodevelopmental Disorders',
    'feeble-minded': 'Neurodevelopmental Disorders',
    'high-functioning autism': 'Neurodevelopmental Disorders',
    'intellectual disability': 'Neurodevelopmental Disorders',
    'pervasive developmental disorder not otherwise specified': 'Neurodevelopmental Disorders',
    'Tourette syndrome': 'Neurodevelopmental Disorders',

    # Schizophrenia Spectrum and Other Psychotic Disorders
    'delusion': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'disorganized schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'hallucination': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'paranoid schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizoid personality disorder': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizotypal personality disorder': 'Schizophrenia Spectrum and Other Psychotic Disorders',

    # Bipolar and Related Disorders
    'bipolar disorder': 'Bipolar and Related Disorders',
    'bipolar I disorder': 'Bipolar and Related Disorders',
    'bipolar II disorder': 'Bipolar and Related Disorders',

    # Depressive Disorders
    'major depressive disorder': 'Depressive Disorders',
    'melancholia': 'Depressive Disorders',
    'mental depression': 'Depressive Disorders',
    'postpartum depression': 'Depressive Disorders',

    # Anxiety Disorders
    'anxiety': 'Anxiety Disorders',
    'anxiety disorder': 'Anxiety Disorders',
    'generalized anxiety disorder': 'Anxiety Disorders',
    'nosophobia': 'Anxiety Disorders',
    'panic attack': 'Anxiety Disorders',
    'panic disorder': 'Anxiety Disorders',
    'social anxiety disorder': 'Anxiety Disorders',
    'triskaidekaphobia': 'Anxiety Disorders',

    # Obsessive-Compulsive and Related Disorders
    'body dysmorphic disorder': 'Obsessive-Compulsive and Related Disorders',
    'muscle dysmorphia': 'Obsessive-Compulsive and Related Disorders',
    'obsessive-compulsive disorder': 'Obsessive-Compulsive and Related Disorders',
    'obsessive-compulsive personality disorder': 'Obsessive-Compulsive and Related Disorders',

    # Trauma and Stressor-Related Disorders
    'adjustment disorder': 'Trauma and Stressor-Related Disorders',
    'combat disorder': 'Trauma and Stressor-Related Disorders',
    'complex post-traumatic stress disorder': 'Trauma and Stressor-Related Disorders',
    'post-traumatic stress disorder': 'Trauma and Stressor-Related Disorders',
    'shell shock': 'Trauma and Stressor-Related Disorders',

    # Dissociative Disorders
    'anterograde amnesia': 'Dissociative Disorders',
    'Clinical lycanthropy': 'Dissociative Disorders',

    # Somatic Symptom and Related Disorders
    'factitious disorder imposed on another': 'Somatic Symptom and Related Disorders',
    'Münchausen syndrome': 'Somatic Symptom and Related Disorders',

    # Feeding and Eating Disorders
    'anorexia': 'Feeding and Eating Disorders',
    'anorexia nervosa': 'Feeding and Eating Disorders',
    'bulimia nervosa': 'Feeding and Eating Disorders',
    'eating disorder': 'Feeding and Eating Disorders',

    # Sleep-Wake Disorders
    'hypersomnia': 'Sleep-Wake Disorders',
    'Kleine-Levin syndrome': 'Sleep-Wake Disorders',
    'sleep apnea': 'Sleep-Wake Disorders',

    # Sexual Dysfunctions
    'erectile dysfunction': 'Sexual Dysfunctions',

    # Gender Dysphoria
    'gender dysphoria': 'Gender Dysphoria',
    'sexual and gender disorder': 'Gender Dysphoria',

    # Disruptive, Impulse-Control, and Conduct Disorders
    'conduct disorder': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'homicidal mania': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'kleptomania': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'oppositional defiant disorder': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'problem gambling': 'Disruptive, Impulse-Control, and Conduct Disorders',

    # Substance-Related and Addictive Disorders
    'alcohol dependence': 'Substance-Related and Addictive Disorders',
    'alcoholism': 'Substance-Related and Addictive Disorders',
    'delirium tremens': 'Substance-Related and Addictive Disorders',
    'non-controlled substance abuse': 'Substance-Related and Addictive Disorders',
    'opioid overdose': 'Substance-Related and Addictive Disorders',
    'opioid use disorder': 'Substance-Related and Addictive Disorders',
    'smoking addiction': 'Substance-Related and Addictive Disorders',
    'substance dependence': 'Substance-Related and Addictive Disorders',
    'substance use disorder': 'Substance-Related and Addictive Disorders',

    # Neurocognitive Disorders
    'chronic traumatic encephalopathy': 'Neurocognitive Disorders',
    'Creutzfeldt-Jakob disease': 'Neurocognitive Disorders',
    'delirium': 'Neurocognitive Disorders',
    'dementia': 'Neurocognitive Disorders',
    'dementia with Lewy bodies': 'Neurocognitive Disorders',
    'frontotemporal dementia': 'Neurocognitive Disorders',
    'Huntington\'s disease': 'Neurocognitive Disorders',
    'Lewy body dementia': 'Neurocognitive Disorders',
    'neurosyphilis': 'Neurocognitive Disorders',
    'post-concussion syndrome': 'Neurocognitive Disorders',
    'progressive supranuclear palsy': 'Neurocognitive Disorders',
    'vascular dementia': 'Neurocognitive Disorders',

    # Paraphilic Disorders
    'chronophilia': 'Paraphilic Disorders',
    'coprophilia': 'Paraphilic Disorders',
    'gerontophilia': 'Paraphilic Disorders',
    'necrophilia': 'Paraphilic Disorders',
    'pedophilia': 'Paraphilic Disorders',
    'sexual sadism disorder': 'Paraphilic Disorders',
    'urolagnia': 'Paraphilic Disorders',
    'zoosadism': 'Paraphilic Disorders',

    # Personality Disorders
    'antisocial personality disorder': 'Personality Disorders',
    'borderline personality disorder': 'Personality Disorders',
    'emotionally unstable personality disorder': 'Personality Disorders',
    'histrionic personality disorder': 'Personality Disorders',
    'narcissistic personality disorder': 'Personality Disorders',
    'paranoid personality disorder': 'Personality Disorders',
    'personality disorder': 'Personality Disorders',
    'personality disorder not otherwise specified': 'Personality Disorders',

    # Communication Disorders
    'aphasia': 'Communication Disorders',
    'deaf-mute': 'Communication Disorders',
    'lisp': 'Communication Disorders',
    'muteness': 'Communication Disorders',
    'primary progressive aphasia': 'Communication Disorders',
    'selective mutism': 'Communication Disorders',
    'speech disorder': 'Communication Disorders',
    'stuttering': 'Communication Disorders',

    # Elimination Disorders
    'nocturnal enuresis': 'Elimination Disorders',

    # Other Conditions
    'fetal alcohol syndrome': 'Other Medical Conditions',
    'focal dermal hypoplasia': 'Other Medical Conditions',
    'hospitalism': 'Other Medical Conditions',
    'mental illness': 'Other Conditions',
    'neurasthenia': 'Other Conditions',
    'paranoia': 'Other Conditions',
    'prosopagnosia': 'Other Conditions'
}
def clean_label(label):
    """Clean label by removing @en and trimming"""
    if pd.isna(label):
        return ''
    return label.replace('@en', '').strip()

def get_dsm5_category(disorder):
    """Get DSM-5 category for a disorder"""
    if pd.isna(disorder):
        return ''
    clean_disorder = clean_label(disorder)
    return dsm5_mapping.get(clean_disorder, 'Uncategorized')

# Read and process the original TSV file
df = pd.read_csv('non_creativi_full_info.tsv', sep='\t')

# Clean disorder labels and add DSM-5 categories
df['clean_disorder'] = df['?disorderLabel'].apply(clean_label)
df['dsm-5'] = df['?disorderLabel'].apply(get_dsm5_category)

# Save the enhanced dataset
df.to_csv('non_creativi_full_info_with_dsm5.tsv', sep='\t', index=False)

def create_category_summary(df_all, df_unique):
    """Create summary using both all occurrences and unique people counts"""
    # Count raw occurrences per disorder
    disorder_counts_all = df_all['clean_disorder'].value_counts()
    disorder_counts_unique = df_unique['clean_disorder'].value_counts()
    
    # Create reverse mapping (category to disorders)
    category_to_disorders = {}
    for disorder, category in dsm5_mapping.items():
        if category not in category_to_disorders:
            category_to_disorders[category] = []
        category_to_disorders[category].append(disorder)
    
    # Sort categories and their disorders
    summary = {}
    for category in sorted(category_to_disorders.keys()):
        summary[category] = sorted(category_to_disorders[category])

    # Save summary to file
    with open('non_creativi_dsm5_categories_summary.txt', 'w', encoding='utf-8') as f:
        f.write("DSM-5 CATEGORIES SUMMARY\n")
        f.write("=" * 50 + "\n\n")
        
        # Count occurrences per category
        category_counts_all = df_all['dsm-5'].value_counts()
        category_counts_unique = df_unique['dsm-5'].value_counts()
        
        f.write("OVERALL STATISTICS\n")
        f.write("-" * 30 + "\n")
        f.write(f"Total disorder occurrences: {len(df_all)}\n")
        f.write(f"Total unique individuals: {len(df_unique)}\n")
        f.write(f"Total DSM-5 categories: {len(summary)}\n\n")

        # Write counts for both all occurrences and unique individuals
        f.write("CATEGORY DISTRIBUTION\n")
        f.write("-" * 30 + "\n")
        for category in sorted(summary.keys()):
            count_all = category_counts_all.get(category, 0)
            count_unique = category_counts_unique.get(category, 0)
            if count_all > 0:
                f.write(f"{category}:\n")
                f.write(f"  Total occurrences: {count_all}\n")
                f.write(f"  Unique individuals: {count_unique}\n")
        f.write("\n")

        # Write detailed category contents with both counts
        f.write("DETAILED CATEGORY CONTENTS AND COUNTS\n")
        f.write("-" * 30 + "\n")
        
        for category, disorders in summary.items():
            count_all = category_counts_all.get(category, 0)
            count_unique = category_counts_unique.get(category, 0)
            if count_all > 0:
                f.write(f"\n{category}:\n")
                f.write(f"Total occurrences: {count_all} | Unique individuals: {count_unique}\n")
                
                for disorder in disorders:
                    clean_disorder = clean_label(disorder)
                    count_all_disorder = disorder_counts_all.get(clean_disorder, 0)
                    count_unique_disorder = disorder_counts_unique.get(clean_disorder, 0)
                    if count_all_disorder > 0:
                        f.write(f"  - {disorder}:\n")
                        f.write(f"    Occurrences: {count_all_disorder} | Unique individuals: {count_unique_disorder}\n")

    return summary

# Create dataset with unique individuals
df_unique = df.drop_duplicates(subset=['?nonCreativePerson'])

# Create the summary using both datasets
summary = create_category_summary(df, df_unique)

# Save distribution counts to CSV
dsm5_distribution_all = df['dsm-5'].value_counts()
dsm5_distribution_unique = df_unique['dsm-5'].value_counts()

# Create a DataFrame with both counts
distribution_df = pd.DataFrame({
    'all_occurrences': dsm5_distribution_all,
    'unique_individuals': dsm5_distribution_unique
})
distribution_df.to_csv('non_creatives_dsm5_counts.csv')

# Print detailed contents
print("\nDETAILED CATEGORY CONTENTS AND COUNTS")
print("-" * 30)

for category, disorders in sorted(summary.items()):
    category_count_all = df['dsm-5'].value_counts().get(category, 0)
    category_count_unique = df_unique['dsm-5'].value_counts().get(category, 0)
    
    if category_count_all > 0:
        print(f"\n{category}:")
        print(f"Total occurrences: {category_count_all} | Unique individuals: {category_count_unique}")
        
        for disorder in disorders:
            clean_disorder = clean_label(disorder)
            count_all = df['clean_disorder'].value_counts().get(clean_disorder, 0)
            count_unique = df_unique['clean_disorder'].value_counts().get(clean_disorder, 0)
            if count_all > 0:
                print(f"  - {disorder}:")
                print(f"    Occurrences: {count_all} | Unique individuals: {count_unique}")
# Out:
# DETAILED CATEGORY CONTENTS AND COUNTS
# ------------------------------
#
# Anxiety Disorders:
# Total occurrences: 27 | Unique individuals: 9
#   - anxiety:
#     Occurrences: 1 | Unique individuals: 1
#   - anxiety disorder:
#     Occurrences: 9 | Unique individuals: 4
#   - generalized anxiety disorder:
#     Occurrences: 6 | Unique individuals: 0
#   - nosophobia:
#     Occurrences: 1 | Unique individuals: 1
#   - panic attack:
#     Occurrences: 5 | Unique individuals: 0
#   - panic disorder:
#     Occurrences: 2 | Unique individuals: 2
#   - social anxiety disorder:
#     Occurrences: 2 | Unique individuals: 0
#   - triskaidekaphobia:
#     Occurrences: 1 | Unique individuals: 1
#
# Bipolar and Related Disorders:
# Total occurrences: 238 | Unique individuals: 120
#   - bipolar I disorder:
#     Occurrences: 1 | Unique individuals: 1
#   - bipolar II disorder:
#     Occurrences: 4 | Unique individuals: 1
#   - bipolar disorder:
#     Occurrences: 233 | Unique individuals: 118
#
# ...

# %% [markdown]
# Here are the macro-disorders ranked by their percentage of total unique individuals (775 total):
#
# Neurodevelopmental Disorders: 253 (32.6%)\
# Bipolar and Related Disorders: 120 (15.5%)\
# Communication Disorders: 91 (11.7%)\
# Neurocognitive Disorders: 71 (9.2%)\
# Depressive Disorders: 46 (5.9%)\
# Personality Disorders: 39 (5.0%)\
# Substance-Related and Addictive Disorders: 37 (4.8%)\
# Schizophrenia Spectrum and Other Psychotic Disorders: 33 (4.3%)\
# Trauma and Stressor-Related Disorders: 18 (2.3%)\
# Paraphilic Disorders: 17 (2.2%)\
# Other Conditions: 13 (1.7%)\
# Anxiety Disorders: 9 (1.2%)\
# Feeding and Eating Disorders: 7 (0.9%)\
# Disruptive, Impulse-Control, and Conduct Disorders: 3 (0.4%)\
# Obsessive-Compulsive and Related Disorders: 3 (0.4%)\
# Other Medical Conditions: 3 (0.4%)\
# Sexual Dysfunctions: 3 (0.4%)\
# Sleep-Wake Disorders: 3 (0.4%)\
# Dissociative Disorders: 2 (0.3%)\
# Somatic Symptom and Related Disorders: 2 (0.3%)\
# Elimination Disorders: 1 (0.1%)\
# Gender Dysphoria: 1 (0.1%)
#
# The top three categories (Neurodevelopmental, Bipolar, and Communication Disorders) account for nearly 60% of all unique individuals in the dataset.

# %% [markdown]
# ### Breakdown on neurodevelopmental:
# dyslexia (103 individuals, 250 occurrences)\
# autism (63 individuals, 138 occurrences)\
# Asperger syndrome (36 individuals, 79 occurrences)\
# attention deficit hyperactivity disorder (27 individuals, 64 occurrences)\
# intellectual disability (9 individuals, 18 occurrences)\
# autism spectrum disorder (7 individuals, 19 occurrences)\
# Tourette syndrome (4 individuals, 9 occurrences)\
# developmental coordination disorder (1 individual, 3 occurrences)\
# disability affecting intellectual abilities (1 individual, 1 occurrence)\
# feeble-minded (1 individual, 2 occurrences)\
# high-functioning autism (1 individual, 3 occurrences)\
# pervasive developmental disorder not otherwise specified (0 individuals, 4 occurrences)

# %% [markdown]
# # Comparison
# ### Key differences between the populations:
#
# ### Total Sample Size:
#
#
# Creative population: 1,483 individuals\
# Non-creative population: 775 individuals
#
#
# ### Major Differences:
#
#
# Neurodevelopmental Disorders: Significantly higher in creatives (43.6% vs 32.6%)
#
# Notable insight: While both populations show high rates of dyslexia and autism, ADHD shows a marked difference in prevalence (8.7% in creatives vs 3.5% in non-creatives)
#
#
# Communication Disorders: Higher in non-creatives (11.7% vs 7.3%)\
# Neurocognitive Disorders: Notably higher in non-creatives (9.2% vs 3.2%)\
# Personality Disorders: Higher in non-creatives (5.0% vs 1.5%)\
#
#
# ### Similar Rates:
#
#
# Bipolar Disorders: Similar rates (16.7% creative vs 15.5% non-creative)\
# Substance-Related Disorders: Similar rates (4.0% vs 4.8%)\
# Schizophrenia Spectrum: Similar rates (5.4% vs 4.3%)
#
#
# ### Additional Observations:
#
#
# The creative population shows a stronger concentration in neurodevelopmental disorders\
# The non-creative population shows a more even distribution across different disorder categories\
# Both populations show similar patterns in bipolar disorders, suggesting this condition may not be specifically linked to creativity\
# The non-creative population shows higher rates in disorders that affect cognitive and personality functions

# %% [markdown]
# # Total people affected by mental disorders.

# %%
SELECT  (COUNT (DISTINCT ?person) as ?peopleCount) 
WHERE { 
  # ?person wdt:P31 wd:Q5. 
  # ?person wdt:P1050 ?disorder.
  # ?disorder wdt:P279+ wd:Q12135.
}

# %% [markdown]
# 2,387

# %% [markdown]
# # Total people for disorder

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT (COUNT (DISTINCT ?person) as ?peopleCount) ?disorderLabel
WHERE { 
  # ?person wdt:P31 wd:Q5. 
  # ?person wdt:P1050 ?disorder.
  # ?disorder rdfs:label ?disorderLabel.
  # ?disorder wdt:P279+ wd:Q12135.
  FILTER (lang(?disorderLabel) = "en")
} 
GROUP BY ?disorderLabel  
ORDER BY DESC (?peopleCount)

# %% [markdown]
# Results saved in 'totPeoplePerDisorder.tsv'

# %% [markdown]
# # Print all unique disorders

# %%
import pandas as pd

# Read the TSV file
df = pd.read_csv('totPeoplePerDisoder.tsv', sep='\t')

# Extract unique values from ?disorderLabel column, remove '@en' suffix and sort
unique_disorders = sorted(df['?disorderLabel'].str.replace('@en', '').str.strip().unique())

# Print each unique disorder
for disorder in unique_disorders:
    print(disorder)
# Out:
# Alcohol dementia
# Asperger syndrome
# Attention deficit hyperactivity disorder predominantly inattentive
# Clinical lycanthropy
# Cotard delusion
# Creutzfeldt-Jakob disease
# Diogenes syndrome
# Hallermann-Streiff syndrome
# Huntington's disease
# Joubert syndrome
# Kleine-Levin syndrome
# Korsakoff's syndrome
# Language-based learning disability
# Lewy body dementia
# Muscle dysmorphia
# Münchausen syndrome
# Non-Verbal Learning Disorder
# REM sleep behavior disorder
# Tourette syndrome
# Wiedemann-Rautenstrauch syndrome
# Williams-Beuren syndrome
# Wilson disease
# XXXY syndrome
# adjustment disorder
# agoraphobia
# alcohol abuse
# alcohol dependence
# alcohol-related neurodevelopmental disorder
# alcoholic hepatitis
# alcoholism
# amnesia
# anorexia
# anorexia nervosa
# anterograde amnesia
# antisocial personality disorder
# anxiety
# anxiety disorder
# aphasia
# aphonia
# apperceptive agnosia
# attention deficit hyperactivity disorder
# atypical autism
# autism
# ...

# %% [markdown]
# ## Add DSM-5 category to tsv

# %%
import pandas as pd

# Our DSM-5 mapping (same as before)
dsm5_mapping = {
    # Neurodevelopmental Disorders
    'Asperger syndrome': 'Neurodevelopmental Disorders',
    'Attention deficit hyperactivity disorder predominantly inattentive': 'Neurodevelopmental Disorders',
    'attention deficit hyperactivity disorder': 'Neurodevelopmental Disorders',
    'autism': 'Neurodevelopmental Disorders',
    'autism spectrum disorder': 'Neurodevelopmental Disorders',
    'atypical autism': 'Neurodevelopmental Disorders',
    'developmental coordination disorder': 'Neurodevelopmental Disorders',
    'disability affecting intellectual abilities': 'Neurodevelopmental Disorders',
    'dyscalculia': 'Neurodevelopmental Disorders',
    'dyslexia': 'Neurodevelopmental Disorders',
    'feeble-minded': 'Neurodevelopmental Disorders',
    'high-functioning autism': 'Neurodevelopmental Disorders',
    'intellectual disability': 'Neurodevelopmental Disorders',
    'Language-based learning disability': 'Neurodevelopmental Disorders',
    'learning disability': 'Neurodevelopmental Disorders',
    'mild intellectual disabilty': 'Neurodevelopmental Disorders',
    'Non-Verbal Learning Disorder': 'Neurodevelopmental Disorders',
    'pervasive developmental disorder': 'Neurodevelopmental Disorders',
    'pervasive developmental disorder not otherwise specified': 'Neurodevelopmental Disorders',
    'Tourette syndrome': 'Neurodevelopmental Disorders',

    # Communication Disorders
    'aphasia': 'Communication Disorders',
    'aphonia': 'Communication Disorders',
    'deaf-mute': 'Communication Disorders',
    'lisp': 'Communication Disorders',
    'muteness': 'Communication Disorders',
    'primary progressive aphasia': 'Communication Disorders',
    'selective mutism': 'Communication Disorders',
    'speech disorder': 'Communication Disorders',
    'stuttering': 'Communication Disorders',

    # Schizophrenia Spectrum and Other Psychotic Disorders
    'Cotard delusion': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'delusion': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'disorganized schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'grandiose delusions': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'hallucination': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'paranoid delusion': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'paranoid schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizoaffective disorder': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizoid personality disorder': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizophrenia': 'Schizophrenia Spectrum and Other Psychotic Disorders',
    'schizotypal personality disorder': 'Schizophrenia Spectrum and Other Psychotic Disorders',

    # Bipolar and Related Disorders
    'bipolar I disorder': 'Bipolar and Related Disorders',
    'bipolar II disorder': 'Bipolar and Related Disorders',
    'bipolar disorder': 'Bipolar and Related Disorders',

    # Depressive Disorders
    'chronic depressive disorder': 'Depressive Disorders',
    'dysthymic disorder': 'Depressive Disorders',
    'major depressive disorder': 'Depressive Disorders',
    'melancholia': 'Depressive Disorders',
    'mental depression': 'Depressive Disorders',
    'postpartum depression': 'Depressive Disorders',

    # Anxiety Disorders
    'agoraphobia': 'Anxiety Disorders',
    'anxiety': 'Anxiety Disorders',
    'anxiety disorder': 'Anxiety Disorders',
    'claustrophobia': 'Anxiety Disorders',
    'generalized anxiety disorder': 'Anxiety Disorders',
    'nosophobia': 'Anxiety Disorders',
    'panic attack': 'Anxiety Disorders',
    'panic disorder': 'Anxiety Disorders',
    'social anxiety disorder': 'Anxiety Disorders',
    'triskaidekaphobia': 'Anxiety Disorders',

    # Obsessive-Compulsive and Related Disorders
    'body dysmorphic disorder': 'Obsessive-Compulsive and Related Disorders',
    'excoriation disorder': 'Obsessive-Compulsive and Related Disorders',
    'Muscle dysmorphia': 'Obsessive-Compulsive and Related Disorders',
    'obsessive-compulsive disorder': 'Obsessive-Compulsive and Related Disorders',
    'obsessive-compulsive personality disorder': 'Obsessive-Compulsive and Related Disorders',
    'trichotillomania': 'Obsessive-Compulsive and Related Disorders',

    # Trauma and Stressor-Related Disorders
    'adjustment disorder': 'Trauma and Stressor-Related Disorders',
    'combat disorder': 'Trauma and Stressor-Related Disorders',
    'complex post-traumatic stress disorder': 'Trauma and Stressor-Related Disorders',
    'post-traumatic stress disorder': 'Trauma and Stressor-Related Disorders',
    'reactive attachment disorder': 'Trauma and Stressor-Related Disorders',
    'shell shock': 'Trauma and Stressor-Related Disorders',

    # Dissociative Disorders
    'dissociative disorder': 'Dissociative Disorders',
    'dissociative disorder not otherwise specified': 'Dissociative Disorders',
    'dissociative identity disorder': 'Dissociative Disorders',

    # Feeding and Eating Disorders
    'anorexia': 'Feeding and Eating Disorders',
    'anorexia nervosa': 'Feeding and Eating Disorders',
    'binge eating disorder': 'Feeding and Eating Disorders',
    'bulimia nervosa': 'Feeding and Eating Disorders',
    'eating disorder': 'Feeding and Eating Disorders',

    # Sleep-Wake Disorders
    'hypersomnia': 'Sleep-Wake Disorders',
    'insomnia': 'Sleep-Wake Disorders',
    'Kleine-Levin syndrome': 'Sleep-Wake Disorders',
    'narcolepsy': 'Sleep-Wake Disorders',
    'REM sleep behavior disorder': 'Sleep-Wake Disorders',
    'sleep apnea': 'Sleep-Wake Disorders',
    'sleep paralysis': 'Sleep-Wake Disorders',
    'sleepwalking': 'Sleep-Wake Disorders',

    # Sexual Dysfunctions
    'erectile dysfunction': 'Sexual Dysfunctions',

    # Gender Dysphoria
    'gender dysphoria': 'Gender Dysphoria',
    'sexual and gender disorder': 'Gender Dysphoria',

    # Elimination Disorders
    'nocturnal enuresis': 'Elimination Disorders',

    # Disruptive, Impulse-Control, and Conduct Disorders
    'conduct disorder': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'kleptomania': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'oppositional defiant disorder': 'Disruptive, Impulse-Control, and Conduct Disorders',
    'pathological lying': 'Disruptive, Impulse-Control, and Conduct Disorders',

    # Substance-Related and Addictive Disorders
    'Alcohol dementia': 'Substance-Related and Addictive Disorders',
    'alcohol abuse': 'Substance-Related and Addictive Disorders',
    'alcohol dependence': 'Substance-Related and Addictive Disorders',
    'alcoholic hepatitis': 'Substance-Related and Addictive Disorders',
    'alcoholism': 'Substance-Related and Addictive Disorders',
    'benzodiazepine withdrawal syndrome': 'Substance-Related and Addictive Disorders',
    'cannabis dependence': 'Substance-Related and Addictive Disorders',
    'cocaine dependence': 'Substance-Related and Addictive Disorders',
    'fetal alcohol syndrome': 'Substance-Related and Addictive Disorders',
    'hallucinogen persisting perception disorder': 'Substance-Related and Addictive Disorders',
    'heroin dependence': 'Substance-Related and Addictive Disorders',
    'ketamine dependence': 'Substance-Related and Addictive Disorders',
    'nicotine dependence': 'Substance-Related and Addictive Disorders',
    'non-controlled substance abuse': 'Substance-Related and Addictive Disorders',
    'opioid overdose': 'Substance-Related and Addictive Disorders',
    'opioid use disorder': 'Substance-Related and Addictive Disorders',
    'problem gambling': 'Substance-Related and Addictive Disorders',
    'smoking addiction': 'Substance-Related and Addictive Disorders',
    'substance dependence': 'Substance-Related and Addictive Disorders',
    'substance use disorder': 'Substance-Related and Addictive Disorders',

    # Neurocognitive Disorders
    'amnesia': 'Neurocognitive Disorders',
    'anterograde amnesia': 'Neurocognitive Disorders',
    'chronic traumatic encephalopathy': 'Neurocognitive Disorders',
    'Creutzfeldt-Jakob disease': 'Neurocognitive Disorders',
    'dementia': 'Neurocognitive Disorders',
    'dementia with Lewy bodies': 'Neurocognitive Disorders',
    'frontotemporal degeneration with dementia': 'Neurocognitive Disorders',
    'frontotemporal dementia': 'Neurocognitive Disorders',
    'Huntington\'s disease': 'Neurocognitive Disorders',
    'Korsakoff\'s syndrome': 'Neurocognitive Disorders',
    'Lewy body dementia': 'Neurocognitive Disorders',
    'memory disorder': 'Neurocognitive Disorders',
    'neurosyphilis': 'Neurocognitive Disorders',
    'post-concussion syndrome': 'Neurocognitive Disorders',
    'progressive supranuclear palsy': 'Neurocognitive Disorders',
    'retrograde amnesia': 'Neurocognitive Disorders',
    'vascular dementia': 'Neurocognitive Disorders',

    # Personality Disorders
    'antisocial personality disorder': 'Personality Disorders',
    'borderline personality disorder': 'Personality Disorders',
    'dependent personality disorder': 'Personality Disorders',
    'emotionally unstable personality disorder': 'Personality Disorders',
    'histrionic personality disorder': 'Personality Disorders',
    'narcissistic personality disorder': 'Personality Disorders',
    'organic personality disorder': 'Personality Disorders',
    'paranoid personality disorder': 'Personality Disorders',
    'personality disorder': 'Personality Disorders',
    'personality disorder not otherwise specified': 'Personality Disorders',

    # Paraphilic Disorders
    'chronophilia': 'Paraphilic Disorders',
    'coprophilia': 'Paraphilic Disorders',
    'gerontophilia': 'Paraphilic Disorders',
    'necrophilia': 'Paraphilic Disorders',
    'pedophilia': 'Paraphilic Disorders',
    'sexual sadism disorder': 'Paraphilic Disorders',
    'urolagnia': 'Paraphilic Disorders',
    'zoosadism': 'Paraphilic Disorders',

    # Other Medical Conditions
    'Hallermann-Streiff syndrome': 'Other Medical Conditions',
    'Joubert syndrome': 'Other Medical Conditions',
    'lipoid proteinosis': 'Other Medical Conditions',
    'myotonic dystrophy': 'Other Medical Conditions',
    'Wiedemann-Rautenstrauch syndrome': 'Other Medical Conditions',
    'Williams-Beuren syndrome': 'Other Medical Conditions',
    'Wilson disease': 'Other Medical Conditions',
    'XXXY syndrome': 'Other Medical Conditions',

    # Other/Unspecified Disorders
    'apperceptive agnosia': 'Other/Unspecified Disorders',
    'autistic savant': 'Other/Unspecified Disorders',
    'boanthropy': 'Other/Unspecified Disorders',
    'borderline intellectual functioning': 'Other/Unspecified Disorders',
    'Clinical lycanthropy': 'Other/Unspecified Disorders',
    'coprolalia': 'Other/Unspecified Disorders',
    'corticobasal degeneration': 'Other/Unspecified Disorders',
    'delirium': 'Other/Unspecified Disorders',
    'delirium tremens': 'Other/Unspecified Disorders',
    'Diogenes syndrome': 'Other/Unspecified Disorders',
    'emotional disorder': 'Other/Unspecified Disorders',
    'factitious disorder imposed on another': 'Other/Unspecified Disorders',
    'focal dermal hypoplasia': 'Other/Unspecified Disorders',
    'foreign accent syndrome': 'Other/Unspecified Disorders',
    'homicidal mania': 'Other/Unspecified Disorders',
    'hospitalism': 'Other/Unspecified Disorders',
    'hyperactivity': 'Other/Unspecified Disorders',
    'hyperlexia': 'Other/Unspecified Disorders',
    'hyperthymesia': 'Other/Unspecified Disorders',
    'mental breakdown': 'Other/Unspecified Disorders',
    'mental illness': 'Other/Unspecified Disorders',
    'Münchausen syndrome': 'Other/Unspecified Disorders',
    'neurasthenia': 'Other/Unspecified Disorders',
    'oral galvanism': 'Other/Unspecified Disorders',
    'paranoia': 'Other/Unspecified Disorders',
    'prosopagnosia': 'Other/Unspecified Disorders',
    'pseudobulbar affect': 'Other/Unspecified Disorders',
    'savant syndrome': 'Other/Unspecified Disorders',
    'school refusal': 'Other/Unspecified Disorders'

}

def process_tsv(input_file, output_file):
    # Read the TSV file
    df = pd.read_csv(input_file, sep='\t')
    
    # Clean up the disorder labels by removing "@en" and quotes
    df['?disorderLabel'] = df['?disorderLabel'].str.replace('"', '').str.replace('@en', '').str.strip()
    
    # Add the DSM-5 category using the mapping
    df['dsm-5'] = df['?disorderLabel'].map(dsm5_mapping)
    
    # Save to new TSV file
    df.to_csv(output_file, sep='\t', index=False)
    
    return df


result_df = process_tsv('totPeoplePerDisoder.tsv', 'totPeoplePerDisorderWithDsm.tsv')

# %%
import pandas as pd

# Read the TSV file
df = pd.read_csv('totPeoplePerDisorderWithDsm.tsv', sep='\t')

# Group by DSM-5 category and calculate totals
grouped = df.groupby('dsm-5')

# Sort the groups by total count in descending order
category_totals = df.groupby('dsm-5')['?peopleCount'].sum().sort_values(ascending=False)

# For each category
for category in category_totals.index:
    # Get disorders for this category
    category_disorders = df[df['dsm-5'] == category].sort_values('?peopleCount', ascending=False)
    
    # Print category name with total
    print(f"\n{category} ({category_totals[category]})")
    
    # Print each disorder in the category with its count
    for _, row in category_disorders.iterrows():
        print(f"* {row['?disorderLabel']} ({row['?peopleCount']})")
# Out:
# Neurodevelopmental Disorders (1093)
# * autism (347)
# * dyslexia (307)
# * attention deficit hyperactivity disorder (182)
# * Asperger syndrome (144)
# * Tourette syndrome (31)
# * autism spectrum disorder (25)
# * intellectual disability (24)
# * developmental coordination disorder (11)
# * Attention deficit hyperactivity disorder predominantly inattentive (7)
# * dyscalculia (3)
# * pervasive developmental disorder not otherwise specified (3)
# * pervasive developmental disorder (1)
# * atypical autism (1)
# * mild intellectual disabilty (1)
# * feeble-minded (1)
# * learning disability (1)
# * Language-based learning disability (1)
# * high-functioning autism (1)
# * disability affecting intellectual abilities (1)
# * Non-Verbal Learning Disorder (1)
#
# Bipolar and Related Disorders (395)
# * bipolar disorder (386)
# * bipolar II disorder (7)
# * bipolar I disorder (2)
#
# Communication Disorders (233)
# * stuttering (190)
# * deaf-mute (21)
# * muteness (8)
# * aphasia (5)
# ...

# %% [markdown]
# Neurodevelopmental Disorders: 1,093 (39.3% of total)\
# Bipolar and Related Disorders: 395 (14.2%)\
# Communication Disorders: 233 (8.4%)\
# Depressive Disorders: 204 (7.3%)\
# Schizophrenia Spectrum and Other Psychotic Disorders: 171 (6.2%)\
# Neurocognitive Disorders: 132 (4.7%)\
# Substance-Related and Addictive Disorders: 124 (4.5%)\
# Personality Disorders: 93 (3.3%)\
# Other/Unspecified Disorders: 68 (2.4%)\
# Obsessive-Compulsive and Related Disorders: 60 (2.2%)\
# Anxiety Disorders: 50 (1.8%)\
# Trauma and Stressor-Related Disorders: 49 (1.8%)\
# Feeding and Eating Disorders: 28 (1.0%)\
# Paraphilic Disorders: 26 (0.9%)\
# Sleep-Wake Disorders: 16 (0.6%)\
# Other Medical Conditions: 10 (0.4%)\
# Dissociative Disorders: 10 (0.4%)\
# Disruptive, Impulse-Control, and Conduct Disorders: 7 (0.3%)\
# Gender Dysphoria: 6 (0.2%)\
# Sexual Dysfunctions: 3 (0.1%)\
# Elimination Disorders: 1 (<0.1%)

# %% [markdown]
# # Gender and disturbs.

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT (COUNT(DISTINCT ?person) as ?peopleCount) ?gender
where {
  # ?person wdt:P31 wd:Q5.
  # ?person wdt:P21 ?gender.
  # ?person wdt:P1050 ?disorder.
  # ?disorder wdt:P279+ wd:Q12135.
}  
GROUP BY ?gender
ORDER BY DESC (?peopleCount)

# %% [markdown]
# Results saved to 'genderDisturbs.tsv'

# %% [markdown]
# # Disturbs across different creative professions

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.sparse import csr_matrix
from statsmodels.sandbox.stats.multicomp import multipletests

def preprocess_labels(data):
    """
    Remove '@en' suffix from occupation and disorder labels
    """
    data = data.copy()
    data['?occupationLabel'] = data['?occupationLabel'].str.replace('@en', '')
    data['?disorderLabel'] = data['?disorderLabel'].str.replace('@en', '')
    return data

def analyze_disorder_occupation(data, alpha=0.05):
    """
    Analyzes associations between mental disorders and occupations for Wikidata format data.
    
    Args:
        data: Pandas DataFrame with '?creativePerson', '?disorderLabel', and '?occupationLabel' columns
        alpha: Significance level (default: 0.05)
    """
    # Preprocess the labels
    data = preprocess_labels(data)
    
    # Create wide-format table
    data_wide = pd.get_dummies(
        data[['?creativePerson', '?disorderLabel']], 
        columns=['?disorderLabel'], 
        prefix='', 
        prefix_sep=''
    ).groupby('?creativePerson').max()
    
    data_wide = data_wide.merge(
        pd.get_dummies(
            data[['?creativePerson', '?occupationLabel']], 
            columns=['?occupationLabel'], 
            prefix='', 
            prefix_sep=''
        ).groupby('?creativePerson').max(), 
        left_index=True, 
        right_index=True
    )
    
    # Create all disorder x occupation pairs
    disorder_cols = data['?disorderLabel'].unique()
    occupation_cols = data['?occupationLabel'].unique()
    all_pairs = [(d, o) for d in disorder_cols for o in occupation_cols]
    
    # Create contingency table
    contingency_data = []
    for disorder, occupation in all_pairs:
        # Count individuals with both disorder and occupation
        both_count = data_wide[
            (data_wide[disorder] == 1) & 
            (data_wide[occupation] == 1)
        ].shape[0]
        
        # Count individuals with disorder but not occupation
        disorder_only = data_wide[
            (data_wide[disorder] == 1) & 
            (data_wide[occupation] == 0)
        ].shape[0]
        
        # Count individuals with occupation but not disorder
        occupation_only = data_wide[
            (data_wide[disorder] == 0) & 
            (data_wide[occupation] == 1)
        ].shape[0]
        
        # Count individuals with neither
        neither = data_wide[
            (data_wide[disorder] == 0) & 
            (data_wide[occupation] == 0)
        ].shape[0]
        
        contingency_data.append([
            disorder, 
            occupation, 
            both_count, 
            disorder_only, 
            occupation_only, 
            neither
        ])
    
    contingency_df = pd.DataFrame(
        contingency_data,
        columns=['Disorder', 'Occupation', 'Both', 'DisorderOnly', 'OccupationOnly', 'Neither']
    )
    
    # Create pivot table for chi-square test
    contingency_table = contingency_df.pivot_table(
        index='Disorder',
        columns='Occupation',
        values='Both',
        fill_value=0
    )
    
    # Perform chi-square test
    chi2, p, dof, expected = stats.chi2_contingency(contingency_table)
    
    # Calculate association measures
    n = contingency_table.sum().sum()
    phi2 = chi2 / n
    r, k = contingency_table.shape
    phi2corr = max(0, phi2 - ((k-1) * (r-1)) / (n-1))
    rcorr = r - ((r-1)**2) / (n-1)
    kcorr = k - ((k-1)**2) / (n-1)
    cramers_v = np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))
    
    # Find significant pairs if overall test is significant
    significant_pairs = []
    if p < alpha:
        p_value_matrix = np.ones((len(disorder_cols), len(occupation_cols)))
        
        for i, disorder in enumerate(disorder_cols):
            for j, occupation in enumerate(occupation_cols):
                # Get 2x2 contingency table for this pair
                both = contingency_table.loc[disorder, occupation]
                disorder_only = contingency_df[
                    (contingency_df['Disorder'] == disorder) & 
                    (contingency_df['Occupation'] == occupation)
                ]['DisorderOnly'].iloc[0]
                occupation_only = contingency_df[
                    (contingency_df['Disorder'] == disorder) & 
                    (contingency_df['Occupation'] == occupation)
                ]['OccupationOnly'].iloc[0]
                neither = contingency_df[
                    (contingency_df['Disorder'] == disorder) & 
                    (contingency_df['Occupation'] == occupation)
                ]['Neither'].iloc[0]
                
                sub_table = np.array([
                    [both, disorder_only],
                    [occupation_only, neither]
                ])
                
                try:
                    _, p_val, _, _ = stats.chi2_contingency(sub_table)
                except ValueError:
                    p_val = 1.0
                    
                p_value_matrix[i, j] = p_val
        
        # FDR correction
        reject, pvals_corrected, _, _ = multipletests(
            p_value_matrix.flatten(),
            alpha=alpha,
            method='fdr_bh'
        )
        pvals_corrected_matrix = pvals_corrected.reshape(p_value_matrix.shape)
        
        # Collect significant pairs
        k = 0
        for i, disorder in enumerate(disorder_cols):
            for j, occupation in enumerate(occupation_cols):
                if reject[k]:
                    significant_pairs.append({
                        "disorder": disorder,
                        "occupation": occupation,
                        "original_p": p_value_matrix[i, j],
                        "adjusted_p": pvals_corrected_matrix[i, j]
                    })
                k += 1
    
    return {
        "chi2_results": {
            "statistic": chi2,
            "p_value": p,
            "dof": dof
        },
        "cramers_v": cramers_v,
        "significant_pairs": significant_pairs
    }

# Example usage
try:
    # Read the TSV file
    data = pd.read_csv('creativi_full_info_with_dsm5.tsv', sep='\t')
    
    # Run the analysis
    results = analyze_disorder_occupation(data)
    
    # Print results
    print("\nChi-square test results:")
    print(f"Statistic: {results['chi2_results']['statistic']:.2f}")
    print(f"P-value: {results['chi2_results']['p_value']:.4f}")
    print(f"Degrees of freedom: {results['chi2_results']['dof']}")
    print(f"\nCramer's V: {results['cramers_v']:.4f}")
    
    if results["significant_pairs"]:
        print("\nSignificant Disorder-Occupation Pairs (FDR corrected):")
        for pair in sorted(results["significant_pairs"], 
                         key=lambda x: x['adjusted_p']):
            print(f"  {pair['disorder']} - {pair['occupation']}:")
            print(f"    Original p={pair['original_p']:.4f}")
            print(f"    Adjusted p={pair['adjusted_p']:.4f}")
    else:
        print("\nNo significant disorder-occupation pairs found after FDR correction.")
        
except FileNotFoundError:
    print("Error: TSV file not found. Make sure the file exists and the path is correct.")
except pd.errors.ParserError:
    print("Error: Could not parse the TSV file. Check for formatting issues.")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Chi-square test results:
# Statistic: 34902.73
# P-value: 0.0000
# Degrees of freedom: 22692
#
# Cramer's V: 0.1422
#
# Significant Disorder-Occupation Pairs (FDR corrected):
#   pseudobulbar affect - digital artist:
#     Original p=0.0000
#     Adjusted p=0.0000
#   alcohol abuse - street musician:
#     Original p=0.0000
#     Adjusted p=0.0000
#   neurasthenia - organist:
#     Original p=0.0000
#     Adjusted p=0.0000
#   foreign accent syndrome - drafter:
#     Original p=0.0000
#     Adjusted p=0.0000
#   cannabis dependence - djembe player:
#     Original p=0.0000
#     Adjusted p=0.0000
#   cannabis dependence - roleplayer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   alcoholic hepatitis - religious writer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   opioid use disorder - pop singer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   heroin dependence - rock singer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   deaf-mute - painter:
# ...

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.sparse import csr_matrix
from statsmodels.sandbox.stats.multicomp import multipletests

def preprocess_labels(data):
    """
    Remove '@en' suffix from occupation and disorder labels
    """
    data = data.copy()
    data['?occupationLabel'] = data['?occupationLabel'].str.replace('@en', '')
    data['?disorderLabel'] = data['?disorderLabel'].str.replace('@en', '')
    return data

def theils_u(x, y):
    """
    Calculate Theil's U statistic (uncertainty coefficient).
    """
    s_xy = stats.contingency.crosstab(x, y)[1]
    sum_s_xy = np.sum(s_xy)
    
    py = np.sum(s_xy, axis=0) / sum_s_xy
    hx = -np.sum(py * np.log(py))  # Entropy of Y
    
    s_y = np.sum(s_xy, axis=0)
    s_x = np.sum(s_xy, axis=1)
    
    ps_x = s_x / sum_s_xy
    ps_y = s_y / sum_s_xy
    anti_ps_y = 1 - ps_y
    
    conditional_entropy = 0
    for iy in range(0, ps_y.size):
        for ix in range(0, ps_x.size):
            if s_xy[ix, iy] != 0:
                p_xy = s_xy[ix, iy] / sum_s_xy
                conditional_entropy += p_xy * np.log(p_xy/ps_y[iy])
    
    conditional_entropy = -conditional_entropy
    
    if hx == 0:
        theil_u = 0
    else:
        theil_u = (hx - conditional_entropy) / hx
        
    return theil_u

def analyze_disorder_occupation(data, alpha=0.05):
    """
    Analyzes associations between mental disorders and occupations for Wikidata format data.
    """
    # Preprocess the labels
    data = preprocess_labels(data)
    
    # Calculate Theil's U before any transformations
    theils_u_value = theils_u(data['?disorderLabel'], data['?occupationLabel'])
    
    # Create wide-format table
    data_wide = pd.get_dummies(
        data[['?creativePerson', '?disorderLabel']], 
        columns=['?disorderLabel'], 
        prefix='', 
        prefix_sep=''
    ).groupby('?creativePerson').max()
    
    data_wide = data_wide.merge(
        pd.get_dummies(
            data[['?creativePerson', '?occupationLabel']], 
            columns=['?occupationLabel'], 
            prefix='', 
            prefix_sep=''
        ).groupby('?creativePerson').max(), 
        left_index=True, 
        right_index=True
    )
    
    # Create all disorder x occupation pairs
    disorder_cols = data['?disorderLabel'].unique()
    occupation_cols = data['?occupationLabel'].unique()
    all_pairs = [(d, o) for d in disorder_cols for o in occupation_cols]
    
    # Create contingency table
    contingency_data = []
    for disorder, occupation in all_pairs:
        # Count individuals with both disorder and occupation
        both_count = data_wide[
            (data_wide[disorder] == 1) & 
            (data_wide[occupation] == 1)
        ].shape[0]
        
        # Count individuals with disorder but not occupation
        disorder_only = data_wide[
            (data_wide[disorder] == 1) & 
            (data_wide[occupation] == 0)
        ].shape[0]
        
        # Count individuals with occupation but not disorder
        occupation_only = data_wide[
            (data_wide[disorder] == 0) & 
            (data_wide[occupation] == 1)
        ].shape[0]
        
        # Count individuals with neither
        neither = data_wide[
            (data_wide[disorder] == 0) & 
            (data_wide[occupation] == 0)
        ].shape[0]
        
        contingency_data.append([
            disorder, 
            occupation, 
            both_count, 
            disorder_only, 
            occupation_only, 
            neither
        ])
    
    contingency_df = pd.DataFrame(
        contingency_data,
        columns=['Disorder', 'Occupation', 'Both', 'DisorderOnly', 'OccupationOnly', 'Neither']
    )
    
    # Create pivot table for chi-square test
    contingency_table = contingency_df.pivot_table(
        index='Disorder',
        columns='Occupation',
        values='Both',
        fill_value=0
    )
    
    # Perform chi-square test
    chi2, p, dof, expected = stats.chi2_contingency(contingency_table)
    
    # Calculate association measures
    n = contingency_table.sum().sum()
    phi2 = chi2 / n
    r, k = contingency_table.shape
    phi2corr = max(0, phi2 - ((k-1) * (r-1)) / (n-1))
    rcorr = r - ((r-1)**2) / (n-1)
    kcorr = k - ((k-1)**2) / (n-1)
    cramers_v = np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))
    
    # Find significant pairs if overall test is significant
    significant_pairs = []
    if p < alpha:
        p_value_matrix = np.ones((len(disorder_cols), len(occupation_cols)))
        
        for i, disorder in enumerate(disorder_cols):
            for j, occupation in enumerate(occupation_cols):
                # Get 2x2 contingency table for this pair
                both = contingency_table.loc[disorder, occupation]
                disorder_only = contingency_df[
                    (contingency_df['Disorder'] == disorder) & 
                    (contingency_df['Occupation'] == occupation)
                ]['DisorderOnly'].iloc[0]
                occupation_only = contingency_df[
                    (contingency_df['Disorder'] == disorder) & 
                    (contingency_df['Occupation'] == occupation)
                ]['OccupationOnly'].iloc[0]
                neither = contingency_df[
                    (contingency_df['Disorder'] == disorder) & 
                    (contingency_df['Occupation'] == occupation)
                ]['Neither'].iloc[0]
                
                sub_table = np.array([
                    [both, disorder_only],
                    [occupation_only, neither]
                ])
                
                try:
                    _, p_val, _, _ = stats.chi2_contingency(sub_table)
                except ValueError:
                    p_val = 1.0
                    
                p_value_matrix[i, j] = p_val
        
        # FDR correction
        reject, pvals_corrected, _, _ = multipletests(
            p_value_matrix.flatten(),
            alpha=alpha,
            method='fdr_bh'
        )
        pvals_corrected_matrix = pvals_corrected.reshape(p_value_matrix.shape)
        
        # Collect significant pairs
        k = 0
        for i, disorder in enumerate(disorder_cols):
            for j, occupation in enumerate(occupation_cols):
                if reject[k]:
                    significant_pairs.append({
                        "disorder": disorder,
                        "occupation": occupation,
                        "original_p": p_value_matrix[i, j],
                        "adjusted_p": pvals_corrected_matrix[i, j]
                    })
                k += 1
    
    return {
        "chi2_results": {
            "statistic": chi2,
            "p_value": p,
            "dof": dof
        },
        "cramers_v": cramers_v,
        "theils_u": theils_u_value,  # Added Theil's U to the results
        "significant_pairs": significant_pairs
    }

# Example usage
try:
    # Read the TSV file
    data = pd.read_csv('creativi_full_info_with_dsm5.tsv', sep='\t')
    
    # Run the analysis
    results = analyze_disorder_occupation(data)
    
    # Print results
    print("\nChi-square test results:")
    print(f"Statistic: {results['chi2_results']['statistic']:.2f}")
    print(f"P-value: {results['chi2_results']['p_value']:.4f}")
    print(f"Degrees of freedom: {results['chi2_results']['dof']}")
    print(f"\nCramer's V: {results['cramers_v']:.4f}")
    print(f"Theil's U: {results['theils_u']:.4f}")  # Added Theil's U to output
    
    if results["significant_pairs"]:
        print("\nSignificant Disorder-Occupation Pairs (FDR corrected):")
        for pair in sorted(results["significant_pairs"], 
                         key=lambda x: x['adjusted_p']):
            print(f"  {pair['disorder']} - {pair['occupation']}:")
            print(f"    Original p={pair['original_p']:.4f}")
            print(f"    Adjusted p={pair['adjusted_p']:.4f}")
    else:
        print("\nNo significant disorder-occupation pairs found after FDR correction.")
        
except FileNotFoundError:
    print("Error: TSV file not found. Make sure the file exists and the path is correct.")
except pd.errors.ParserError:
    print("Error: Could not parse the TSV file. Check for formatting issues.")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Chi-square test results:
# Statistic: 34902.73
# P-value: 0.0000
# Degrees of freedom: 22692
#
# Cramer's V: 0.1422
# Theil's U: 0.3089
#
# Significant Disorder-Occupation Pairs (FDR corrected):
#   pseudobulbar affect - digital artist:
#     Original p=0.0000
#     Adjusted p=0.0000
#   alcohol abuse - street musician:
#     Original p=0.0000
#     Adjusted p=0.0000
#   neurasthenia - organist:
#     Original p=0.0000
#     Adjusted p=0.0000
#   foreign accent syndrome - drafter:
#     Original p=0.0000
#     Adjusted p=0.0000
#   cannabis dependence - djembe player:
#     Original p=0.0000
#     Adjusted p=0.0000
#   cannabis dependence - roleplayer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   alcoholic hepatitis - religious writer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   opioid use disorder - pop singer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   heroin dependence - rock singer:
#     Original p=0.0000
#     Adjusted p=0.0000
#   deaf-mute - painter:
# ...

# %% [markdown]
# # Creatives with no disorders, with occupations

# %% [markdown]
# ## Query: look for all creatives.

# %%
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?creativePerson ?occupation
WHERE {
 # ?creativePerson wdt:P31 wd:Q5.
 # ?creativePerson wdt:P106 ?occupation.
 # ?occupation wdt:P279* ?creativeOccupation.
 VALUES ?creativeOccupation { wd:Q205375 wd:Q3492227 wd:Q482980 wd:Q483501 }
 
 MINUS {?occupation wdt:P279* wd:Q15980158} # non-fiction writer
 MINUS {?occupation wdt:P279* wd:Q108289407} # authors, journalists, linguists
 MINUS {?occupation wdt:P279* wd:Q1607826} # editor
 MINUS {?occupation wdt:P279* wd:Q2675537} # music teacher
 MINUS {?occupation wdt:P279* wd:Q4610556} # model
 MINUS {?occupation wdt:P279* wd:Q138858} # entertainer
 MINUS {?occupation wdt:P279* wd:Q13474373} # professional wrestler
 MINUS {?occupation wdt:P279* wd:Q2066131} # athlete
 MINUS {?occupation wdt:P279* wd:Q947873} # television presenter
 MINUS {?occupation wdt:P279* wd:Q2405480} # voice actor
 MINUS {?occupation wdt:P279* wd:Q852857} # sex worker
 MINUS {?occupation wdt:P279* wd:Q55187} # hairdresser
 MINUS {?occupation wdt:P279* wd:Q1294787} # artisan
 MINUS {?occupation wdt:P279* wd:Q13235160} # manufacturer
 MINUS {?occupation wdt:P279* wd:Q755070} # narrator
 MINUS {?occupation wdt:P279* wd:Q1907198} # taxonomist
 MINUS {?occupation wdt:P279* wd:Q1734662} # cartographer
 MINUS {?occupation wdt:P279* wd:Q183888} # software developer
 MINUS {?occupation wdt:P279* wd:Q1790480} # translator-interpreter
 MINUS {?occupation wdt:P279* wd:Q47541952} # producer
}

# %% [markdown]
# Now compare with creatives with disturbs and cancel people from list based on creative ID.

# %%
import pandas as pd

def clean_value(value):
    """
    Remove angular brackets from string values
    Example: '<http://www.wikidata.org/entity/Q42>' -> 'http://www.wikidata.org/entity/Q42'
    """
    if isinstance(value, str):
        return value.strip('<>').strip()
    return value

def filter_creativi_files(full_info_path, creativi_path, output_path):
    """
    Filter rows from creativi.tsv where ?creativePerson exists in creativi_full_info.tsv
    Cleans angular brackets from values before comparison
    
    Args:
        full_info_path (str): Path to creativi_full_info.tsv
        creativi_path (str): Path to creativi.tsv
        output_path (str): Path where to save the filtered TSV
    """
    try:
        # Read both TSV files
        full_info_df = pd.read_csv(full_info_path, sep='\t')
        creativi_df = pd.read_csv(creativi_path, sep='\t')
        
        # Clean the ?creativePerson values in both dataframes
        full_info_df['?creativePerson_clean'] = full_info_df['?creativePerson'].apply(clean_value)
        creativi_df['?creativePerson_clean'] = creativi_df['?creativePerson'].apply(clean_value)
        
        # Get set of cleaned creative persons from full_info
        persons_to_remove = set(full_info_df['?creativePerson_clean'])
        
        # Filter creativi_df to keep only rows where cleaned ?creativePerson is not in full_info
        filtered_df = creativi_df[~creativi_df['?creativePerson_clean'].isin(persons_to_remove)]
        
        # Remove the temporary cleaning column
        filtered_df = filtered_df.drop('?creativePerson_clean', axis=1)
        
        # Print summary of operation
        total_rows = len(creativi_df)
        remaining_rows = len(filtered_df)
        removed_rows = total_rows - remaining_rows
        
        print(f"Original rows: {total_rows}")
        print(f"Rows removed: {removed_rows}")
        print(f"Remaining rows: {remaining_rows}")
        
        # Sample check of what was removed vs kept
        if removed_rows > 0:
            print("\nExample of removed values (first 3):")
            removed_df = creativi_df[creativi_df['?creativePerson_clean'].isin(persons_to_remove)]
            for idx, row in removed_df.head(3).iterrows():
                print(f"Original: {row['?creativePerson']} -> Cleaned: {row['?creativePerson_clean']}")
        
        # Save filtered DataFrame to new TSV
        filtered_df.to_csv(output_path, sep='\t', index=False)
        print(f"\nFiltered data saved to: {output_path}")
        
    except FileNotFoundError as e:
        print(f"Error: Could not find file - {e}")
    except pd.errors.EmptyDataError:
        print("Error: One of the TSV files is empty")
    except KeyError:
        print("Error: Could not find '?creativePerson' column in one of the files")
    except Exception as e:
        print(f"Unexpected error: {e}")

# Example usage:
if __name__ == "__main__":
    filter_creativi_files(
        full_info_path='creativi_full_info.tsv',
        creativi_path='creativi_tot.tsv',
        output_path='creativi_filtered.tsv'
    )
# Out:
# Original rows: 2919855
# Rows removed: 4085
# Remaining rows: 2915770
#
# Example of removed values (first 3):
# Original: <http://www.wikidata.org/entity/Q100138685> -> Cleaned: http://www.wikidata.org/entity/Q100138685
# Original: <http://www.wikidata.org/entity/Q100138685> -> Cleaned: http://www.wikidata.org/entity/Q100138685
# Original: <http://www.wikidata.org/entity/Q100583464> -> Cleaned: http://www.wikidata.org/entity/Q100583464
#
# Filtered data saved to: creativi_filtered.tsv

# %% [markdown]
# # Add labels through a query

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import time
from tqdm import tqdm

def clean_wikidata_url(url):
    """Remove angle brackets and extract Q number from Wikidata URL"""
    if pd.isna(url):
        return None
    return url.strip('<>').split('/')[-1]

def get_occupation_labels(qids, endpoint_url="https://query.wikidata.org/sparql"):
    """
    Fetch English labels for a batch of Wikidata occupation QIDs
    """
    sparql = SPARQLWrapper(endpoint_url)
    # Add proper user agent
    sparql.addCustomHttpHeader('User-Agent', 'My Research Bot/1.0 (academic research project; contact@example.com)')
    sparql.setReturnFormat(JSON)
    
    # Convert QIDs list to SPARQL-compatible format
    values_str = ' '.join(f'wd:{qid}' for qid in qids)
    
    query = f"""
    SELECT ?item ?label
    WHERE {{
        VALUES ?item {{ {values_str} }}
        # ?item rdfs:label ?label .
        FILTER(LANG(?label) = "en")
    }}
    """
    
    sparql.setQuery(query)
    
    try:
        results = sparql.query().convert()
        labels = {}
        for result in results["results"]["bindings"]:
            qid = result["item"]["value"].split("/")[-1]
            label = result["label"]["value"]
            labels[qid] = label
        return labels
    except Exception as e:
        print(f"Error fetching labels for batch: {e}")
        print("Problematic QIDs:", qids)
        return {}

def process_occupation_file(input_file, output_file, batch_size=25):  # Reduced batch size
    """
    Process TSV file with occupation QIDs and add English labels
    """
    try:
        # Read the TSV file
        df = pd.read_csv(input_file, sep='\t')
        print(f"Loaded {len(df)} rows")
        
        # Get unique occupation QIDs
        df['occupation_qid'] = df['?occupation'].apply(clean_wikidata_url)
        unique_qids = df['occupation_qid'].dropna().unique()
        print(f"Found {len(unique_qids)} unique occupation QIDs")
        
        # Process in batches
        labels_dict = {}
        for i in tqdm(range(0, len(unique_qids), batch_size)):
            batch_qids = unique_qids[i:i + batch_size]
            batch_labels = get_occupation_labels(batch_qids)
            labels_dict.update(batch_labels)
            time.sleep(2)  # Increased delay between requests
            
        # Add labels to dataframe
        df['?occupationLabel'] = df['occupation_qid'].map(labels_dict)
        
        # Remove temporary QID column
        df = df.drop('occupation_qid', axis=1)
        
        # Save results
        df.to_csv(output_file, sep='\t', index=False)
        print(f"\nProcessed file saved to: {output_file}")
        
        # Report statistics
        missing_labels = df['?occupationLabel'].isna().sum()
        print(f"\nStatistics:")
        print(f"Total rows: {len(df)}")
        print(f"Rows with labels: {len(df) - missing_labels}")
        print(f"Rows missing labels: {missing_labels}")
        
        # Show some examples
        print("\nFirst few rows with labels:")
        print(df[['?occupation', '?occupationLabel']].head())
        
    except FileNotFoundError:
        print(f"Error: Input file '{input_file}' not found")
    except pd.errors.EmptyDataError:
        print("Error: Input file is empty")
    except Exception as e:
        print(f"Error processing file: {e}")

if __name__ == "__main__":
    process_occupation_file(
        input_file='creativi_filtered.tsv',
        output_file='creativi_non_disturbed.tsv',
        batch_size=25  # Reduced batch size
    )
# Out:
# Loaded 2915770 rows
# Found 1309 unique occupation QIDs
# 100%|██████████████████████████████████████████████████████████████████████████████████| 53/53 [02:25<00:00,  2.74s/it]
# Processed file saved to: creativi_non_disturbed.tsv
#
# Statistics:
# Total rows: 2915770
# Rows with labels: 2915159
# Rows missing labels: 611
#
# First few rows with labels:
#                                   ?occupation ?occupationLabel
# 0    <http://www.wikidata.org/entity/Q805221>    ballet dancer
# 1    <http://www.wikidata.org/entity/Q214917>       playwright
# 2     <http://www.wikidata.org/entity/Q28389>     screenwriter
# 3     <http://www.wikidata.org/entity/Q36180>           writer
# 4  <http://www.wikidata.org/entity/Q12144794>     prose writer

# %% [markdown]
# # Non creatives with no disorders

# %% [markdown]
# First: we look for non-creatives and their occupations via two queries.
# Secon: form the merged result, we eliminate a) non-creatives with disturbs; b) creative people (may have multiple occupations, some creative and some not).

# %% [markdown]
# ## Query 1 (non-creatives occupations)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT DISTINCT ?nonCreativePerson ?occupation
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # Exclude creative professions and their subclasses
  MINUS {
    # ?occupation wdt:P279* ?excludedOccupation.
    VALUES ?excludedOccupation { 
      wd:Q205375  # inventor
      wd:Q3492227 # innovator
      wd:Q482980  # author
      wd:Q483501  # artist
    }
  }
}

# %% [markdown]
# Results to 'non_creative_occupations1.tsv'

# %% [markdown]
# ## Query 2 (non-creatives occupations)

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT distinct ?nonCreativePerson ?occupation
WHERE {
  # ?nonCreativePerson wdt:P31 wd:Q5.
  # ?nonCreativePerson wdt:P106 ?occupation.
  # ?occupation wdt:P279* ?includedOccupation.
  VALUES ?includedOccupation {
    wd:Q15980158 wd:Q108289407 wd:Q1607826 wd:Q2675537 
    wd:Q4610556 wd:Q138858 wd:Q13474373
    wd:Q2066131 wd:Q947873 wd:Q2405480 wd:Q852857
    wd:Q55187 wd:Q1294787 wd:Q13235160 wd:Q755070
    wd:Q1907198 wd:Q1734662 wd:Q183888
    wd:Q1790480 wd:Q47541952
  }
}

# %% [markdown]
# Results to 'non_creative_occupations2.tsv'

# %% [markdown]
# ## Merge the two files, keeping multiple rows for people with multiple occupations

# %%
import pandas as pd

def merge_tsv_files(file1_path, file2_path):
    """
    Merge two TSV files and remove duplicates only when both ?nonCreativePerson and ?occupation match.
    Provides statistics about the merge operation and duplicate persons.
    
    Args:
        file1_path (str): Path to first TSV file
        file2_path (str): Path to second TSV file
    """
    # Read TSV files
    df1 = pd.read_csv(file1_path, sep='\t')
    df2 = pd.read_csv(file2_path, sep='\t')
    
    # Print initial statistics
    print("\nInitial Statistics:")
    print(f"File 1 row count: {len(df1)}")
    print(f"File 2 row count: {len(df2)}")
    print(f"\nUnique ?nonCreativePerson in File 1: {df1['?nonCreativePerson'].nunique()}")
    print(f"Unique ?nonCreativePerson in File 2: {df2['?nonCreativePerson'].nunique()}")
    
    # Print occupation counts for each file
    print("\nOccupation distribution in File 1:")
    print(df1['?occupation'].value_counts().head())
    print("\nOccupation distribution in File 2:")
    print(df2['?occupation'].value_counts().head())
    
    # Merge files and drop duplicates only when both columns match
    merged_df = pd.concat([df1, df2]).drop_duplicates(subset=['?nonCreativePerson', '?occupation'])
    
    # Print merge statistics
    print("\nMerge Statistics:")
    print(f"Total rows after merge and deduplication: {len(merged_df)}")
    print(f"Unique ?nonCreativePerson in merged file: {merged_df['?nonCreativePerson'].nunique()}")
    
    # Calculate and print statistics about duplicate persons
    person_counts = merged_df['?nonCreativePerson'].value_counts()
    duplicate_persons = person_counts[person_counts > 1]
    
    print(f"\nPersons appearing multiple times in final dataset:")
    print(f"Number of persons with multiple entries: {len(duplicate_persons)}")
    print(f"Total number of rows involved in duplicates: {sum(duplicate_persons)}")
    
    # Print example of duplicates (first 5)
    if len(duplicate_persons) > 0:
        print("\nExample of persons with multiple entries (first 5):")
        for person in duplicate_persons.head().index:
            print(f"\nPerson: {person}")
            print(merged_df[merged_df['?nonCreativePerson'] == person][['?nonCreativePerson', '?occupation']])
    
    # Calculate overlap statistics
    common_persons = set(df1['?nonCreativePerson']).intersection(set(df2['?nonCreativePerson']))
    print(f"\nNumber of ?nonCreativePerson present in both files: {len(common_persons)}")
    
    # Print occupation distribution in merged file
    print("\nTop 5 occupations in merged file:")
    print(merged_df['?occupation'].value_counts().head())
    
    # Save merged file
    output_path = 'non_creative_occupations_merged.tsv'
    merged_df.to_csv(output_path, sep='\t', index=False)
    print(f"\nMerged file saved as: {output_path}")
    
    return merged_df

# Usage example
if __name__ == "__main__":
    # Replace these with your actual file paths
    file1_path = "non_creative_occupations1.tsv"
    file2_path = "non_creative_occupations2.tsv"
    
    try:
        merged_data = merge_tsv_files(file1_path, file2_path)
    except FileNotFoundError as e:
        print(f"Error: {e}")
    except pd.errors.EmptyDataError:
        print("Error: One or both of the files are empty")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Initial Statistics:
# File 1 row count: 4991429
# File 2 row count: 5270131
#
# Unique ?nonCreativePerson in File 1: 4046072
# Unique ?nonCreativePerson in File 2: 4761115
#
# Occupation distribution in File 1:
# ?occupation
# <http://www.wikidata.org/entity/Q82955>      846130
# <http://www.wikidata.org/entity/Q937857>     369062
# <http://www.wikidata.org/entity/Q1622272>    269722
# <http://www.wikidata.org/entity/Q3665646>    172271
# <http://www.wikidata.org/entity/Q47064>      101721
# Name: count, dtype: int64
#
# Occupation distribution in File 2:
# ?occupation
# <http://www.wikidata.org/entity/Q1650915>    1994681
# <http://www.wikidata.org/entity/Q937857>      369062
# <http://www.wikidata.org/entity/Q1930187>     172561
# <http://www.wikidata.org/entity/Q3665646>     172271
# <http://www.wikidata.org/entity/Q201788>      114054
# Name: count, dtype: int64
#
# Merge Statistics:
# Total rows after merge and deduplication: 8802408
# ...

# %% [markdown]
# Analysis of the merged occupational dataset reveals significant professional diversity among individuals. After merging two large datasets containing approximately 5 million records each, we found that 18.5% of people (1,291,374 out of 6,966,748 unique individuals) held multiple occupations. These multi-occupation individuals account for 3,127,034 rows in the final dataset, indicating substantial career variety. For example, examining specific cases like individual Q231690 shows an impressive range of 31 different occupational roles. This pattern suggests that many people, particularly those notable enough to be included in Wikidata, tend to diversify their professional activities rather than maintaining a single career path. Such occupational multiplicity could reflect either simultaneous roles (such as being both a professor and writer) or career transitions over time. The data challenges the traditional notion of single-career paths and highlights the complexity of modern professional lives, where individuals frequently engage in various professional roles throughout their careers. This multiplicity of occupations is particularly evident in the dataset, where even after removing exact duplicates (same person with same occupation), the high number of multiple entries persists due to genuinely different occupational relationships.

# %% [markdown]
# ## Compare with creatives to cancel people with both creative occupations and non-creative occupations.

# %%
import pandas as pd

def filter_non_creative_occupations(creative_file, non_creative_file, output_file):
    """
    Filter out rows from non_creative_occupations where the person appears in creative_tot.
    
    Parameters:
    creative_file (str): Path to the creative_tot.tsv file
    non_creative_file (str): Path to the non_creative_occupations_merged.tsv file
    output_file (str): Path where the filtered TSV will be saved
    """
    try:
        # Read the TSV files
        creative_df = pd.read_csv(creative_file, sep='\t')
        non_creative_df = pd.read_csv(non_creative_file, sep='\t')
        
        # Get the list of creative persons
        creative_persons = set(creative_df['?creativePerson'].dropna())
        
        # Filter out rows where the person appears in creative_persons
        filtered_df = non_creative_df[~non_creative_df['?nonCreativePerson'].isin(creative_persons)]
        
        # Save the filtered DataFrame to a new TSV file
        filtered_df.to_csv(output_file, sep='\t', index=False)
        
        # Print statistics
        print("\nSTATISTICS:")
        print(f"Original non-creative occupations count: {len(non_creative_df):,}")
        print(f"Filtered non-creative occupations count: {len(filtered_df):,}")
        print(f"Removed {len(non_creative_df) - len(filtered_df):,} entries")
        
        # Show examples of removed entries
        print("\nEXAMPLES OF REMOVED ENTRIES:")
        removed_df = non_creative_df[non_creative_df['?nonCreativePerson'].isin(creative_persons)]
        if len(removed_df) > 0:
            print("\nFirst 5 removed entries:")
            for idx, row in removed_df.head().iterrows():
                print(f"\nPerson: {row['?nonCreativePerson']}")
                # Print all columns for this row
                for col in removed_df.columns:
                    if col != '?nonCreativePerson':  # Skip printing person again
                        print(f"{col}: {row[col]}")
        
    except FileNotFoundError as e:
        print(f"Error: Could not find file - {e}")
    except pd.errors.EmptyDataError:
        print("Error: One of the files is empty")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    # File paths
    creative_file = "creativi_tot.tsv"
    non_creative_file = "non_creative_occupations_merged.tsv"
    output_file = "non_creative_occupations_filtered.tsv"
    
    # Run the filtering process
    filter_non_creative_occupations(creative_file, non_creative_file, output_file)
# Out:
# STATISTICS:
# Original non-creative occupations count: 8,802,408
# Filtered non-creative occupations count: 7,955,960
# Removed 846,448 entries
#
# EXAMPLES OF REMOVED ENTRIES:
#
# First 5 removed entries:
#
# Person: <http://www.wikidata.org/entity/Q1000006>
# ?occupation: <http://www.wikidata.org/entity/Q3282637>
#
# Person: <http://www.wikidata.org/entity/Q100011609>
# ?occupation: <http://www.wikidata.org/entity/Q13590141>
#
# Person: <http://www.wikidata.org/entity/Q100013293>
# ?occupation: <http://www.wikidata.org/entity/Q40348>
#
# Person: <http://www.wikidata.org/entity/Q100019438>
# ?occupation: <http://www.wikidata.org/entity/Q1999841>
#
# Person: <http://www.wikidata.org/entity/Q100029>
# ?occupation: <http://www.wikidata.org/entity/Q47064>

# %% [markdown]
# ## Now remove disturbed non-creatives.

# %% [markdown]
# Compare with the 'merged_cleaned_noncreative.tsv' file which contains non-creative people with disturbs and remove common rows.

# %%
import pandas as pd

def filter_non_creative_occupations(merged_cleaned_file, filtered_file, output_file):
    """
    Filter out rows from non_creative_occupations_filtered.tsv where the person appears in merged_cleaned_noncreative.tsv
    
    Parameters:
    merged_cleaned_file (str): Path to the merged_cleaned_noncreative.tsv file
    filtered_file (str): Path to the non_creative_occupations_filtered.tsv file
    output_file (str): Path where the new filtered TSV will be saved
    """
    try:
        # Read the TSV files
        merged_cleaned_df = pd.read_csv(merged_cleaned_file, sep='\t')
        filtered_df = pd.read_csv(filtered_file, sep='\t')
        
        # Get the list of persons from merged_cleaned_noncreative
        merged_persons = set(merged_cleaned_df['?nonCreativePerson'].dropna())
        
        # Filter out rows where the person appears in merged_persons
        final_filtered_df = filtered_df[~filtered_df['?nonCreativePerson'].isin(merged_persons)]
        
        # Save the filtered DataFrame to a new TSV file
        final_filtered_df.to_csv(output_file, sep='\t', index=False)
        
        # Print statistics
        print("\nSTATISTICS:")
        print(f"Original number of entries: {len(filtered_df):,}")
        print(f"Final number of entries: {len(final_filtered_df):,}")
        print(f"Removed {len(filtered_df) - len(final_filtered_df):,} entries")
        
        # Show examples of removed entries
        print("\nEXAMPLES OF REMOVED ENTRIES:")
        removed_df = filtered_df[filtered_df['?nonCreativePerson'].isin(merged_persons)]
        if len(removed_df) > 0:
            print("\nFirst 5 removed entries:")
            for idx, row in removed_df.head().iterrows():
                print(f"\nPerson: {row['?nonCreativePerson']}")
                # Print all columns for this row
                for col in removed_df.columns:
                    if col != '?nonCreativePerson':  # Skip printing person again
                        print(f"{col}: {row[col]}")
        
    except FileNotFoundError as e:
        print(f"Error: Could not find file - {e}")
    except pd.errors.EmptyDataError:
        print("Error: One of the files is empty")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    # File paths
    merged_cleaned_file = "merged_cleaned_noncreative.tsv"
    filtered_file = "non_creative_occupations_filtered.tsv"
    output_file = "non_creatives_not_disturbed_occupations.tsv"
    
    # Run the filtering process
    filter_non_creative_occupations(merged_cleaned_file, filtered_file, output_file)
# Out:
# STATISTICS:
# Original number of entries: 7,955,960
# Final number of entries: 7,954,575
# Removed 1,385 entries
#
# EXAMPLES OF REMOVED ENTRIES:
#
# First 5 removed entries:
#
# Person: <http://www.wikidata.org/entity/Q100597361>
# ?occupation: <http://www.wikidata.org/entity/Q2775569>
#
# Person: <http://www.wikidata.org/entity/Q101189220>
# ?occupation: <http://www.wikidata.org/entity/Q61857538>
#
# Person: <http://www.wikidata.org/entity/Q101189220>
# ?occupation: <http://www.wikidata.org/entity/Q82955>
#
# Person: <http://www.wikidata.org/entity/Q10132>
# ?occupation: <http://www.wikidata.org/entity/Q10833314>
#
# Person: <http://www.wikidata.org/entity/Q10132>
# ?occupation: <http://www.wikidata.org/entity/Q4610556>

# %% [markdown]
# ## Now let's add occupation labels via a remote query.

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import time
from tqdm import tqdm
import re

def extract_qid(uri):
    """Extract Q-number from Wikidata URI"""
    match = re.search(r'Q\d+', uri)
    return match.group(0) if match else None

def create_sparql_query(qids):
    """Create SPARQL query for multiple QIDs"""
    qid_values = ' '.join(f'wd:{qid}' for qid in qids)
    query = f"""
    SELECT ?entity ?label
    WHERE {{
        VALUES ?entity {{ {qid_values} }}
        # ?entity rdfs:label ?label .
        FILTER(LANG(?label) = "en")
    }}
    """
    return query

def query_wikidata_labels(qids, endpoint_url="https://query.wikidata.org/sparql"):
    """Query Wikidata for labels of multiple entities"""
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(create_sparql_query(qids))
    sparql.setReturnFormat(JSON)
    
    try:
        results = sparql.query().convert()
        labels = {}
        for result in results["results"]["bindings"]:
            entity_uri = result["entity"]["value"]
            qid = extract_qid(entity_uri)
            if qid:
                labels[qid] = result["label"]["value"]
        return labels
    except Exception as e:
        print(f"Error querying Wikidata: {e}")
        return {}

def process_tsv_in_batches(input_file, output_file, batch_size=50):
    """Process TSV file in batches, adding occupation labels"""
    try:
        # Read the input TSV
        df = pd.read_csv(input_file, sep='\t')
        total_rows = len(df)
        print(f"Total rows to process: {total_rows:,}")
        
        # Extract QIDs for all occupations
        df['occupation_qid'] = df['?occupation'].apply(extract_qid)
        
        # Get unique occupations to reduce API calls
        unique_occupations = df['occupation_qid'].unique()
        print(f"Unique occupations to query: {len(unique_occupations):,}")
        
        # Process unique occupations in batches
        occupation_labels = {}
        batches = [unique_occupations[i:i + batch_size] for i in range(0, len(unique_occupations), batch_size)]
        
        print("Querying Wikidata for occupation labels...")
        for batch in tqdm(batches):
            batch_labels = query_wikidata_labels(batch)
            occupation_labels.update(batch_labels)
            time.sleep(0.1)  # Rate limiting
            
        # Add labels to the DataFrame
        df['?occupationLabel'] = df['occupation_qid'].map(occupation_labels)
        
        # Remove temporary QID column
        df = df.drop('occupation_qid', axis=1)
        
        # Save to new TSV file
        df.to_csv(output_file, sep='\t', index=False)
        
        # Print statistics
        print("\nPROCESSING COMPLETE")
        print(f"Total rows processed: {total_rows:,}")
        print(f"Labels found: {df['?occupationLabel'].notna().sum():,}")
        print(f"Labels missing: {df['?occupationLabel'].isna().sum():,}")
        
        # Show some examples
        print("\nExample rows from output:")
        print(df.head().to_string())
        
    except Exception as e:
        print(f"Error processing file: {e}")

if __name__ == "__main__":
    input_file = "non_creatives_not_disturbed_occupations.tsv"  # Replace with your input file name
    output_file = "non_creatives_not_disturbed_occupations_with_labels.tsv"
    batch_size = 50  # Adjust based on Wikidata's rate limits
    
    process_tsv_in_batches(input_file, output_file, batch_size)
# Out:
# Total rows to process: 7,954,575
# Unique occupations to query: 16,668
# Querying Wikidata for occupation labels...
#   5%|███▉                                                                             | 16/334 [00:10<02:12,  2.40it/s]
# Error querying Wikidata: HTTP Error 429: Too Many Requests
#   7%|█████▎                                                                           | 22/334 [00:13<02:04,  2.50it/s]
# Error querying Wikidata: HTTP Error 429: Too Many Requests
#  10%|████████                                                                         | 33/334 [00:17<01:44,  2.88it/s]
# Error querying Wikidata: HTTP Error 429: Too Many Requests
#  10%|████████▏                                                                        | 34/334 [00:17<01:37,  3.08it/s]
# Error querying Wikidata: HTTP Error 429: Too Many Requests
#  11%|████████▉                                                                        | 37/334 [00:19<01:46,  2.78it/s]
# ...

# %% [markdown]
# # First trial.

# %%
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.sandbox.stats.multicomp import multipletests

def clean_string(s):
    """Clean strings by removing @en, brackets, and URLs"""
    if pd.isna(s):
        return s
    s = str(s)
    s = s.replace('@en', '')
    s = s.strip('<>')
    if 'http://' in s or 'https://' in s:
        s = s.split('/')[-1]
    return s

def read_and_standardize_data(cd_file, cnd_file, ncd_file, ncnd_file):
    """Read and standardize the data with specific cleaning for each file"""
    
    # Read Creative Disordered
    print("\nReading Creative Disordered (CD) data...")
    cd_data = pd.read_csv(cd_file, sep='\t', usecols=['?creativePerson', '?occupationLabel', '?disorderLabel'])
    cd_data = cd_data.assign(
        person_id=cd_data['?creativePerson'].apply(clean_string),
        occupation=cd_data['?occupationLabel'].apply(clean_string),
        disorder=cd_data['?disorderLabel'].apply(clean_string)
    ).drop(['?creativePerson', '?occupationLabel', '?disorderLabel'], axis=1)
    
    # Read Creative Non-Disordered
    print("\nReading Creative Non-Disordered (CND) data...")
    cnd_data = pd.read_csv(cnd_file, sep='\t')
    cnd_data = cnd_data.assign(
        person_id=cnd_data['?creativePerson'].apply(clean_string),
        occupation=cnd_data['?occupationLabel'].apply(clean_string),
        disorder='NO_DISORDER'
    ).drop(['?creativePerson', '?occupation', '?occupationLabel'], axis=1)
    
    # Read Non-Creative Disordered
    print("\nReading Non-Creative Disordered (NCD) data...")
    ncd_data = pd.read_csv(ncd_file, sep='\t', usecols=['?nonCreativePerson', '?occupationLabel', '?disorderLabel'])
    ncd_data = ncd_data.assign(
        person_id=ncd_data['?nonCreativePerson'].apply(clean_string),
        occupation=ncd_data['?occupationLabel'].apply(clean_string),
        disorder=ncd_data['?disorderLabel'].apply(clean_string)
    ).drop(['?nonCreativePerson', '?occupationLabel', '?disorderLabel'], axis=1)
    
    # Read Non-Creative Non-Disordered
    print("\nReading Non-Creative Non-Disordered (NCND) data...")
    ncnd_data = pd.read_csv(ncnd_file, sep='\t')
    ncnd_data = ncnd_data.assign(
        person_id=ncnd_data['?nonCreativePerson'].apply(clean_string),
        occupation=ncnd_data['?occupationLabel'].apply(clean_string),
        disorder='NO_DISORDER'
    ).drop(['?nonCreativePerson', '?occupationLabel'], axis=1)
    
    # Add group indicators
    cd_data['group'] = 'CD'
    cnd_data['group'] = 'CND'
    ncd_data['group'] = 'NCD'
    ncnd_data['group'] = 'NCND'
    
    # Remove duplicates
    print("\nRemoving duplicates and preparing final datasets...")
    data_dict = {
        'CD': cd_data.drop_duplicates(),
        'CND': cnd_data.drop_duplicates(),
        'NCD': ncd_data.drop_duplicates(),
        'NCND': ncnd_data.drop_duplicates()
    }
    
    # Print summary
    print("\nData Summary:")
    for group, df in data_dict.items():
        print(f"\n{group}:")
        print(f"Unique individuals: {df['person_id'].nunique()}")
        print(f"Unique occupations: {df['occupation'].nunique()}")
        if group in ['CD', 'NCD']:
            print(f"Unique disorders: {df['disorder'].nunique()}")
    
    return data_dict

def calculate_chi_square_stats(table, alpha=0.05):
    """Calculate chi-square statistics and odds ratio"""
    # Chi-square test
    chi2, p_value, dof, expected = stats.chi2_contingency(table, correction=False)
    
    # Calculate odds ratio and confidence intervals
    a, b = table[0]
    c, d = table[1]
    
    odds_ratio = (a * d) / (b * c)
    log_odds_ratio = np.log(odds_ratio)
    se_log_odds = np.sqrt(1/a + 1/b + 1/c + 1/d)
    
    z = stats.norm.ppf(1 - alpha/2)
    ci_lower = np.exp(log_odds_ratio - z * se_log_odds)
    ci_upper = np.exp(log_odds_ratio + z * se_log_odds)
    
    # Effect size (Cramer's V)
    n = table.sum()
    cramers_v = np.sqrt(chi2 / (n * min(table.shape[0]-1, table.shape[1]-1)))
    
    return {
        'chi2': chi2,
        'p_value': p_value,
        'dof': dof,
        'odds_ratio': odds_ratio,
        'ci_lower': ci_lower,
        'ci_upper': ci_upper,
        'cramers_v': cramers_v,
        'expected': expected
    }

def analyze_four_group_associations(data_dict, alpha=0.05, min_count=5, min_effect=0.1):
    """Analyze associations with adjustments for unbalanced groups"""
    # Get unique disorders (excluding NO_DISORDER)
    disorders = pd.unique(pd.concat([
        data_dict['CD']['disorder'],
        data_dict['NCD']['disorder']
    ]))
    disorders = disorders[disorders != 'NO_DISORDER']
    
    # Pre-calculate frequencies with normalization
    freq_dict = {}
    totals = {}
    for group, df in data_dict.items():
        # Calculate total size for normalization
        totals[group] = len(df)
        
        # Group by both disorder and occupation with normalized counts
        freq_df = df.groupby(['disorder', 'occupation']).size().reset_index(name='count')
        freq_df['normalized_count'] = freq_df['count'] / len(df)
        freq_dict[group] = freq_df
        
        # Calculate disorder totals
        freq_dict[group + '_disorder_total'] = df.groupby('disorder').size()
        freq_dict[group + '_disorder_prop'] = df.groupby('disorder').size() / len(df)
    
    results = {
        'cd_vs_ncd': [],  # Creative Disordered vs Non-Creative Disordered
        'cd_vs_cnd': [],  # Creative Disordered vs Creative Non-Disordered
        'cd_vs_ncnd': []  # Creative Disordered vs Non-Creative Non-Disordered
    }
    
    print("\nAnalyzing disorder-occupation pairs...")
    
    for disorder in disorders:
        # Get disorder prevalence in each group
        cd_prev = freq_dict['CD_disorder_prop'].get(disorder, 0)
        ncd_prev = freq_dict['NCD_disorder_prop'].get(disorder, 0)
        
        # Only analyze disorders with sufficient prevalence
        if cd_prev < 0.01 or ncd_prev < 0.01:  # Less than 1% prevalence
            continue
            
        print(f"\nAnalyzing {disorder}:")
        print(f"Prevalence in CD: {cd_prev:.1%}")
        print(f"Prevalence in NCD: {ncd_prev:.1%}")
        
        # Get all occupations for this disorder
        occupations = pd.unique(pd.concat([
            freq_dict['CD'][freq_dict['CD']['disorder'] == disorder]['occupation'],
            freq_dict['NCD'][freq_dict['NCD']['disorder'] == disorder]['occupation']
        ]))
        
        cd_disorder_total = freq_dict['CD_disorder_total'].get(disorder, 0)
        
        for occupation in occupations:
            # Get normalized counts for CD group
            cd_data = freq_dict['CD'][
                (freq_dict['CD']['disorder'] == disorder) & 
                (freq_dict['CD']['occupation'] == occupation)
            ]
            cd_both = cd_data['count'].iloc[0] if not cd_data.empty else 0
            cd_norm = cd_data['normalized_count'].iloc[0] if not cd_data.empty else 0
            
            if cd_both < min_count:
                continue
            
            # Calculate tables and statistics for each comparison
            for comparison, group in [('cd_vs_ncd', 'NCD'), ('cd_vs_cnd', 'CND'), ('cd_vs_ncnd', 'NCND')]:
                comp_data = freq_dict[group][
                    (freq_dict[group]['disorder'] == disorder) & 
                    (freq_dict[group]['occupation'] == occupation)
                ]
                comp_both = comp_data['count'].iloc[0] if not comp_data.empty else 0
                comp_norm = comp_data['normalized_count'].iloc[0] if not comp_data.empty else 0
                
                comp_total = freq_dict[f'{group}_disorder_total'].get(
                    disorder, totals[group]
                )
                
                # Create contingency table
                table = np.array([
                    [cd_both, cd_disorder_total - cd_both],
                    [comp_both, comp_total - comp_both]
                ])
                
                if table.min() >= min_count:
                    try:
                        stats_result = calculate_chi_square_stats(table, alpha)
                        
                        # Only include if effect size is meaningful
                        if stats_result['cramers_v'] >= min_effect:
                            results[comparison].append({
                                'disorder': disorder,
                                'occupation': occupation,
                                'cd_count': cd_both,
                                'cd_total': cd_disorder_total,
                                'cd_proportion': cd_norm,
                                'comparison_count': comp_both,
                                'comparison_total': comp_total,
                                'comparison_proportion': comp_norm,
                                'relative_risk': cd_norm / comp_norm if comp_norm > 0 else np.inf,
                                **stats_result
                            })
                    except:
                        continue
    
    # Process results
    for comparison in results:
        if results[comparison]:
            df = pd.DataFrame(results[comparison])
            
            # Apply FDR correction
            _, adjusted_p = multipletests(df['p_value'], alpha=alpha, method='fdr_bh')[:2]
            df['adjusted_p_value'] = adjusted_p
            df['significant'] = df['adjusted_p_value'] < alpha
            
            # Sort by effect size and odds ratio
            results[comparison] = df.sort_values(
                ['cramers_v', 'odds_ratio'], 
                ascending=[False, False]
            )
            
            # Print summary for this comparison
            sig_count = sum(df['significant'])
            print(f"\n{comparison}:")
            print(f"Total pairs analyzed: {len(df)}")
            print(f"Significant pairs: {sig_count}")
            if sig_count > 0:
                print("Top associations:")
                top_pairs = df[df['significant']].head(3)
                for _, row in top_pairs.iterrows():
                    print(f"  {row['disorder']} - {row['occupation']}")
                    print(f"  OR: {row['odds_ratio']:.2f}, Cramer's V: {row['cramers_v']:.3f}")
    
    return results

def print_analysis_results(results, alpha=0.05, min_odds_ratio=1.5):
    """Print analysis results with additional context"""
    for comparison in results:
        if isinstance(results[comparison], pd.DataFrame) and not results[comparison].empty:
            significant_pairs = results[comparison][
                (results[comparison]['significant']) & 
                (results[comparison]['odds_ratio'] >= min_odds_ratio)
            ]
            
            if len(significant_pairs) > 0:
                print(f"\nDetailed results for {comparison}:")
                print("=" * 80)
                
                # Group by disorder for better organization
                for disorder in significant_pairs['disorder'].unique():
                    disorder_pairs = significant_pairs[significant_pairs['disorder'] == disorder]
                    print(f"\nDisorder: {disorder}")
                    print("-" * 40)
                    
                    for _, row in disorder_pairs.iterrows():
                        print(f"Occupation: {row['occupation']}")
                        print(f"Effect size (Cramer's V): {row['cramers_v']:.3f}")
                        print(f"Odds Ratio: {row['odds_ratio']:.2f} "
                              f"(95% CI: {row['ci_lower']:.2f}-{row['ci_upper']:.2f})")
                        print(f"Relative Risk: {row['relative_risk']:.2f}")
                        print(f"Proportions: CD={row['cd_proportion']:.1%}, "
                              f"Comparison={row['comparison_proportion']:.1%}")
                        print(f"Raw counts: CD={row['cd_count']}/{row['cd_total']}, "
                              f"Comparison={row['comparison_count']}/{row['comparison_total']}")
                        print("-" * 40)

def save_results(results, prefix=""):
    """Save results to CSV files"""
    for comparison in results:
        if isinstance(results[comparison], pd.DataFrame) and not results[comparison].empty:
            # Save all results
            results[comparison].to_csv(f'{prefix}all_results_{comparison}.csv', index=False)
            
            # Save only significant results
            significant_results = results[comparison][results[comparison]['significant']]
            if not significant_results.empty:
                significant_results.to_csv(f'{prefix}significant_results_{comparison}.csv', index=False)
                
if __name__ == "__main__":
    # Configuration parameters
    ALPHA = 0.05  # Significance level
    MIN_COUNT = 5  # Minimum count for contingency tables
    MIN_EFFECT = 0.1  # Minimum effect size (Cramer's V)
    MIN_ODDS_RATIO = 1.5  # Minimum odds ratio for reporting
    
    # File paths (adjust these to match your data locations)
    cd_file = "creativi_full_info_with_dsm5.tsv"
    cnd_file = "creativi_non_disturbed.tsv"
    ncd_file = "non_creativi_full_info_with_dsm5.tsv"
    ncnd_file = "non_creatives_not_disturbed_occupations_with_labels.tsv"
    
    
    # Output directory
    OUTPUT_DIR = "results/"
    
    try:
        print("Starting analysis of creativity-disorder associations...")
        
        # Read and standardize the data
        data_dict = read_and_standardize_data(
            cd_file=cd_file,
            cnd_file=cnd_file,
            ncd_file=ncd_file,
            ncnd_file=ncnd_file
        )
        
        # Perform the analysis
        results = analyze_four_group_associations(
            data_dict=data_dict,
            alpha=ALPHA,
            min_count=MIN_COUNT,
            min_effect=MIN_EFFECT
        )
        
        # Print detailed results
        print("\nPrinting detailed analysis results...")
        print_analysis_results(
            results=results,
            alpha=ALPHA,
            min_odds_ratio=MIN_ODDS_RATIO
        )
        
        # Save results to files
        print("\nSaving results to files...")
        save_results(results, prefix=f"{OUTPUT_DIR}")
        
        print("\nAnalysis completed successfully!")
        
    except FileNotFoundError as e:
        print(f"Error: Could not find data file - {e}")
        print("Please check that all data files exist in the specified directory.")
    
    except Exception as e:
        print(f"Error during analysis: {e}")
        print("Please check your data files and parameters.")

# %% [markdown]
# # Problem:
# Problems with code: gives no significant results. The issue stems from multiple cascading filters that are too restrictive:
#
# - Out of 177 unique disorders found, 129 were immediately filtered out due to low prevalence (less than 0.3% in both creative and non-creative groups). Even when looking at common disorders like Bipolar Disorder (16.4% in creatives, 12.2% in non-creatives), autism (10.8% in creatives, 7.0% in non-creatives), or dyslexia (13.7% in creatives, 13.1% in non-creatives), the next filters are too strict.
# - When these disorders are broken down by specific occupations, the numbers become too small. For example, while there might be many cases of bipolar disorder overall, once divided among 88 different creative occupations, each occupation-disorder pair has too few cases to meet the minimum count threshold (MIN_COUNT = 2). This resulted in 565 pairs being filtered out.
# - The contingency table filter is particularly problematic - it filtered out 1521 pairs, which is more than the total number of pairs (1072). This suggests some pairs are being counted multiple times in the filtering process, making the filter overly restrictive.

# %% [markdown]
# # Solution:
# We therefore try another approach: we gather occupations in wider categories. Not only will this allow us to perform statistical testing, but it also ensures better consistency and readability to the data (e.g. television actor, film actor, voice actor, stage actor can all map to just "actor")

# %% [markdown]
# # Cleaning.

# %% [markdown]
# We now have :
# - non creatives not disturbed with occupations (non_creatives_not_disturbed_occupations_with_labels.tsv)
# - non creatives disturbed with occupations and disturbs(non_creativi_full_info_with_dsm5.tsv)
# - creatives not disturbed with occupations (creativi_non_disturbed.tsv)
# - creatives dirturbed with occupations and disturbs (creativi_full_info_with_dsm5.tsv)

# %% [markdown]
# ## 1. Clean values.

# %% [markdown]
# We need to clean and standardize the data before analysis
# - Different column names between files
# - Some URIs are enclosed in <>, others aren't
# - Some labels have @en suffix

# %%
import pandas as pd
import os

def clean_string(value):
    """
    Clean a string value by:
    1. Removing <> brackets if present
    2. Removing @en suffix if present
    3. Stripping whitespace
    """
    if not isinstance(value, str):
        return value
        
    # Remove <> brackets
    value = value.strip('<>')
    
    # Remove @en suffix
    value = value.replace('@en', '')
    
    # Strip whitespace
    value = value.strip()
    
    return value

def clean_dataframe(df):
    """
    Clean all string columns in a dataframe
    """
    # Make a copy to avoid modifying the original
    df_cleaned = df.copy()
    
    # Apply cleaning to all string columns
    for column in df_cleaned.columns:
        if df_cleaned[column].dtype == 'object':  # Check if column contains strings
            df_cleaned[column] = df_cleaned[column].apply(clean_string)
    
    return df_cleaned

def process_files():
    """
    Process all four TSV files and create cleaned versions
    """
    # List of input files
    input_files = [
        'creativi_full_info_with_dsm5.tsv',  # creatives disturbed
        'non_creatives_not_disturbed_occupations_with_labels.tsv',  # non-creatives not disturbed
        'creativi_non_disturbed.tsv',  # creatives not disturbed
        'non_creativi_full_info_with_dsm5.tsv'  # non-creatives disturbed
    ]
    
    # Process each file
    for input_file in input_files:
        try:
            # Check if input file exists
            if not os.path.exists(input_file):
                print(f"Warning: Input file {input_file} not found")
                continue
                
            print(f"\nProcessing {input_file}...")
            
            # Read the TSV file
            df = pd.read_csv(input_file, sep='\t')
            
            # Print original sample
            print("\nOriginal sample:")
            print(df.head(2))
            
            # Clean the data
            df_cleaned = clean_dataframe(df)
            
            # Create output filename
            output_file = f"cleaned_{input_file}"
            
            # Save cleaned data
            df_cleaned.to_csv(output_file, sep='\t', index=False)
            
            # Print cleaned sample
            print("\nCleaned sample:")
            print(df_cleaned.head(2))
            
            print(f"\nCleaned data saved to: {output_file}")
            
            # Print statistics
            print("\nCleaning statistics:")
            print(f"Number of rows: {len(df_cleaned)}")
            print(f"Number of columns: {len(df_cleaned.columns)}")
            print("Columns:", df_cleaned.columns.tolist())
            
        except Exception as e:
            print(f"Error processing {input_file}: {str(e)}")

def main():
    print("Starting data cleaning process...")
    process_files()
    print("\nData cleaning process completed!")

if __name__ == "__main__":
    main()
# Out:
# Starting data cleaning process...
#
# Processing creativi_full_info_with_dsm5.tsv...
#
# Original sample:
#                              ?creativePerson ?occupationLabel  \
# 0  http://www.wikidata.org/entity/Q100138685         actor@en
# 1  http://www.wikidata.org/entity/Q100138685         actor@en
#
#          ?disorderLabel     gender      provenance  year_of_birth  \
# 0  Asperger syndrome@en  trans man  United Kingdom         2002.0
# 1        dyscalculia@en  trans man  United Kingdom         2002.0
#
#       clean_disorder                         dsm-5
# 0  Asperger syndrome  Neurodevelopmental Disorders
# 1        dyscalculia  Neurodevelopmental Disorders
#
# Cleaned sample:
#                              ?creativePerson ?occupationLabel  \
# 0  http://www.wikidata.org/entity/Q100138685            actor
# 1  http://www.wikidata.org/entity/Q100138685            actor
#
#       ?disorderLabel     gender      provenance  year_of_birth  \
# ...

# %% [markdown]
# ## 2. Extract all creative occupations and normalise data
# For example: television actor, film actor, voice actor, stage actor can all map to just "actor"

# %%
import pandas as pd

def get_unique_occupations(filename):
    """Read TSV file and return unique occupations"""
    try:
        df = pd.read_csv(filename, sep='\t')
        # Try both 'occupation' and 'Occupation' column names
        occ_col = '?occupationLabel'
        if occ_col in df.columns:
            occupations = sorted(df[occ_col].unique())
            return occupations
        else:
            print(f"No occupation column found in {filename}")
            print("Available columns:", df.columns.tolist())
            return []
    except Exception as e:
        print(f"Error reading {filename}: {e}")
        return []

def analyze_occupations():
    """Analyze occupations from both creative files"""
    files = {
        'CD': "cleaned_creativi_full_info_with_dsm5.tsv",
        'CND': "cleaned_creativi_non_disturbed.tsv"
    }
    
    all_occupations = set()
    
    print("\nAnalyzing occupations in each group:")
    print("=" * 50)
    
    for group, filename in files.items():
        print(f"\n{group} Group (from {filename}):")
        print("-" * 30)
        
        occupations = get_unique_occupations(filename)
        if occupations:
            print(f"Found {len(occupations)} unique occupations:")
            for occ in occupations:
                print(f"  - {occ}")
            all_occupations.update(occupations)
        print()
    
    print("\nSummary:")
    print("=" * 50)
    print(f"Total unique occupations across all files: {len(all_occupations)}")
    print("\nComplete list of all unique occupations:")
    for occ in sorted(all_occupations):
        print(f"  - {occ}")

if __name__ == "__main__":
    analyze_occupations()
# Out:
# Analyzing occupations in each group:
# ...
#
# CD Group (from cleaned_creativi_full_info_with_dsm5.tsv):
# ------------------------------
# Found 187 unique occupations:
#   - Formally schooled painter
#   - Minecraft YouTuber
#   - VTuber
#   - YouTuber
#   - Yōga painter
#   - actor
#   - animation director
#   - animator
#   - architect
#   - artist
#   - author
#   - ballet dancer
#   - ballet master
#   - bandleader
#   - banjoist
#   - bass guitarist
#   - bassist
#   - blogger
#   - board game designer
#   - botanical illustrator
#   - calligrapher
#   - cantaor
#   - car designer
#   - caricaturist
#   - carillonist
#   - cartoonist
#   - cellist
#   - character actor
#   - character animator
#   - child actor
#   - children's writer
#   - choreographer
#   - cinematographer
#   - circus performer
#   - classical pianist
#   - club DJ
#   - collagist
#   - comedian
#   - comedy writer
#   - comics artist
#   - comics creator
#   - comics writer
#   - composer
# ...

# %% [markdown]
# ## 3. Devise an occupations' organization to employ in the analysis
# We propose the following mapping to gather scattered occupations in broader, more telling macro-categories:\
#
#     # OCCUPATION_MAPPING = {
#     # PERFORMING ARTS - ACTING
#     'actor': 'actor',
#     'character actor': 'actor',
#     'child actor': 'actor',
#     'film actor': 'actor',
#     'musical theatre actor': 'actor',
#     'stage actor': 'actor',
#     'television actor': 'actor',
#     'video game actor': 'actor',
#     'voice actor': 'actor',
#
#     # PERFORMING ARTS - MUSIC
#     'bandleader': 'musician',
#     'banjoist': 'musician',
#     'bass guitarist': 'musician',
#     'bassist': 'musician',
#     'cantaor': 'musician',
#     'carillonist': 'musician',
#     'cellist': 'musician',
#     'classical pianist': 'musician',
#     'club DJ': 'musician',
#     'composer': 'musician',
#     'conductor': 'musician',
#     'disc jockey': 'musician',
#     'djembe player': 'musician',
#     'double-bassist': 'musician',
#     'drummer': 'musician',
#     'electronic musician': 'musician',
#     'guitarist': 'musician',
#     'instrumentalist': 'musician',
#     'jazz drummer': 'musician',
#     'jazz guitarist': 'musician',
#     'jazz musician': 'musician',
#     'jazz pianist': 'musician',
#     'jazz singer': 'musician',
#     'keyboardist': 'musician',
#     'lutenist': 'musician',
#     'mandolinist': 'musician',
#     'multi-instrumentalist': 'musician',
#     'music artist': 'musician',
#     'musician': 'musician',
#     'opera singer': 'musician',
#     'organist': 'musician',
#     'percussionist': 'musician',
#     'pianist': 'musician',
#     'pop singer': 'musician',
#     'rapper': 'musician',
#     'recording artist': 'musician',
#     'rock musician': 'musician',
#     'rock singer': 'musician',
#     'saxophonist': 'musician',
#     'scat singer': 'musician',
#     'session musician': 'musician',
#     'singer': 'musician',
#     'singer-songwriter': 'musician',
#     'songwriter': 'musician',
#     'street musician': 'musician',
#     'trumpeter': 'musician',
#     'turntabler': 'musician',
#     'violinist': 'musician',
#     'violist': 'musician',
#     'vocalist': 'musician',
#
#     # PERFORMING ARTS - DANCE
#     'ballet dancer': 'dancer',
#     'ballet master': 'dancer',
#     'choreographer': 'dancer',
#     'dancer': 'dancer',
#     'showgirl': 'dancer',
#
#     # PERFORMING ARTS - OTHER
#     'circus performer': 'performer',
#     'conferencier': 'performer',
#     'drag queen': 'performer',
#     'entertainer': 'performer',
#     'impostor': 'performer',
#     'mime artist': 'performer',
#     'narrator': 'performer',
#     'owarai tarento': 'performer',
#     'performance artist': 'performer',
#     'performing artist': 'performer',
#     'stage magician': 'performer',
#     'stunt performer': 'performer',
#     'tarento': 'performer',
#
#     # VISUAL ARTS - TRADITIONAL
#     'artist': 'visual artist',
#     'botanical illustrator': 'visual artist',
#     'calligrapher': 'visual artist',
#     'caricaturist': 'visual artist',
#     'cartoonist': 'visual artist',
#     'collagist': 'visual artist',
#     'comics artist': 'visual artist',
#     'etcher': 'visual artist',
#     'Formally schooled painter': 'visual artist',
#     'graffiti artist': 'visual artist',
#     'graphic artist': 'visual artist',
#     'illustrator': 'visual artist',
#     'installation artist': 'visual artist',
#     'mangaka': 'visual artist',
#     'object artist': 'visual artist',
#     'painter': 'visual artist',
#     'papercut artist': 'visual artist',
#     'plastic artist': 'visual artist',
#     'portrait painter': 'visual artist',
#     'printmaker': 'visual artist',
#     'serigrapher': 'visual artist',
#     'street artist': 'visual artist',
#     'textile artist': 'visual artist',
#     'visual artist': 'visual artist',
#     'watercolorist': 'visual artist',
#     'Yōga painter': 'visual artist',
#
#     # VISUAL ARTS - DIGITAL/MODERN
#     'animation director': 'digital artist',
#     'animator': 'digital artist',
#     'character animator': 'digital artist',
#     'computer animator': 'digital artist',
#     'conceptual artist': 'digital artist',
#     'digital artist': 'digital artist',
#     'multimedia artist': 'digital artist',
#     'storyboard artist': 'digital artist',
#     'video artist': 'digital artist',
#
#     # DESIGN
#     'architect': 'designer',
#     'board game designer': 'designer',
#     'car designer': 'designer',
#     'designer': 'designer',
#     'drafter': 'designer',
#     'draftsperson': 'designer',
#     'fashion designer': 'designer',
#     'furniture designer': 'designer',
#     'graphic designer': 'designer',
#     'industrial designer': 'designer',
#     'jewelry designer': 'designer',
#     'postage stamp designer': 'designer',
#     'product designer': 'designer',
#     'production designer': 'designer',
#     'role-playing game designer': 'designer',
#
#     # WRITING
#     'author': 'writer',
#     'blogger': 'writer',
#     "children's writer": 'writer',
#     'comedy writer': 'writer',
#     'comics creator': 'writer',
#     'comics writer': 'writer',
#     'dub poet': 'writer',
#     'editor': 'writer',
#     'electronic literature writer': 'writer',
#     'essayist': 'writer',
#     'film screenwriter': 'writer',
#     'instapoet': 'writer',
#     'librettist': 'writer',
#     'lyricist': 'writer',
#     'non-fiction writer': 'writer',
#     'novelist': 'writer',
#     'playwright': 'writer',
#     'poet': 'writer',
#     'poet lawyer': 'writer',
#     'prose writer': 'writer',
#     'religious writer': 'writer',
#     'science fiction writer': 'writer',
#     'screenwriter': 'writer',
#     'script doctor': 'writer',
#     'short story writer': 'writer',
#     'television writer': 'writer',
#     'writer': 'writer',
#
#     # FILM/TV/MEDIA
#     'cinematographer': 'media director',
#     'director': 'media director',
#     'film director': 'media director',
#     'film editor': 'media director',
#     'filmmaker': 'media director',
#     'music video director': 'media director',
#     'pornographic film director': 'media director',
#     'television director': 'media director',
#     'theatrical director': 'media director',
#     'theatre maker': 'media director',
#
#     # COMEDY
#     'comedian': 'comedian',
#     'humorist': 'comedian',
#     'impressionist': 'comedian',
#     'improviser': 'comedian',
#     'stand-up comedian': 'comedian',
#
#     # NEW MEDIA
#     'content creator': 'new media creator',
#     'Minecraft YouTuber': 'new media creator',
#     'online streamer': 'new media creator',
#     'VTuber': 'new media creator',
#     'vlogger': 'new media creator',
#     'YouTuber': 'new media creator',
#
#     # PHOTOGRAPHY
#     'nature photographer': 'photographer',
#     'photographer': 'photographer',
#     'portrait photographer': 'photographer',
#
#     # OTHER
#     'dramaturge': 'other creative',
#     'film score composer': 'other creative',
#     'inventor': 'other creative',
#     'music arranger': 'other creative',
#     'roleplayer': 'other creative',
#     'sound artist': 'other creative',
#     'tattoo artist': 'other creative',
#     'troll': 'other creative'
# }
#
# Main categories and their descriptions
#
#     # CATEGORY_DESCRIPTIONS = {
#     'actor': 'Professional performers in theater, film, television, and voice acting',
#     'musician': 'Musical performers, composers, and instrumentalists',
#     'dancer': 'Professional dancers and choreographers',
#     'performer': 'Other performing artists and entertainers',
#     'visual artist': 'Traditional visual artists working in physical mediums',
#     'digital artist': 'Artists working primarily with digital and animated mediums',
#     'designer': 'Professional designers across various fields',
#     'writer': 'Authors and writers across different genres and mediums',
#     'media director': 'Directors and producers of film, television, and theater',
#     'comedian': 'Professional comedy performers and writers',
#     'new media creator': 'Content creators on modern digital platforms',
#     'photographer': 'Professional photographers across different specialties',
#     'other creative': 'Other creative professionals not fitting main categories'
# }

# %% [markdown]
# # Final analysis code.

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency, fisher_exact
from collections import defaultdict
import scipy.stats as ss

# ============= OCCUPATION MAPPING =============
def standardize_occupation(occupation):
    """Map occupation to standard category"""
    if not isinstance(occupation, str):
        return 'other'
    return OCCUPATION_MAPPING.get(occupation.lower(), 'other')

OCCUPATION_MAPPING = {
    
#PERFORMING ARTS - ACTING
'actor': 'actor',
'character actor': 'actor',
'child actor': 'actor',
'film actor': 'actor',
'musical theatre actor': 'actor',
'stage actor': 'actor',
'television actor': 'actor',
'video game actor': 'actor',
'voice actor': 'actor',

# PERFORMING ARTS - MUSIC
'bandleader': 'musician',
'banjoist': 'musician',
'bass guitarist': 'musician',
'bassist': 'musician',
'cantaor': 'musician',
'carillonist': 'musician',
'cellist': 'musician',
'classical pianist': 'musician',
'club DJ': 'musician',
'composer': 'musician',
'conductor': 'musician',
'disc jockey': 'musician',
'djembe player': 'musician',
'double-bassist': 'musician',
'drummer': 'musician',
'electronic musician': 'musician',
'guitarist': 'musician',
'instrumentalist': 'musician',
'jazz drummer': 'musician',
'jazz guitarist': 'musician',
'jazz musician': 'musician',
'jazz pianist': 'musician',
'jazz singer': 'musician',
'keyboardist': 'musician',
'lutenist': 'musician',
'mandolinist': 'musician',
'multi-instrumentalist': 'musician',
'music artist': 'musician',
'musician': 'musician',
'opera singer': 'musician',
'organist': 'musician',
'percussionist': 'musician',
'pianist': 'musician',
'pop singer': 'musician',
'rapper': 'musician',
'recording artist': 'musician',
'rock musician': 'musician',
'rock singer': 'musician',
'saxophonist': 'musician',
'scat singer': 'musician',
'session musician': 'musician',
'singer': 'musician',
'singer-songwriter': 'musician',
'songwriter': 'musician',
'street musician': 'musician',
'trumpeter': 'musician',
'turntabler': 'musician',
'violinist': 'musician',
'violist': 'musician',
'vocalist': 'musician',

# PERFORMING ARTS - DANCE
'ballet dancer': 'dancer',
'ballet master': 'dancer',
'choreographer': 'dancer',
'dancer': 'dancer',
'showgirl': 'dancer',

# PERFORMING ARTS - OTHER
'circus performer': 'performer',
'conferencier': 'performer',
'drag queen': 'performer',
'entertainer': 'performer',
'impostor': 'performer',
'mime artist': 'performer',
'narrator': 'performer',
'owarai tarento': 'performer',
'performance artist': 'performer',
'performing artist': 'performer',
'stage magician': 'performer',
'stunt performer': 'performer',
'tarento': 'performer',

# VISUAL ARTS - TRADITIONAL
'artist': 'visual artist',
'botanical illustrator': 'visual artist',
'calligrapher': 'visual artist',
'caricaturist': 'visual artist',
'cartoonist': 'visual artist',
'collagist': 'visual artist',
'comics artist': 'visual artist',
'etcher': 'visual artist',
'Formally schooled painter': 'visual artist',
'graffiti artist': 'visual artist',
'graphic artist': 'visual artist',
'illustrator': 'visual artist',
'installation artist': 'visual artist',
'mangaka': 'visual artist',
'object artist': 'visual artist',
'painter': 'visual artist',
'papercut artist': 'visual artist',
'plastic artist': 'visual artist',
'portrait painter': 'visual artist',
'printmaker': 'visual artist',
'serigrapher': 'visual artist',
'street artist': 'visual artist',
'textile artist': 'visual artist',
'visual artist': 'visual artist',
'watercolorist': 'visual artist',
'Yōga painter': 'visual artist',

# VISUAL ARTS - DIGITAL/MODERN
'animation director': 'digital artist',
'animator': 'digital artist',
'character animator': 'digital artist',
'computer animator': 'digital artist',
'conceptual artist': 'digital artist',
'digital artist': 'digital artist',
'multimedia artist': 'digital artist',
'storyboard artist': 'digital artist',
'video artist': 'digital artist',

# DESIGN
'architect': 'designer',
'board game designer': 'designer',
'car designer': 'designer',
'designer': 'designer',
'drafter': 'designer',
'draftsperson': 'designer',
'fashion designer': 'designer',
'furniture designer': 'designer',
'graphic designer': 'designer',
'industrial designer': 'designer',
'jewelry designer': 'designer',
'postage stamp designer': 'designer',
'product designer': 'designer',
'production designer': 'designer',
'role-playing game designer': 'designer',

# WRITING
'author': 'writer',
'blogger': 'writer',
"children's writer": 'writer',
'comedy writer': 'writer',
'comics creator': 'writer',
'comics writer': 'writer',
'dub poet': 'writer',
'editor': 'writer',
'electronic literature writer': 'writer',
'essayist': 'writer',
'film screenwriter': 'writer',
'instapoet': 'writer',
'librettist': 'writer',
'lyricist': 'writer',
'non-fiction writer': 'writer',
'novelist': 'writer',
'playwright': 'writer',
'poet': 'writer',
'poet lawyer': 'writer',
'prose writer': 'writer',
'religious writer': 'writer',
'science fiction writer': 'writer',
'screenwriter': 'writer',
'script doctor': 'writer',
'short story writer': 'writer',
'television writer': 'writer',
'writer': 'writer',

# FILM/TV/MEDIA
'cinematographer': 'media director',
'director': 'media director',
'film director': 'media director',
'film editor': 'media director',
'filmmaker': 'media director',
'music video director': 'media director',
'pornographic film director': 'media director',
'television director': 'media director',
'theatrical director': 'media director',
'theatre maker': 'media director',

# COMEDY
'comedian': 'comedian',
'humorist': 'comedian',
'impressionist': 'comedian',
'improviser': 'comedian',
'stand-up comedian': 'comedian',

# NEW MEDIA
'content creator': 'new media creator',
'Minecraft YouTuber': 'new media creator',
'online streamer': 'new media creator',
'VTuber': 'new media creator',
'vlogger': 'new media creator',
'YouTuber': 'new media creator',

# PHOTOGRAPHY
'nature photographer': 'photographer',
'photographer': 'photographer',
'portrait photographer': 'photographer',

# OTHER
'dramaturge': 'other creative',
'film score composer': 'other creative',
'inventor': 'other creative',
'music arranger': 'other creative',
'roleplayer': 'other creative',
'sound artist': 'other creative',
'tattoo artist': 'other creative',
'troll': 'other creative'

}

# ============= ANALYSIS FUNCTIONS =============


def calculate_cramers_v(contingency):
    """Calculate Cramer's V coefficient"""
    chi2 = chi2_contingency(contingency)[0]
    n = contingency.sum()
    min_dim = min(contingency.shape) - 1
    return np.sqrt(chi2 / (n * min_dim))

def calculate_theil_u(x, y):
    """Calculate Theil's U statistic (asymmetric)"""
    # Ensure inputs are numpy arrays
    x = np.array(x)
    y = np.array(y)
    
    # Calculate joint and marginal frequencies
    xy_count = pd.crosstab(x, y, normalize=True).values
    x_count = xy_count.sum(axis=1)
    y_count = xy_count.sum(axis=0)
    
    # Calculate entropies
    h_x = -np.sum(x_count * np.log2(x_count + np.finfo(float).eps))
    h_y = -np.sum(y_count * np.log2(y_count + np.finfo(float).eps))
    h_xy = -np.sum(xy_count.flatten() * np.log2(xy_count.flatten() + np.finfo(float).eps))
    
    # Calculate U statistics (both directions)
    u_xy = (h_x + h_y - h_xy) / h_x  # U(Y|X)
    u_yx = (h_x + h_y - h_xy) / h_y  # U(X|Y)
    
    return u_xy, u_yx

def analyze_disorder_occupation_patterns(data):
    """Analyze patterns between disorders and creative occupations with additional measures"""
    cd_data = data['CD']
    results = {}
    
    # For each disorder
    for disorder in cd_data['dsm-5'].unique():
        disorder_data = cd_data[cd_data['dsm-5'] == disorder]
        disorder_binary = (cd_data['dsm-5'] == disorder).astype(int)
        
        # Count occupations for this disorder
        occupation_counts = disorder_data['occupation_category'].value_counts()
        total_disorder = len(disorder_data)
        
        # Calculate proportions and statistics
        disorder_stats = {}
        for occ in occupation_counts.index:
            # Create occupation binary vector
            occ_binary = (cd_data['occupation_category'] == occ).astype(int)
            
            # Get counts for contingency table
            count = occupation_counts[occ]
            with_disorder_with_occ = count
            with_disorder_without_occ = total_disorder - count
            without_disorder_with_occ = len(cd_data[cd_data['occupation_category'] == occ]) - count
            without_disorder_without_occ = len(cd_data) - without_disorder_with_occ - total_disorder
            
            # Create contingency table
            contingency = np.array([
                [with_disorder_with_occ, with_disorder_without_occ],
                [without_disorder_with_occ, without_disorder_without_occ]
            ])
            
            # Calculate Fisher's exact test
            odds_ratio, p_value = fisher_exact(contingency)
            
            # Calculate Cramer's V
            cramers_v = calculate_cramers_v(contingency)
            
            # Calculate Theil's U
            theil_u_disorder_occ, theil_u_occ_disorder = calculate_theil_u(
                disorder_binary, 
                occ_binary
            )
            
            disorder_stats[occ] = {
                'count': count,
                'proportion': count / total_disorder,
                'odds_ratio': odds_ratio,
                'p_value': p_value,
                'cramers_v': cramers_v,
                'theil_u_disorder_given_occ': theil_u_disorder_occ,
                'theil_u_occ_given_disorder': theil_u_occ_disorder
            }
        
        results[disorder] = disorder_stats
    
    return results

def generate_report(results):
    """Generate enhanced analysis report with additional measures"""
    report = []
    report.append("ANALYSIS OF DISORDERS AND CREATIVE OCCUPATIONS")
    report.append("=" * 50)
    
    # Sort disorders by total number of significant associations
    significant_counts = {}
    for disorder, stats in results.items():
        significant_counts[disorder] = sum(1 for occ_stats in stats.values() 
                                        if occ_stats['p_value'] < 0.05)
    
    sorted_disorders = sorted(significant_counts.items(), 
                            key=lambda x: x[1], reverse=True)
    
    # Report significant associations
    for disorder, count in sorted_disorders:
        if count > 0:
            report.append(f"\nDisorder: {disorder}")
            report.append("Significant associations:")
            
            # Get occupation stats for this disorder
            disorder_stats = results[disorder]
            significant_occs = {occ: stats for occ, stats in disorder_stats.items()
                              if stats['p_value'] < 0.05}
            
            # Sort by odds ratio
            sorted_occs = sorted(significant_occs.items(),
                               key=lambda x: x[1]['odds_ratio'],
                               reverse=True)
            
            for occ, stats in sorted_occs:
                report.append(f"  {occ}:")
                report.append(f"    Count: {stats['count']}")
                report.append(f"    Proportion: {stats['proportion']:.2%}")
                report.append(f"    Odds Ratio: {stats['odds_ratio']:.2f}")
                report.append(f"    P-value: {stats['p_value']:.4f}")
                report.append(f"    Cramer's V: {stats['cramers_v']:.4f}")
                report.append(f"    Theil's U (Disorder|Occupation): {stats['theil_u_disorder_given_occ']:.4f}")
                report.append(f"    Theil's U (Occupation|Disorder): {stats['theil_u_occ_given_disorder']:.4f}")
    
    return "\n".join(report)

def main():
    # Read and process data
    print("Reading and processing data...")
    data = read_and_process_data()
    
    # Analyze patterns
    print("Analyzing patterns...")
    results = analyze_disorder_occupation_patterns(data)
    
    # Generate report
    print("Generating report...")
    report = generate_report(results)
    
    # Save report
    with open('disorder_occupation_analysis_enhanced.txt', 'w') as f:
        f.write(report)
    
    print("Analysis complete! Results saved to 'disorder_occupation_analysis_enhanced.txt'")

if __name__ == "__main__":
    main()
# Out:
# Reading and processing data...
# Analyzing patterns...
# Generating report...
# Analysis complete! Results saved to 'disorder_occupation_analysis_enhanced.txt'

# %% [markdown]
# ## Code explanation.
# The code first standardizes various creative professions into broader categories (like 'musician', 'visual artist', 'writer', etc.) and then applies multiple statistical measures to assess the relationships between these occupations and different DSM-5 disorders. The statistical tests used include:
#
# Fisher's Exact Test: This tests for independence between categorical variables and is particularly useful for small sample sizes. It calculates an odds ratio and p-value to determine if there's a significant association between a specific disorder and occupation. It was chosen over Chi-square because it calculates exact probabilities rather than approximations and remains reliable with small sample sizes or sparse data (unlike Chi-square which requires expected frequencies >5 in each cell), making it ideal for analyzing potentially rare disorder-occupation combinations. \
# Cramer's V: This measures the strength of association between two categorical variables, ranging from 0 (no association) to 1 (perfect association). It's particularly useful because it's independent of the sample size and number of categories.\
# Theil's U (Information Uncertainty Coefficient): This is an asymmetric measure that quantifies how much knowing one variable reduces uncertainty about the other. It's calculated in both directions: how well occupation predicts disorder (U(Disorder|Occupation)) and how well disorder predicts occupation (U(Occupation|Disorder)). Values range from 0 (no reduction in uncertainty) to 1 (perfect prediction).\
#
# The code generates a comprehensive report that includes these statistics for each significant association found, with significant relationships determined by p-values less than 0.05. The results are sorted by the number of significant associations for each disorder, making it easier to identify which disorders have the strongest connections to creative occupations.
#
#
# In particular, the results contains the following  statistical measures:
# 1. Raw Measures:
#
# - Count: The absolute number of individuals with both the specific disorder and occupation
# - Proportion: The percentage of individuals with that occupation among all individuals with that disorder
#
# 2. Association Strength Measures:
# - Odds Ratio (OR): Measures how much more/less likely an occupation is among those with the disorder compared to those without
#     - OR > 1: positive association (e.g., OR=2 means twice as likely)
#     - OR < 1: negative association (e.g., OR=0.5 means half as likely)
#     - OR = 1: no association
#
# 3. Statistical Significance:
# - P-value:
#     - Probability of observing such results by chance.
#     - Conventionally significant if < 0.05.
#     - Calculated using Fisher's Exact Test (chosen over Chi-square due to small samples)
#
# 4. Effect Size Measures:
# - Cramer's V:
#     - Measures strength of association between two categorical variables
#     - Ranges from 0 (no association) to 1 (perfect association)
#     - Independent of sample size
#     - General interpretation:
#         - <0.1: very weak
#         - 0.1-0.3: weak
#         - 0.3-0.5: moderate
#         - 0.5: strong
#
# 5. Predictive Power Measures:
# - Theil's U (Information Uncertainty Coefficient):
#     - Measures how much knowing one variable reduces uncertainty about the other
#     - Calculated in both directions (asymmetric measure):
#     - U(Disorder|Occupation): How well occupation predicts disorder
#     - U(Occupation|Disorder): How well disorder predicts occupation
#     - Ranges from 0 (no prediction) to 1 (perfect prediction)
#     - Our results show consistently low values (<0.05), indicating weak predictive power in both directions
#
# ## Results.
# ### Disorder: Neurodevelopmental Disorders
#  Significant associations:
#   #### new media creator:
#     Count: 21
#     Proportion: 1.02%
#     Odds Ratio: 2.05
#     P-value: 0.0398
#     Cramer's V: 0.0280
#     Theil's U (Disorder|Occupation): 0.0007
#     Theil's U (Occupation|Disorder): 0.0107
#   #### other:
#     Count: 65
#     Proportion: 3.15%
#     Odds Ratio: 1.93
#     P-value: 0.0007
#     Cramer's V: 0.0478
#     Theil's U (Disorder|Occupation): 0.0017
#     Theil's U (Occupation|Disorder): 0.0109
#   #### designer:
#     Count: 48
#     Proportion: 2.33%
#     Odds Ratio: 1.53
#     P-value: 0.0438
#     Cramer's V: 0.0276
#     Theil's U (Disorder|Occupation): 0.0006
#     Theil's U (Occupation|Disorder): 0.0045
#   #### comedian:
#     Count: 91
#     Proportion: 4.41%
#     Odds Ratio: 1.40
#     P-value: 0.0276
#     Cramer's V: 0.0308
#     Theil's U (Disorder|Occupation): 0.0007
#     Theil's U (Occupation|Disorder): 0.0032
#   #### media director:
#     Count: 118
#     Proportion: 5.72%
#     Odds Ratio: 1.34
#     P-value: 0.0243
#     Cramer's V: 0.0310
#     Theil's U (Disorder|Occupation): 0.0007
#     Theil's U (Occupation|Disorder): 0.0026
#   #### visual artist:
#     Count: 85
#     Proportion: 4.12%
#     Odds Ratio: 0.76
#     P-value: 0.0461
#     Cramer's V: 0.0279
#     Theil's U (Disorder|Occupation): 0.0006
#     Theil's U (Occupation|Disorder): 0.0022
#
# ### Disorder: Schizophrenia Spectrum and Other Psychotic Disorders
# Significant associations:
#   #### visual artist:
#     Count: 51
#     Proportion: 17.11%
#     Odds Ratio: 4.82
#     P-value: 0.0000
#     Cramer's V: 0.1402
#     Theil's U (Disorder|Occupation): 0.0293
#     Theil's U (Occupation|Disorder): 0.0337
#   #### dancer:
#     Count: 7
#     Proportion: 2.35%
#     Odds Ratio: 2.65
#     P-value: 0.0255
#     Cramer's V: 0.0302
#     Theil's U (Disorder|Occupation): 0.0020
#     Theil's U (Occupation|Disorder): 0.0079
#   #### musician:
#     Count: 108
#     Proportion: 36.24%
#     Odds Ratio: 1.55
#     P-value: 0.0006
#     Cramer's V: 0.0485
#     Theil's U (Disorder|Occupation): 0.0052
#     Theil's U (Occupation|Disorder): 0.0020
#   #### actor:
#     Count: 43
#     Proportion: 14.43%
#     Odds Ratio: 0.48
#     P-value: 0.0000
#     Cramer's V: 0.0608
#     Theil's U (Disorder|Occupation): 0.0095
#     Theil's U (Occupation|Disorder): 0.0038
#   #### media director:
#     Count: 3
#     Proportion: 1.01%
#     Odds Ratio: 0.19
#     P-value: 0.0004
#     Cramer's V: 0.0430
#     Theil's U (Disorder|Occupation): 0.0065
#     Theil's U (Occupation|Disorder): 0.0074
#   #### comedian:
#     Count: 1
#     Proportion: 0.34%
#     Odds Ratio: 0.08
#     P-value: 0.0002
#     Cramer's V: 0.0422
#     Theil's U (Disorder|Occupation): 0.0071
#     Theil's U (Occupation|Disorder): 0.0101
#
# ### Disorder: Obsessive-Compulsive and Related Disorders
# Significant associations:
#   #### new media creator:
#     Count: 5
#     Proportion: 3.03%
#     Odds Ratio: 4.92
#     P-value: 0.0057
#     Cramer's V: 0.0441
#     Theil's U (Disorder|Occupation): 0.0051
#     Theil's U (Occupation|Disorder): 0.0173
#   #### other:
#     Count: 9
#     Proportion: 5.45%
#     Odds Ratio: 2.61
#     P-value: 0.0120
#     Cramer's V: 0.0355
#     Theil's U (Disorder|Occupation): 0.0039
#     Theil's U (Occupation|Disorder): 0.0052
#   #### actor:
#     Count: 54
#     Proportion: 32.73%
#     Odds Ratio: 1.47
#     P-value: 0.0282
#     Cramer's V: 0.0307
#     Theil's U (Disorder|Occupation): 0.0034
#     Theil's U (Occupation|Disorder): 0.0009
#   #### writer:
#     Count: 28
#     Proportion: 16.97%
#     Odds Ratio: 0.60
#     P-value: 0.0136
#     Cramer's V: 0.0330
#     Theil's U (Disorder|Occupation): 0.0044
#     Theil's U (Occupation|Disorder): 0.0011
#   #### visual artist:
#     Count: 2
#     Proportion: 1.21%
#     Odds Ratio: 0.23
#     P-value: 0.0248
#     Cramer's V: 0.0286
#     Theil's U (Disorder|Occupation): 0.0047
#     Theil's U (Occupation|Disorder): 0.0035
#
# ### Disorder: Communication Disorders
# Significant associations:
#   #### actor:
#     Count: 131
#     Proportion: 32.19%
#     Odds Ratio: 1.46
#     P-value: 0.0008
#     Cramer's V: 0.0470
#     Theil's U (Disorder|Occupation): 0.0039
#     Theil's U (Occupation|Disorder): 0.0019
#   #### writer:
#     Count: 129
#     Proportion: 31.70%
#     Odds Ratio: 1.43
#     P-value: 0.0019
#     Cramer's V: 0.0443
#     Theil's U (Disorder|Occupation): 0.0035
#     Theil's U (Occupation|Disorder): 0.0017
#   #### musician:
#     Count: 87
#     Proportion: 21.38%
#     Odds Ratio: 0.70
#     P-value: 0.0045
#     Cramer's V: 0.0392
#     Theil's U (Disorder|Occupation): 0.0030
#     Theil's U (Occupation|Disorder): 0.0014
#   #### visual artist:
#     Count: 9
#     Proportion: 2.21%
#     Odds Ratio: 0.42
#     P-value: 0.0077
#     Cramer's V: 0.0348
#     Theil's U (Disorder|Occupation): 0.0029
#     Theil's U (Occupation|Disorder): 0.0042
#   #### other:
#     Count: 1
#     Proportion: 0.25%
#     Odds Ratio: 0.10
#     P-value: 0.0014
#     Cramer's V: 0.0377
#     Theil's U (Disorder|Occupation): 0.0045
#     Theil's U (Occupation|Disorder): 0.0117
#
# ### Disorder: Bipolar and Related Disorders
# Significant associations:
#   #### musician:
#     Count: 290
#     Proportion: 34.56%
#     Odds Ratio: 1.50
#     P-value: 0.0000
#     Cramer's V: 0.0707
#     Theil's U (Disorder|Occupation): 0.0055
#     Theil's U (Occupation|Disorder): 0.0042
#   #### designer:
#     Count: 7
#     Proportion: 0.83%
#     Odds Ratio: 0.40
#     P-value: 0.0162
#     Cramer's V: 0.0317
#     Theil's U (Disorder|Occupation): 0.0015
#     Theil's U (Occupation|Disorder): 0.0074
#   #### other:
#     Count: 8
#     Proportion: 0.95%
#     Odds Ratio: 0.37
#     P-value: 0.0033
#     Cramer's V: 0.0375
#     Theil's U (Disorder|Occupation): 0.0021
#     Theil's U (Occupation|Disorder): 0.0087
#   #### new media creator:
#     Count: 1
#     Proportion: 0.12%
#     Odds Ratio: 0.14
#     P-value: 0.0221
#     Cramer's V: 0.0282
#     Theil's U (Disorder|Occupation): 0.0016
#     Theil's U (Occupation|Disorder): 0.0167
#
# ### Disorder: Neurocognitive Disorders
# Significant associations:
#   #### other creative:
#     Count: 3
#     Proportion: 2.10%
#     Odds Ratio: 4.04
#     P-value: 0.0470
#     Cramer's V: 0.0266
#     Theil's U (Disorder|Occupation): 0.0028
#     Theil's U (Occupation|Disorder): 0.0102
#   #### performer:
#     Count: 5
#     Proportion: 3.50%
#     Odds Ratio: 3.69
#     P-value: 0.0161
#     Cramer's V: 0.0352
#     Theil's U (Disorder|Occupation): 0.0041
#     Theil's U (Occupation|Disorder): 0.0092
#   #### actor:
#     Count: 58
#     Proportion: 40.56%
#     Odds Ratio: 2.08
#     P-value: 0.0000
#     Cramer's V: 0.0591
#     Theil's U (Disorder|Occupation): 0.0129
#     Theil's U (Occupation|Disorder): 0.0029
#   #### writer:
#     Count: 19
#     Proportion: 13.29%
#     Odds Ratio: 0.45
#     P-value: 0.0006
#     Cramer's V: 0.0449
#     Theil's U (Disorder|Occupation): 0.0095
#     Theil's U (Occupation|Disorder): 0.0022
#
# ### Disorder: Anxiety Disorders
# Significant associations:
#   #### new media creator:
#     Count: 3
#     Proportion: 3.30%
#     Odds Ratio: 5.11
#     P-value: 0.0260
#     Cramer's V: 0.0328
#     Theil's U (Disorder|Occupation): 0.0052
#     Theil's U (Occupation|Disorder): 0.0111
#   #### dancer:
#     Count: 4
#     Proportion: 4.40%
#     Odds Ratio: 4.93
#     P-value: 0.0119
#     Cramer's V: 0.0391
#     Theil's U (Disorder|Occupation): 0.0066
#     Theil's U (Occupation|Disorder): 0.0108
#   #### writer:
#     Count: 32
#     Proportion: 35.16%
#     Odds Ratio: 1.64
#     P-value: 0.0282
#     Cramer's V: 0.0298
#     Theil's U (Disorder|Occupation): 0.0051
#     Theil's U (Occupation|Disorder): 0.0008
#   #### musician:
#     Count: 10
#     Proportion: 10.99%
#     Odds Ratio: 0.32
#     P-value: 0.0002
#     Cramer's V: 0.0481
#     Theil's U (Disorder|Occupation): 0.0164
#     Theil's U (Occupation|Disorder): 0.0025
#
# ### Disorder: Other Conditions
# Significant associations:
#   #### visual artist:
#     Count: 20
#     Proportion: 15.04%
#     Odds Ratio: 3.67
#     P-value: 0.0000
#     Cramer's V: 0.0747
#     Theil's U (Disorder|Occupation): 0.0165
#     Theil's U (Occupation|Disorder): 0.0103
#   #### designer:
#     Count: 7
#     Proportion: 5.26%
#     Odds Ratio: 3.10
#     P-value: 0.0112
#     Cramer's V: 0.0369
#     Theil's U (Disorder|Occupation): 0.0048
#     Theil's U (Occupation|Disorder): 0.0063
#   #### musician:
#     Count: 7
#     Proportion: 5.26%
#     Odds Ratio: 0.14
#     P-value: 0.0000
#     Cramer's V: 0.0801
#     Theil's U (Disorder|Occupation): 0.0365
#     Theil's U (Occupation|Disorder): 0.0075
#
# ### Disorder: Trauma and Stressor-Related Disorders
# Significant associations:
#   #### writer:
#     Count: 17
#     Proportion: 40.48%
#     Odds Ratio: 2.05
#     P-value: 0.0302
#     Cramer's V: 0.0300
#     Theil's U (Disorder|Occupation): 0.0099
#     Theil's U (Occupation|Disorder): 0.0008
#   #### actor:
#     Count: 3
#     Proportion: 7.14%
#     Odds Ratio: 0.23
#     P-value: 0.0041
#     Cramer's V: 0.0354
#     Theil's U (Disorder|Occupation): 0.0192
#     Theil's U (Occupation|Disorder): 0.0016
#
# ### Disorder: Substance-Related and Addictive Disorders
# Significant associations:
#   #### digital artist:
#     Count: 5
#     Proportion: 2.21%
#     Odds Ratio: 3.89
#     P-value: 0.0144
#     Cramer's V: 0.0360
#     Theil's U (Disorder|Occupation): 0.0031
#     Theil's U (Occupation|Disorder): 0.0142
#   #### actor:
#     Count: 42
#     Proportion: 18.58%
#     Odds Ratio: 0.67
#     P-value: 0.0187
#     Cramer's V: 0.0316
#     Theil's U (Disorder|Occupation): 0.0031
#     Theil's U (Occupation|Disorder): 0.0010
#
# ### Disorder: Personality Disorders
# Significant associations:
#   #### dancer:
#     Count: 3
#     Proportion: 3.61%
#     Odds Ratio: 3.94
#     P-value: 0.0477
#     Cramer's V: 0.0265
#     Theil's U (Disorder|Occupation): 0.0042
#     Theil's U (Occupation|Disorder): 0.0064
#   #### comedian:
#     Count: 7
#     Proportion: 8.43%
#     Odds Ratio: 2.46
#     P-value: 0.0324
#     Cramer's V: 0.0284
#     Theil's U (Disorder|Occupation): 0.0047
#     Theil's U (Occupation|Disorder): 0.0025
#
# ### Disorder: Depressive Disorders
# Significant associations:
#   #### writer:
#     Count: 127
#     Proportion: 29.33%
#     Odds Ratio: 1.27
#     P-value: 0.0368
#     Cramer's V: 0.0292
#     Theil's U (Disorder|Occupation): 0.0015
#     Theil's U (Occupation|Disorder): 0.0008
#
# ### Disorder: Uncategorized
# Significant associations:
#   #### other:
#     Count: 3
#     Proportion: 16.67%
#     Odds Ratio: 8.83
#     P-value: 0.0072
#     Cramer's V: 0.0466
#     Theil's U (Disorder|Occupation): 0.0303
#     Theil's U (Occupation|Disorder): 0.0066
#
# ### Disorder: Feeding and Eating Disorders
# Significant associations:
#   #### musician:
#     Count: 27
#     Proportion: 45.00%
#     Odds Ratio: 2.19
#     P-value: 0.0033
#     Cramer's V: 0.0411
#     Theil's U (Disorder|Occupation): 0.0131
#     Theil's U (Occupation|Disorder): 0.0014
